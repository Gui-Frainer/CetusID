# %%
#80 DPI 2S

# %%
import pandas as pd
import datetime
time = "2021-3-21 00:00:00.00"
#real_start_time = datetime.fromisoformat(time)
time_actual = datetime.datetime.strptime(time, "%Y-%m-%d %H:%M:%S.%f")
delta = delta = datetime.timedelta(seconds=1)
#print(time_actual)
time_to_be_detected = time_actual
#Human detector encounters SNR >=1
H_ENC1_s = datetime.datetime.strptime("2021-03-21 00:58:22.938328", "%Y-%m-%d %H:%M:%S.%f")
H_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:03:39.952157", "%Y-%m-%d %H:%M:%S.%f")

H_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:31.935836", "%Y-%m-%d %H:%M:%S.%f")
H_ENC2_e=  datetime.datetime.strptime("2021-03-21 04:21:59.049616", "%Y-%m-%d %H:%M:%S.%f")

H_ENC3_s = datetime.datetime.strptime("2021-03-21 04:53:49.078051", "%Y-%m-%d %H:%M:%S.%f")
H_ENC3_e=  datetime.datetime.strptime("2021-03-21 06:49:34.904194", "%Y-%m-%d %H:%M:%S.%f")

H_ENC4_s = datetime.datetime.strptime("2021-03-21 07:24:18.985777", "%Y-%m-%d %H:%M:%S.%f")
H_ENC4_e=  datetime.datetime.strptime("2021-03-21 07:39:28.855199", "%Y-%m-%d %H:%M:%S.%f")

H_ENC5_s = datetime.datetime.strptime("2021-03-21 12:11:50.374341", "%Y-%m-%d %H:%M:%S.%f")
H_ENC5_e=  datetime.datetime.strptime("2021-03-21 12:22:31.117159", "%Y-%m-%d %H:%M:%S.%f")

H_ENC6_s = datetime.datetime.strptime("2021-03-21 12:37:42.023821", "%Y-%m-%d %H:%M:%S.%f")
H_ENC6_e=  datetime.datetime.strptime("2021-03-21 13:06:38.879766", "%Y-%m-%d %H:%M:%S.%f")

H_ENC7_s = datetime.datetime.strptime("2021-03-21 13:22:59.004893", "%Y-%m-%d %H:%M:%S.%f")
H_ENC7_e=  datetime.datetime.strptime("2021-03-21 14:23:26.628424", "%Y-%m-%d %H:%M:%S.%f")

H_ENC8_s = datetime.datetime.strptime("2021-03-21 14:23:35.936122", "%Y-%m-%d %H:%M:%S.%f")
H_ENC8_e=  datetime.datetime.strptime("2021-03-21 15:03:31.143575", "%Y-%m-%d %H:%M:%S.%f")

H_ENC9_s = datetime.datetime.strptime("2021-03-21 18:46:23.912812", "%Y-%m-%d %H:%M:%S.%f")
H_ENC9_e=  datetime.datetime.strptime("2021-03-21 19:30:46.765953", "%Y-%m-%d %H:%M:%S.%f")

H_ENC10_s = datetime.datetime.strptime("2021-03-21 20:15:33.222835", "%Y-%m-%d %H:%M:%S.%f")
H_ENC10_e=  datetime.datetime.strptime("2021-03-21 20:15:42.360361", "%Y-%m-%d %H:%M:%S.%f")

H_ENC11_s = datetime.datetime.strptime("2021-03-21 20:36:44.460596", "%Y-%m-%d %H:%M:%S.%f")
H_ENC11_e=  datetime.datetime.strptime("2021-03-21 20:50:40.901156", "%Y-%m-%d %H:%M:%S.%f")

H_ENC12_s = datetime.datetime.strptime("2021-03-21 21:16:07.103957", "%Y-%m-%d %H:%M:%S.%f")
H_ENC12_e=  datetime.datetime.strptime("2021-03-21 21:48:59.425626", "%Y-%m-%d %H:%M:%S.%f")

H_ENC13_s = datetime.datetime.strptime("2021-03-21 22:30:54.162231", "%Y-%m-%d %H:%M:%S.%f")
H_ENC13_e=  datetime.datetime.strptime("2021-03-21 22:36:18.208851", "%Y-%m-%d %H:%M:%S.%f")

H_ENC14_s = datetime.datetime.strptime("2021-03-21 22:52:18.849871", "%Y-%m-%d %H:%M:%S.%f")
H_ENC14_e=  datetime.datetime.strptime("2021-03-21 22:52:44.870850", "%Y-%m-%d %H:%M:%S.%f")

H_ENC15_s = datetime.datetime.strptime("2021-03-21 23:26:16.257801", "%Y-%m-%d %H:%M:%S.%f")
H_ENC15_e=  datetime.datetime.strptime("2021-03-21 23:26:36.607445", "%Y-%m-%d %H:%M:%S.%f")

H_ENC16_s = datetime.datetime.strptime("2021-03-21 23:57:45.979014", "%Y-%m-%d %H:%M:%S.%f")
H_ENC16_e=  datetime.datetime.strptime("2021-03-21 23:57:46.724934", "%Y-%m-%d %H:%M:%S.%f")

#Model testing 80 dpi 2s

M_ENC1_s = datetime.datetime.strptime("2021-03-21 03:17:30", "%Y-%m-%d %H:%M:%S")
M_ENC1_e=  datetime.datetime.strptime("2021-03-21 03:17:31", "%Y-%m-%d %H:%M:%S")

M_ENC2_s = datetime.datetime.strptime("2021-03-21 05:39:13", "%Y-%m-%d %H:%M:%S")
M_ENC2_e=  datetime.datetime.strptime("2021-03-21 05:39:14", "%Y-%m-%d %H:%M:%S")

M_ENC3_s = datetime.datetime.strptime("2021-03-21 09:46:52", "%Y-%m-%d %H:%M:%S")
M_ENC3_e=  datetime.datetime.strptime("2021-03-21 09:47:09", "%Y-%m-%d %H:%M:%S")

M_ENC4_s = datetime.datetime.strptime("2021-03-21 11:51:30", "%Y-%m-%d %H:%M:%S")
M_ENC4_e=  datetime.datetime.strptime("2021-03-21 11:51:31", "%Y-%m-%d %H:%M:%S")

M_ENC5_s = datetime.datetime.strptime("2021-03-21 12:36:40", "%Y-%m-%d %H:%M:%S")
M_ENC5_e=  datetime.datetime.strptime("2021-03-21 12:49:16", "%Y-%m-%d %H:%M:%S")

M_ENC6_s = datetime.datetime.strptime("2021-03-21 13:30:27", "%Y-%m-%d %H:%M:%S")
M_ENC6_e=  datetime.datetime.strptime("2021-03-21 15:02:53", "%Y-%m-%d %H:%M:%S")

M_ENC7_s = datetime.datetime.strptime("2021-03-21 15:32:21", "%Y-%m-%d %H:%M:%S")
M_ENC7_e=  datetime.datetime.strptime("2021-03-21 15:32:36", "%Y-%m-%d %H:%M:%S")

M_ENC8_s = datetime.datetime.strptime("2021-03-21 16:36:22", "%Y-%m-%d %H:%M:%S")
M_ENC8_e=  datetime.datetime.strptime("2021-03-21 16:36:23", "%Y-%m-%d %H:%M:%S")

M_ENC9_s = datetime.datetime.strptime("2021-03-21 18:48:24", "%Y-%m-%d %H:%M:%S")
M_ENC9_e=  datetime.datetime.strptime("2021-03-21 18:50:26", "%Y-%m-%d %H:%M:%S")

M_ENC10_s = datetime.datetime.strptime("2021-03-21 19:05:47", "%Y-%m-%d %H:%M:%S")
M_ENC10_e=  datetime.datetime.strptime("2021-03-21 19:27:36", "%Y-%m-%d %H:%M:%S")

M_ENC11_s = datetime.datetime.strptime("2021-03-21 20:34:43", "%Y-%m-%d %H:%M:%S")
M_ENC11_e=  datetime.datetime.strptime("2021-03-21 20:50:45", "%Y-%m-%d %H:%M:%S")

M_ENC12_s = datetime.datetime.strptime("2021-03-21 21:17:14", "%Y-%m-%d %H:%M:%S")
M_ENC12_e=  datetime.datetime.strptime("2021-03-21 21:51:47", "%Y-%m-%d %H:%M:%S")

M_ENC13_s = datetime.datetime.strptime("2021-03-21 22:08:31", "%Y-%m-%d %H:%M:%S")
M_ENC13_e=  datetime.datetime.strptime("2021-03-21 22:08:32", "%Y-%m-%d %H:%M:%S")

M_ENC14_s = datetime.datetime.strptime("2021-03-21 22:30:48", "%Y-%m-%d %H:%M:%S")
M_ENC14_e=  datetime.datetime.strptime("2021-03-21 22:36:09", "%Y-%m-%d %H:%M:%S")

confusion_matrix = []
for i in range(86400):
    #print(time_to_be_detected)
    
    if M_ENC1_s <= time_to_be_detected <= M_ENC1_e or M_ENC2_s <= time_to_be_detected <= M_ENC2_e or M_ENC3_s <= time_to_be_detected <= M_ENC3_e or M_ENC4_s <= time_to_be_detected <= M_ENC4_e or M_ENC5_s <= time_to_be_detected <= M_ENC5_e or M_ENC6_s <= time_to_be_detected <= M_ENC6_e or M_ENC7_s <= time_to_be_detected <= M_ENC7_e or M_ENC8_s <= time_to_be_detected <= M_ENC8_e or M_ENC9_s <= time_to_be_detected <= M_ENC9_e or M_ENC10_s <= time_to_be_detected <= M_ENC10_e or M_ENC11_s <= time_to_be_detected <= M_ENC11_e or M_ENC12_s <= time_to_be_detected <= M_ENC12_e or M_ENC13_s <= time_to_be_detected <= M_ENC13_e or M_ENC14_s <= time_to_be_detected <= M_ENC14_e:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e:
            #print("True Positive")
            confusion_matrix.append("TP")            
        else:
            #print("False Positive")
            confusion_matrix.append("FP")
    else:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e:
            #print("False Negative")
            confusion_matrix.append("FN")
        else:
            #print("True Negative")
            confusion_matrix.append("TN")    
           
    
    time_to_be_detected = time_to_be_detected + delta
    
confusion_matrix = pd.DataFrame(confusion_matrix, columns = ['confusion_matrix'])
prop_norm_off = confusion_matrix['confusion_matrix'].value_counts(normalize=False).to_string()#change normalize to true
#print("Confusion Matrix")
#print(prop_norm_off)
prop_norm_on = confusion_matrix['confusion_matrix'].value_counts(normalize=True).to_string()#change normalize to true
print("Model testing 80 dpi 2s x Human Detector all SNR")
print()
print("Normalized Confusion Matrix")
print(prop_norm_on)

TN = int(confusion_matrix['confusion_matrix'].value_counts()['TN'])
FN = int(confusion_matrix['confusion_matrix'].value_counts()['FN'])
TP = int(confusion_matrix['confusion_matrix'].value_counts()['TP'])
FP = int(confusion_matrix['confusion_matrix'].value_counts()['FP'])
specificity = TN/(TN + FP)
sensitivity = TP/(FN+TP)
accuracy = (TP+TN)/(TP+TN+FP+FN)
precision = TP/(TP+FP)
print('Specificity:', specificity)
print('Sensitivity:', sensitivity)
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Model testing 80 dpi 2s x Human Detector all SNR
#
# Normalized Confusion Matrix
# TN    0.690891
# FN    0.180174
# TP    0.124120
# FP    0.004815
# Specificity: 0.9930792393817898
# Sensitivity: 0.40789623825643756
# Accuracy: 0.8150115740740741
# Precision: 0.9626570915619389

# %%
import pandas as pd
import datetime
time = "2021-3-21 00:00:00.00"
#real_start_time = datetime.fromisoformat(time)
time_actual = datetime.datetime.strptime(time, "%Y-%m-%d %H:%M:%S.%f")
delta = delta = datetime.timedelta(seconds=1)
#print(time_actual)
time_to_be_detected = time_actual
#Human detector encounters SNR >=1
H_ENC1_s = datetime.datetime.strptime("2021-03-21 00:58:22.938328", "%Y-%m-%d %H:%M:%S.%f")
H_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:03:39.952157", "%Y-%m-%d %H:%M:%S.%f")

H_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:31.935836", "%Y-%m-%d %H:%M:%S.%f")
H_ENC2_e=  datetime.datetime.strptime("2021-03-21 04:21:59.049616", "%Y-%m-%d %H:%M:%S.%f")

H_ENC3_s = datetime.datetime.strptime("2021-03-21 04:53:49.078051", "%Y-%m-%d %H:%M:%S.%f")
H_ENC3_e=  datetime.datetime.strptime("2021-03-21 06:49:34.904194", "%Y-%m-%d %H:%M:%S.%f")

H_ENC4_s = datetime.datetime.strptime("2021-03-21 07:24:18.985777", "%Y-%m-%d %H:%M:%S.%f")
H_ENC4_e=  datetime.datetime.strptime("2021-03-21 07:39:28.855199", "%Y-%m-%d %H:%M:%S.%f")

H_ENC5_s = datetime.datetime.strptime("2021-03-21 12:11:50.374341", "%Y-%m-%d %H:%M:%S.%f")
H_ENC5_e=  datetime.datetime.strptime("2021-03-21 12:22:31.117159", "%Y-%m-%d %H:%M:%S.%f")

H_ENC6_s = datetime.datetime.strptime("2021-03-21 12:37:42.023821", "%Y-%m-%d %H:%M:%S.%f")
H_ENC6_e=  datetime.datetime.strptime("2021-03-21 13:06:38.879766", "%Y-%m-%d %H:%M:%S.%f")

H_ENC7_s = datetime.datetime.strptime("2021-03-21 13:22:59.004893", "%Y-%m-%d %H:%M:%S.%f")
H_ENC7_e=  datetime.datetime.strptime("2021-03-21 14:23:26.628424", "%Y-%m-%d %H:%M:%S.%f")

H_ENC8_s = datetime.datetime.strptime("2021-03-21 14:23:35.936122", "%Y-%m-%d %H:%M:%S.%f")
H_ENC8_e=  datetime.datetime.strptime("2021-03-21 15:03:31.143575", "%Y-%m-%d %H:%M:%S.%f")

H_ENC9_s = datetime.datetime.strptime("2021-03-21 18:46:23.912812", "%Y-%m-%d %H:%M:%S.%f")
H_ENC9_e=  datetime.datetime.strptime("2021-03-21 19:30:46.765953", "%Y-%m-%d %H:%M:%S.%f")

H_ENC10_s = datetime.datetime.strptime("2021-03-21 20:15:33.222835", "%Y-%m-%d %H:%M:%S.%f")
H_ENC10_e=  datetime.datetime.strptime("2021-03-21 20:15:42.360361", "%Y-%m-%d %H:%M:%S.%f")

H_ENC11_s = datetime.datetime.strptime("2021-03-21 20:36:44.460596", "%Y-%m-%d %H:%M:%S.%f")
H_ENC11_e=  datetime.datetime.strptime("2021-03-21 20:50:40.901156", "%Y-%m-%d %H:%M:%S.%f")

H_ENC12_s = datetime.datetime.strptime("2021-03-21 21:16:07.103957", "%Y-%m-%d %H:%M:%S.%f")
H_ENC12_e=  datetime.datetime.strptime("2021-03-21 21:48:59.425626", "%Y-%m-%d %H:%M:%S.%f")

H_ENC13_s = datetime.datetime.strptime("2021-03-21 22:30:54.162231", "%Y-%m-%d %H:%M:%S.%f")
H_ENC13_e=  datetime.datetime.strptime("2021-03-21 22:36:18.208851", "%Y-%m-%d %H:%M:%S.%f")

H_ENC14_s = datetime.datetime.strptime("2021-03-21 22:52:18.849871", "%Y-%m-%d %H:%M:%S.%f")
H_ENC14_e=  datetime.datetime.strptime("2021-03-21 22:52:44.870850", "%Y-%m-%d %H:%M:%S.%f")

H_ENC15_s = datetime.datetime.strptime("2021-03-21 23:26:16.257801", "%Y-%m-%d %H:%M:%S.%f")
H_ENC15_e=  datetime.datetime.strptime("2021-03-21 23:26:36.607445", "%Y-%m-%d %H:%M:%S.%f")

H_ENC16_s = datetime.datetime.strptime("2021-03-21 23:57:45.979014", "%Y-%m-%d %H:%M:%S.%f")
H_ENC16_e=  datetime.datetime.strptime("2021-03-21 23:57:46.724934", "%Y-%m-%d %H:%M:%S.%f")
#Model testing 70 dpi 2s

M_ENC1_s = datetime.datetime.strptime("2021-03-21 01:00:52", "%Y-%m-%d %H:%M:%S")
M_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:03:13", "%Y-%m-%d %H:%M:%S")

M_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:30", "%Y-%m-%d %H:%M:%S")
M_ENC2_e=  datetime.datetime.strptime("2021-03-21 03:19:00", "%Y-%m-%d %H:%M:%S")

M_ENC3_s = datetime.datetime.strptime("2021-03-21 03:41:08", "%Y-%m-%d %H:%M:%S")
M_ENC3_e=  datetime.datetime.strptime("2021-03-21 03:41:09", "%Y-%m-%d %H:%M:%S")

M_ENC4_s = datetime.datetime.strptime("2021-03-21 04:53:47", "%Y-%m-%d %H:%M:%S")
M_ENC4_e=  datetime.datetime.strptime("2021-03-21 05:12:30", "%Y-%m-%d %H:%M:%S")

M_ENC5_s = datetime.datetime.strptime("2021-03-21 05:39:13", "%Y-%m-%d %H:%M:%S")
M_ENC5_e=  datetime.datetime.strptime("2021-03-21 05:53:23", "%Y-%m-%d %H:%M:%S")

M_ENC6_s = datetime.datetime.strptime("2021-03-21 06:16:55", "%Y-%m-%d %H:%M:%S")
M_ENC6_e=  datetime.datetime.strptime("2021-03-21 06:17:26", "%Y-%m-%d %H:%M:%S")

M_ENC7_s = datetime.datetime.strptime("2021-03-21 06:47:10", "%Y-%m-%d %H:%M:%S")
M_ENC7_e=  datetime.datetime.strptime("2021-03-21 06:47:18", "%Y-%m-%d %H:%M:%S")

M_ENC8_s = datetime.datetime.strptime("2021-03-21 09:33:41", "%Y-%m-%d %H:%M:%S")
M_ENC8_e=  datetime.datetime.strptime("2021-03-21 09:47:09", "%Y-%m-%d %H:%M:%S")

M_ENC9_s = datetime.datetime.strptime("2021-03-21 10:20:43", "%Y-%m-%d %H:%M:%S")
M_ENC9_e=  datetime.datetime.strptime("2021-03-21 10:21:59", "%Y-%m-%d %H:%M:%S")

M_ENC10_s = datetime.datetime.strptime("2021-03-21 11:51:30", "%Y-%m-%d %H:%M:%S")
M_ENC10_e=  datetime.datetime.strptime("2021-03-21 11:51:40", "%Y-%m-%d %H:%M:%S")

M_ENC11_s = datetime.datetime.strptime("2021-03-21 12:07:33", "%Y-%m-%d %H:%M:%S")
M_ENC11_e=  datetime.datetime.strptime("2021-03-21 12:08:30", "%Y-%m-%d %H:%M:%S")

M_ENC12_s = datetime.datetime.strptime("2021-03-21 12:36:30", "%Y-%m-%d %H:%M:%S")
M_ENC12_e=  datetime.datetime.strptime("2021-03-21 13:00:13", "%Y-%m-%d %H:%M:%S")

M_ENC13_s = datetime.datetime.strptime("2021-03-21 13:28:01", "%Y-%m-%d %H:%M:%S")
M_ENC13_e=  datetime.datetime.strptime("2021-03-21 15:02:53", "%Y-%m-%d %H:%M:%S")

M_ENC14_s = datetime.datetime.strptime("2021-03-21 15:32:20", "%Y-%m-%d %H:%M:%S")
M_ENC14_e=  datetime.datetime.strptime("2021-03-21 15:32:36", "%Y-%m-%d %H:%M:%S")

M_ENC15_s = datetime.datetime.strptime("2021-03-21 16:36:21", "%Y-%m-%d %H:%M:%S")
M_ENC15_e=  datetime.datetime.strptime("2021-03-21 16:36:24", "%Y-%m-%d %H:%M:%S")

M_ENC16_s = datetime.datetime.strptime("2021-03-21 18:48:23", "%Y-%m-%d %H:%M:%S")
M_ENC16_e=  datetime.datetime.strptime("2021-03-21 19:39:20", "%Y-%m-%d %H:%M:%S")

M_ENC17_s = datetime.datetime.strptime("2021-03-21 20:06:36", "%Y-%m-%d %H:%M:%S")
M_ENC17_e=  datetime.datetime.strptime("2021-03-21 20:06:37", "%Y-%m-%d %H:%M:%S")

M_ENC18_s = datetime.datetime.strptime("2021-03-21 20:36:20", "%Y-%m-%d %H:%M:%S")
M_ENC18_e=  datetime.datetime.strptime("2021-03-21 20:50:20", "%Y-%m-%d %H:%M:%S")

M_ENC19_s = datetime.datetime.strptime("2021-03-21 21:16:05", "%Y-%m-%d %H:%M:%S")
M_ENC19_e=  datetime.datetime.strptime("2021-03-21 21:53:08", "%Y-%m-%d %H:%M:%S")

M_ENC20_s = datetime.datetime.strptime("2021-03-21 22:26:46", "%Y-%m-%d %H:%M:%S")
M_ENC20_e=  datetime.datetime.strptime("2021-03-21 22:36:09", "%Y-%m-%d %H:%M:%S")

M_ENC21_s = datetime.datetime.strptime("2021-03-21 22:51:17", "%Y-%m-%d %H:%M:%S")
M_ENC21_e=  datetime.datetime.strptime("2021-03-21 22:51:18", "%Y-%m-%d %H:%M:%S")

confusion_matrix = []
for i in range(86400):
    #print(time_to_be_detected)
    
    if M_ENC1_s <= time_to_be_detected <= M_ENC1_e or M_ENC2_s <= time_to_be_detected <= M_ENC2_e or M_ENC3_s <= time_to_be_detected <= M_ENC3_e or M_ENC4_s <= time_to_be_detected <= M_ENC4_e or M_ENC5_s <= time_to_be_detected <= M_ENC5_e or M_ENC6_s <= time_to_be_detected <= M_ENC6_e or M_ENC7_s <= time_to_be_detected <= M_ENC7_e or M_ENC8_s <= time_to_be_detected <= M_ENC8_e or M_ENC9_s <= time_to_be_detected <= M_ENC9_e or M_ENC10_s <= time_to_be_detected <= M_ENC10_e or M_ENC11_s <= time_to_be_detected <= M_ENC11_e or M_ENC12_s <= time_to_be_detected <= M_ENC12_e or M_ENC13_s <= time_to_be_detected <= M_ENC13_e or M_ENC14_s <= time_to_be_detected <= M_ENC14_e or M_ENC15_s <= time_to_be_detected <= M_ENC15_e or M_ENC16_s <= time_to_be_detected <= M_ENC16_e or M_ENC17_s <= time_to_be_detected <= M_ENC17_e or M_ENC18_s <= time_to_be_detected <= M_ENC18_e or M_ENC19_s <= time_to_be_detected <= M_ENC19_e or M_ENC20_s <= time_to_be_detected <= M_ENC20_e or M_ENC21_s <= time_to_be_detected <= M_ENC21_e:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e:
            #print("True Positive")
            confusion_matrix.append("TP")            
        else:
            #print("False Positive")
            confusion_matrix.append("FP")
    else:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e:
            #print("False Negative")
            confusion_matrix.append("FN")
        else:
            #print("True Negative")
            confusion_matrix.append("TN")    
           
    
    time_to_be_detected = time_to_be_detected + delta
    
confusion_matrix = pd.DataFrame(confusion_matrix, columns = ['confusion_matrix'])
prop_norm_off = confusion_matrix['confusion_matrix'].value_counts(normalize=False).to_string()#change normalize to true
#print("Confusion Matrix")
#print(prop_norm_off)
prop_norm_on = confusion_matrix['confusion_matrix'].value_counts(normalize=True).to_string()#change normalize to true
print("Model testing 70 dpi 2s x Human Detector all SNR")
print()
print("Normalized Confusion Matrix")
print(prop_norm_on)

TN = int(confusion_matrix['confusion_matrix'].value_counts()['TN'])
FN = int(confusion_matrix['confusion_matrix'].value_counts()['FN'])
TP = int(confusion_matrix['confusion_matrix'].value_counts()['TP'])
FP = int(confusion_matrix['confusion_matrix'].value_counts()['FP'])
specificity = TN/(TN + FP)
sensitivity = TP/(FN+TP)
accuracy = (TP+TN)/(TP+TN+FP+FN)
precision = TP/(TP+FP)
print('Specificity:', specificity)
print('Sensitivity:', sensitivity)
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Model testing 70 dpi 2s x Human Detector all SNR
#
# Normalized Confusion Matrix
# TN    0.671319
# TP    0.172778
# FN    0.131516
# FP    0.024387
# Specificity: 0.9649470129265169
# Sensitivity: 0.5677988665322734
# Accuracy: 0.8440972222222223
# Precision: 0.876313472262988

# %%
#90 dpi2s all SNR
import pandas as pd
import datetime
time = "2021-3-21 00:00:00.00"
#real_start_time = datetime.fromisoformat(time)
time_actual = datetime.datetime.strptime(time, "%Y-%m-%d %H:%M:%S.%f")
delta = delta = datetime.timedelta(seconds=1)
#print(time_actual)
time_to_be_detected = time_actual
#Human detector encounters SNR >=1
H_ENC1_s = datetime.datetime.strptime("2021-03-21 00:58:22.938328", "%Y-%m-%d %H:%M:%S.%f")
H_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:03:39.952157", "%Y-%m-%d %H:%M:%S.%f")

H_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:31.935836", "%Y-%m-%d %H:%M:%S.%f")
H_ENC2_e=  datetime.datetime.strptime("2021-03-21 04:21:59.049616", "%Y-%m-%d %H:%M:%S.%f")

H_ENC3_s = datetime.datetime.strptime("2021-03-21 04:53:49.078051", "%Y-%m-%d %H:%M:%S.%f")
H_ENC3_e=  datetime.datetime.strptime("2021-03-21 06:49:34.904194", "%Y-%m-%d %H:%M:%S.%f")

H_ENC4_s = datetime.datetime.strptime("2021-03-21 07:24:18.985777", "%Y-%m-%d %H:%M:%S.%f")
H_ENC4_e=  datetime.datetime.strptime("2021-03-21 07:39:28.855199", "%Y-%m-%d %H:%M:%S.%f")

H_ENC5_s = datetime.datetime.strptime("2021-03-21 12:11:50.374341", "%Y-%m-%d %H:%M:%S.%f")
H_ENC5_e=  datetime.datetime.strptime("2021-03-21 12:22:31.117159", "%Y-%m-%d %H:%M:%S.%f")

H_ENC6_s = datetime.datetime.strptime("2021-03-21 12:37:42.023821", "%Y-%m-%d %H:%M:%S.%f")
H_ENC6_e=  datetime.datetime.strptime("2021-03-21 13:06:38.879766", "%Y-%m-%d %H:%M:%S.%f")

H_ENC7_s = datetime.datetime.strptime("2021-03-21 13:22:59.004893", "%Y-%m-%d %H:%M:%S.%f")
H_ENC7_e=  datetime.datetime.strptime("2021-03-21 14:23:26.628424", "%Y-%m-%d %H:%M:%S.%f")

H_ENC8_s = datetime.datetime.strptime("2021-03-21 14:23:35.936122", "%Y-%m-%d %H:%M:%S.%f")
H_ENC8_e=  datetime.datetime.strptime("2021-03-21 15:03:31.143575", "%Y-%m-%d %H:%M:%S.%f")

H_ENC9_s = datetime.datetime.strptime("2021-03-21 18:46:23.912812", "%Y-%m-%d %H:%M:%S.%f")
H_ENC9_e=  datetime.datetime.strptime("2021-03-21 19:30:46.765953", "%Y-%m-%d %H:%M:%S.%f")

H_ENC10_s = datetime.datetime.strptime("2021-03-21 20:15:33.222835", "%Y-%m-%d %H:%M:%S.%f")
H_ENC10_e=  datetime.datetime.strptime("2021-03-21 20:15:42.360361", "%Y-%m-%d %H:%M:%S.%f")

H_ENC11_s = datetime.datetime.strptime("2021-03-21 20:36:44.460596", "%Y-%m-%d %H:%M:%S.%f")
H_ENC11_e=  datetime.datetime.strptime("2021-03-21 20:50:40.901156", "%Y-%m-%d %H:%M:%S.%f")

H_ENC12_s = datetime.datetime.strptime("2021-03-21 21:16:07.103957", "%Y-%m-%d %H:%M:%S.%f")
H_ENC12_e=  datetime.datetime.strptime("2021-03-21 21:48:59.425626", "%Y-%m-%d %H:%M:%S.%f")

H_ENC13_s = datetime.datetime.strptime("2021-03-21 22:30:54.162231", "%Y-%m-%d %H:%M:%S.%f")
H_ENC13_e=  datetime.datetime.strptime("2021-03-21 22:36:18.208851", "%Y-%m-%d %H:%M:%S.%f")

H_ENC14_s = datetime.datetime.strptime("2021-03-21 22:52:18.849871", "%Y-%m-%d %H:%M:%S.%f")
H_ENC14_e=  datetime.datetime.strptime("2021-03-21 22:52:44.870850", "%Y-%m-%d %H:%M:%S.%f")

H_ENC15_s = datetime.datetime.strptime("2021-03-21 23:26:16.257801", "%Y-%m-%d %H:%M:%S.%f")
H_ENC15_e=  datetime.datetime.strptime("2021-03-21 23:26:36.607445", "%Y-%m-%d %H:%M:%S.%f")

H_ENC16_s = datetime.datetime.strptime("2021-03-21 23:57:45.979014", "%Y-%m-%d %H:%M:%S.%f")
H_ENC16_e=  datetime.datetime.strptime("2021-03-21 23:57:46.724934", "%Y-%m-%d %H:%M:%S.%f")
#Model testing 70 dpi 2s

M_ENC1_s = datetime.datetime.strptime("2021-03-21 05:39:13", "%Y-%m-%d %H:%M:%S")
M_ENC1_e=  datetime.datetime.strptime("2021-03-21 05:39:14", "%Y-%m-%d %H:%M:%S")

M_ENC2_s = datetime.datetime.strptime("2021-03-21 09:46:51", "%Y-%m-%d %H:%M:%S")
M_ENC2_e=  datetime.datetime.strptime("2021-03-21 09:47:09", "%Y-%m-%d %H:%M:%S")

M_ENC3_s = datetime.datetime.strptime("2021-03-21 13:55:22", "%Y-%m-%d %H:%M:%S")
M_ENC3_e=  datetime.datetime.strptime("2021-03-21 14:18:56", "%Y-%m-%d %H:%M:%S")

M_ENC4_s = datetime.datetime.strptime("2021-03-21 14:37:00", "%Y-%m-%d %H:%M:%S")
M_ENC4_e=  datetime.datetime.strptime("2021-03-21 14:46:09", "%Y-%m-%d %H:%M:%S")

M_ENC5_s = datetime.datetime.strptime("2021-03-21 15:32:26", "%Y-%m-%d %H:%M:%S")
M_ENC5_e=  datetime.datetime.strptime("2021-03-21 15:32:36", "%Y-%m-%d %H:%M:%S")

M_ENC6_s = datetime.datetime.strptime("2021-03-21 18:49:28", "%Y-%m-%d %H:%M:%S")
M_ENC6_e=  datetime.datetime.strptime("2021-03-21 19:27:34", "%Y-%m-%d %H:%M:%S")

M_ENC7_s = datetime.datetime.strptime("2021-03-21 20:36:39", "%Y-%m-%d %H:%M:%S")
M_ENC7_e=  datetime.datetime.strptime("2021-03-21 20:50:19", "%Y-%m-%d %H:%M:%S")

M_ENC8_s = datetime.datetime.strptime("2021-03-21 21:19:42", "%Y-%m-%d %H:%M:%S")
M_ENC8_e=  datetime.datetime.strptime("2021-03-21 21:50:23", "%Y-%m-%d %H:%M:%S")

M_ENC9_s = datetime.datetime.strptime("2021-03-21 22:30:48", "%Y-%m-%d %H:%M:%S")
M_ENC9_e=  datetime.datetime.strptime("2021-03-21 22:36:06", "%Y-%m-%d %H:%M:%S")



confusion_matrix = []
for i in range(86400):
    #print(time_to_be_detected)
    
    if M_ENC1_s <= time_to_be_detected <= M_ENC1_e or M_ENC2_s <= time_to_be_detected <= M_ENC2_e or M_ENC3_s <= time_to_be_detected <= M_ENC3_e or M_ENC4_s <= time_to_be_detected <= M_ENC4_e or M_ENC5_s <= time_to_be_detected <= M_ENC5_e or M_ENC6_s <= time_to_be_detected <= M_ENC6_e or M_ENC7_s <= time_to_be_detected <= M_ENC7_e or M_ENC8_s <= time_to_be_detected <= M_ENC8_e or M_ENC9_s <= time_to_be_detected <= M_ENC9_e:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e:
            #print("True Positive")
            confusion_matrix.append("TP")            
        else:
            #print("False Positive")
            confusion_matrix.append("FP")
    else:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e:
            #print("False Negative")
            confusion_matrix.append("FN")
        else:
            #print("True Negative")
            confusion_matrix.append("TN")    
           
    
    time_to_be_detected = time_to_be_detected + delta
    
confusion_matrix = pd.DataFrame(confusion_matrix, columns = ['confusion_matrix'])
prop_norm_off = confusion_matrix['confusion_matrix'].value_counts(normalize=False).to_string()#change normalize to true
#print("Confusion Matrix")
#print(prop_norm_off)
prop_norm_on = confusion_matrix['confusion_matrix'].value_counts(normalize=True).to_string()#change normalize to true
print("Model testing 90 dpi 2s x Human Detector all SNR")
print()
print("Normalized Confusion Matrix")
print(prop_norm_on)

TN = int(confusion_matrix['confusion_matrix'].value_counts()['TN'])
FN = int(confusion_matrix['confusion_matrix'].value_counts()['FN'])
TP = int(confusion_matrix['confusion_matrix'].value_counts()['TP'])
FP = int(confusion_matrix['confusion_matrix'].value_counts()['FP'])
specificity = TN/(TN + FP)
sensitivity = TP/(FN+TP)
accuracy = (TP+TN)/(TP+TN+FP+FN)
precision = TP/(TP+FP)
print('Specificity:', specificity)
print('Sensitivity:', sensitivity)
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Model testing 90 dpi 2s x Human Detector all SNR
#
# Normalized Confusion Matrix
# TN    0.694236
# FN    0.221667
# TP    0.082627
# FP    0.001470
# Specificity: 0.9978871716381906
# Sensitivity: 0.27153778859685823
# Accuracy: 0.7768634259259259
# Precision: 0.9825213322323149

# %%
#100 dpi 2s all SNR
import pandas as pd
import datetime
time = "2021-3-21 00:00:00.00"
#real_start_time = datetime.fromisoformat(time)
time_actual = datetime.datetime.strptime(time, "%Y-%m-%d %H:%M:%S.%f")
delta = delta = datetime.timedelta(seconds=1)
#print(time_actual)
time_to_be_detected = time_actual
#Human detector encounters SNR >=1
H_ENC1_s = datetime.datetime.strptime("2021-03-21 00:58:22.938328", "%Y-%m-%d %H:%M:%S.%f")
H_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:03:39.952157", "%Y-%m-%d %H:%M:%S.%f")

H_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:31.935836", "%Y-%m-%d %H:%M:%S.%f")
H_ENC2_e=  datetime.datetime.strptime("2021-03-21 04:21:59.049616", "%Y-%m-%d %H:%M:%S.%f")

H_ENC3_s = datetime.datetime.strptime("2021-03-21 04:53:49.078051", "%Y-%m-%d %H:%M:%S.%f")
H_ENC3_e=  datetime.datetime.strptime("2021-03-21 06:49:34.904194", "%Y-%m-%d %H:%M:%S.%f")

H_ENC4_s = datetime.datetime.strptime("2021-03-21 07:24:18.985777", "%Y-%m-%d %H:%M:%S.%f")
H_ENC4_e=  datetime.datetime.strptime("2021-03-21 07:39:28.855199", "%Y-%m-%d %H:%M:%S.%f")

H_ENC5_s = datetime.datetime.strptime("2021-03-21 12:11:50.374341", "%Y-%m-%d %H:%M:%S.%f")
H_ENC5_e=  datetime.datetime.strptime("2021-03-21 12:22:31.117159", "%Y-%m-%d %H:%M:%S.%f")

H_ENC6_s = datetime.datetime.strptime("2021-03-21 12:37:42.023821", "%Y-%m-%d %H:%M:%S.%f")
H_ENC6_e=  datetime.datetime.strptime("2021-03-21 13:06:38.879766", "%Y-%m-%d %H:%M:%S.%f")

H_ENC7_s = datetime.datetime.strptime("2021-03-21 13:22:59.004893", "%Y-%m-%d %H:%M:%S.%f")
H_ENC7_e=  datetime.datetime.strptime("2021-03-21 14:23:26.628424", "%Y-%m-%d %H:%M:%S.%f")

H_ENC8_s = datetime.datetime.strptime("2021-03-21 14:23:35.936122", "%Y-%m-%d %H:%M:%S.%f")
H_ENC8_e=  datetime.datetime.strptime("2021-03-21 15:03:31.143575", "%Y-%m-%d %H:%M:%S.%f")

H_ENC9_s = datetime.datetime.strptime("2021-03-21 18:46:23.912812", "%Y-%m-%d %H:%M:%S.%f")
H_ENC9_e=  datetime.datetime.strptime("2021-03-21 19:30:46.765953", "%Y-%m-%d %H:%M:%S.%f")

H_ENC10_s = datetime.datetime.strptime("2021-03-21 20:15:33.222835", "%Y-%m-%d %H:%M:%S.%f")
H_ENC10_e=  datetime.datetime.strptime("2021-03-21 20:15:42.360361", "%Y-%m-%d %H:%M:%S.%f")

H_ENC11_s = datetime.datetime.strptime("2021-03-21 20:36:44.460596", "%Y-%m-%d %H:%M:%S.%f")
H_ENC11_e=  datetime.datetime.strptime("2021-03-21 20:50:40.901156", "%Y-%m-%d %H:%M:%S.%f")

H_ENC12_s = datetime.datetime.strptime("2021-03-21 21:16:07.103957", "%Y-%m-%d %H:%M:%S.%f")
H_ENC12_e=  datetime.datetime.strptime("2021-03-21 21:48:59.425626", "%Y-%m-%d %H:%M:%S.%f")

H_ENC13_s = datetime.datetime.strptime("2021-03-21 22:30:54.162231", "%Y-%m-%d %H:%M:%S.%f")
H_ENC13_e=  datetime.datetime.strptime("2021-03-21 22:36:18.208851", "%Y-%m-%d %H:%M:%S.%f")

H_ENC14_s = datetime.datetime.strptime("2021-03-21 22:52:18.849871", "%Y-%m-%d %H:%M:%S.%f")
H_ENC14_e=  datetime.datetime.strptime("2021-03-21 22:52:44.870850", "%Y-%m-%d %H:%M:%S.%f")

H_ENC15_s = datetime.datetime.strptime("2021-03-21 23:26:16.257801", "%Y-%m-%d %H:%M:%S.%f")
H_ENC15_e=  datetime.datetime.strptime("2021-03-21 23:26:36.607445", "%Y-%m-%d %H:%M:%S.%f")

H_ENC16_s = datetime.datetime.strptime("2021-03-21 23:57:45.979014", "%Y-%m-%d %H:%M:%S.%f")
H_ENC16_e=  datetime.datetime.strptime("2021-03-21 23:57:46.724934", "%Y-%m-%d %H:%M:%S.%f")
#Model testing 70 dpi 2s

M_ENC1_s = datetime.datetime.strptime("2021-03-21 01:00:23", "%Y-%m-%d %H:%M:%S")
M_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:00:52", "%Y-%m-%d %H:%M:%S")

M_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:30", "%Y-%m-%d %H:%M:%S")
M_ENC2_e=  datetime.datetime.strptime("2021-03-21 03:28:58", "%Y-%m-%d %H:%M:%S")

M_ENC3_s = datetime.datetime.strptime("2021-03-21 05:39:13", "%Y-%m-%d %H:%M:%S")
M_ENC3_e=  datetime.datetime.strptime("2021-03-21 05:39:14", "%Y-%m-%d %H:%M:%S")

M_ENC4_s = datetime.datetime.strptime("2021-03-21 09:46:52", "%Y-%m-%d %H:%M:%S")
M_ENC4_e=  datetime.datetime.strptime("2021-03-21 09:47:09", "%Y-%m-%d %H:%M:%S")

M_ENC5_s = datetime.datetime.strptime("2021-03-21 12:08:22", "%Y-%m-%d %H:%M:%S")
M_ENC5_e=  datetime.datetime.strptime("2021-03-21 12:08:25", "%Y-%m-%d %H:%M:%S")

M_ENC6_s = datetime.datetime.strptime("2021-03-21 12:37:38", "%Y-%m-%d %H:%M:%S")
M_ENC6_e=  datetime.datetime.strptime("2021-03-21 12:51:23", "%Y-%m-%d %H:%M:%S")

M_ENC7_s = datetime.datetime.strptime("2021-03-21 13:27:31", "%Y-%m-%d %H:%M:%S")
M_ENC7_e=  datetime.datetime.strptime("2021-03-21 15:02:52", "%Y-%m-%d %H:%M:%S")

M_ENC8_s = datetime.datetime.strptime("2021-03-21 15:32:26", "%Y-%m-%d %H:%M:%S")
M_ENC8_e=  datetime.datetime.strptime("2021-03-21 15:32:36", "%Y-%m-%d %H:%M:%S")

M_ENC9_s = datetime.datetime.strptime("2021-03-21 18:48:31", "%Y-%m-%d %H:%M:%S")
M_ENC9_e=  datetime.datetime.strptime("2021-03-21 18:50:26", "%Y-%m-%d %H:%M:%S")

M_ENC10_s = datetime.datetime.strptime("2021-03-21 19:05:46", "%Y-%m-%d %H:%M:%S")
M_ENC10_e=  datetime.datetime.strptime("2021-03-21 19:27:26", "%Y-%m-%d %H:%M:%S")

M_ENC11_s = datetime.datetime.strptime("2021-03-21 20:19:48", "%Y-%m-%d %H:%M:%S")
M_ENC11_e=  datetime.datetime.strptime("2021-03-21 20:50:45", "%Y-%m-%d %H:%M:%S")

M_ENC12_s = datetime.datetime.strptime("2021-03-21 21:16:39", "%Y-%m-%d %H:%M:%S")
M_ENC12_e=  datetime.datetime.strptime("2021-03-21 22:08:31", "%Y-%m-%d %H:%M:%S")

M_ENC13_s = datetime.datetime.strptime("2021-03-21 22:31:51", "%Y-%m-%d %H:%M:%S")
M_ENC13_e=  datetime.datetime.strptime("2021-03-21 22:36:09", "%Y-%m-%d %H:%M:%S")

M_ENC14_s = datetime.datetime.strptime("2021-03-21 23:47:35", "%Y-%m-%d %H:%M:%S")
M_ENC14_e=  datetime.datetime.strptime("2021-03-21 23:57:40", "%Y-%m-%d %H:%M:%S")



confusion_matrix = []
for i in range(86400):
    #print(time_to_be_detected)
    
    if M_ENC1_s <= time_to_be_detected <= M_ENC1_e or M_ENC2_s <= time_to_be_detected <= M_ENC2_e or M_ENC3_s <= time_to_be_detected <= M_ENC3_e or M_ENC4_s <= time_to_be_detected <= M_ENC4_e or M_ENC5_s <= time_to_be_detected <= M_ENC5_e or M_ENC6_s <= time_to_be_detected <= M_ENC6_e or M_ENC7_s <= time_to_be_detected <= M_ENC7_e or M_ENC8_s <= time_to_be_detected <= M_ENC8_e or M_ENC9_s <= time_to_be_detected <= M_ENC9_e or M_ENC10_s <= time_to_be_detected <= M_ENC10_e or M_ENC11_s <= time_to_be_detected <= M_ENC11_e or M_ENC12_s <= time_to_be_detected <= M_ENC12_e or M_ENC13_s <= time_to_be_detected <= M_ENC13_e or M_ENC14_s <= time_to_be_detected <= M_ENC14_e:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e:
            #print("True Positive")
            confusion_matrix.append("TP")            
        else:
            #print("False Positive")
            confusion_matrix.append("FP")
    else:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e:
            #print("False Negative")
            confusion_matrix.append("FN")
        else:
            #print("True Negative")
            confusion_matrix.append("TN")    
           
    
    time_to_be_detected = time_to_be_detected + delta
    
confusion_matrix = pd.DataFrame(confusion_matrix, columns = ['confusion_matrix'])
prop_norm_off = confusion_matrix['confusion_matrix'].value_counts(normalize=False).to_string()#change normalize to true
#print("Confusion Matrix")
#print(prop_norm_off)
prop_norm_on = confusion_matrix['confusion_matrix'].value_counts(normalize=True).to_string()#change normalize to true
print("Model testing 100 dpi 2s x Human Detector all SNR")
print()
print("Normalized Confusion Matrix")
print(prop_norm_on)

TN = int(confusion_matrix['confusion_matrix'].value_counts()['TN'])
FN = int(confusion_matrix['confusion_matrix'].value_counts()['FN'])
TP = int(confusion_matrix['confusion_matrix'].value_counts()['TP'])
FP = int(confusion_matrix['confusion_matrix'].value_counts()['FP'])
specificity = TN/(TN + FP)
sensitivity = TP/(FN+TP)
accuracy = (TP+TN)/(TP+TN+FP+FN)
precision = TP/(TP+FP)
print('Specificity:', specificity)
print('Sensitivity:', sensitivity)
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Model testing 100 dpi 2s x Human Detector all SNR
#
# Normalized Confusion Matrix
# TN    0.662731
# FN    0.168808
# TP    0.135486
# FP    0.032975
# Specificity: 0.9526027716315361
# Sensitivity: 0.44524742307253434
# Accuracy: 0.7982175925925926
# Precision: 0.8042597045688766

# %%
#40 dpi 3s all SNR
import pandas as pd
import datetime
time = "2021-3-21 00:00:00.00"
#real_start_time = datetime.fromisoformat(time)
time_actual = datetime.datetime.strptime(time, "%Y-%m-%d %H:%M:%S.%f")
delta = delta = datetime.timedelta(seconds=1)
#print(time_actual)
time_to_be_detected = time_actual
#Human detector encounters SNR >=1
H_ENC1_s = datetime.datetime.strptime("2021-03-21 00:58:22.938328", "%Y-%m-%d %H:%M:%S.%f")
H_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:03:39.952157", "%Y-%m-%d %H:%M:%S.%f")

H_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:31.935836", "%Y-%m-%d %H:%M:%S.%f")
H_ENC2_e=  datetime.datetime.strptime("2021-03-21 04:21:59.049616", "%Y-%m-%d %H:%M:%S.%f")

H_ENC3_s = datetime.datetime.strptime("2021-03-21 04:53:49.078051", "%Y-%m-%d %H:%M:%S.%f")
H_ENC3_e=  datetime.datetime.strptime("2021-03-21 06:49:34.904194", "%Y-%m-%d %H:%M:%S.%f")

H_ENC4_s = datetime.datetime.strptime("2021-03-21 07:24:18.985777", "%Y-%m-%d %H:%M:%S.%f")
H_ENC4_e=  datetime.datetime.strptime("2021-03-21 07:39:28.855199", "%Y-%m-%d %H:%M:%S.%f")

H_ENC5_s = datetime.datetime.strptime("2021-03-21 12:11:50.374341", "%Y-%m-%d %H:%M:%S.%f")
H_ENC5_e=  datetime.datetime.strptime("2021-03-21 12:22:31.117159", "%Y-%m-%d %H:%M:%S.%f")

H_ENC6_s = datetime.datetime.strptime("2021-03-21 12:37:42.023821", "%Y-%m-%d %H:%M:%S.%f")
H_ENC6_e=  datetime.datetime.strptime("2021-03-21 13:06:38.879766", "%Y-%m-%d %H:%M:%S.%f")

H_ENC7_s = datetime.datetime.strptime("2021-03-21 13:22:59.004893", "%Y-%m-%d %H:%M:%S.%f")
H_ENC7_e=  datetime.datetime.strptime("2021-03-21 14:23:26.628424", "%Y-%m-%d %H:%M:%S.%f")

H_ENC8_s = datetime.datetime.strptime("2021-03-21 14:23:35.936122", "%Y-%m-%d %H:%M:%S.%f")
H_ENC8_e=  datetime.datetime.strptime("2021-03-21 15:03:31.143575", "%Y-%m-%d %H:%M:%S.%f")

H_ENC9_s = datetime.datetime.strptime("2021-03-21 18:46:23.912812", "%Y-%m-%d %H:%M:%S.%f")
H_ENC9_e=  datetime.datetime.strptime("2021-03-21 19:30:46.765953", "%Y-%m-%d %H:%M:%S.%f")

H_ENC10_s = datetime.datetime.strptime("2021-03-21 20:15:33.222835", "%Y-%m-%d %H:%M:%S.%f")
H_ENC10_e=  datetime.datetime.strptime("2021-03-21 20:15:42.360361", "%Y-%m-%d %H:%M:%S.%f")

H_ENC11_s = datetime.datetime.strptime("2021-03-21 20:36:44.460596", "%Y-%m-%d %H:%M:%S.%f")
H_ENC11_e=  datetime.datetime.strptime("2021-03-21 20:50:40.901156", "%Y-%m-%d %H:%M:%S.%f")

H_ENC12_s = datetime.datetime.strptime("2021-03-21 21:16:07.103957", "%Y-%m-%d %H:%M:%S.%f")
H_ENC12_e=  datetime.datetime.strptime("2021-03-21 21:48:59.425626", "%Y-%m-%d %H:%M:%S.%f")

H_ENC13_s = datetime.datetime.strptime("2021-03-21 22:30:54.162231", "%Y-%m-%d %H:%M:%S.%f")
H_ENC13_e=  datetime.datetime.strptime("2021-03-21 22:36:18.208851", "%Y-%m-%d %H:%M:%S.%f")

H_ENC14_s = datetime.datetime.strptime("2021-03-21 22:52:18.849871", "%Y-%m-%d %H:%M:%S.%f")
H_ENC14_e=  datetime.datetime.strptime("2021-03-21 22:52:44.870850", "%Y-%m-%d %H:%M:%S.%f")

H_ENC15_s = datetime.datetime.strptime("2021-03-21 23:26:16.257801", "%Y-%m-%d %H:%M:%S.%f")
H_ENC15_e=  datetime.datetime.strptime("2021-03-21 23:26:36.607445", "%Y-%m-%d %H:%M:%S.%f")

H_ENC16_s = datetime.datetime.strptime("2021-03-21 23:57:45.979014", "%Y-%m-%d %H:%M:%S.%f")
H_ENC16_e=  datetime.datetime.strptime("2021-03-21 23:57:46.724934", "%Y-%m-%d %H:%M:%S.%f")
#Model testing 

M_ENC1_s = datetime.datetime.strptime("2021-03-21 09:46:50", "%Y-%m-%d %H:%M:%S")
M_ENC1_e=  datetime.datetime.strptime("2021-03-21 09:47:09", "%Y-%m-%d %H:%M:%S")

M_ENC2_s = datetime.datetime.strptime("2021-03-21 10:21:12", "%Y-%m-%d %H:%M:%S")
M_ENC2_e=  datetime.datetime.strptime("2021-03-21 10:22:34", "%Y-%m-%d %H:%M:%S")

M_ENC3_s = datetime.datetime.strptime("2021-03-21 12:07:27", "%Y-%m-%d %H:%M:%S")
M_ENC3_e=  datetime.datetime.strptime("2021-03-21 12:08:30", "%Y-%m-%d %H:%M:%S")

M_ENC4_s = datetime.datetime.strptime("2021-03-21 13:27:31", "%Y-%m-%d %H:%M:%S")
M_ENC4_e=  datetime.datetime.strptime("2021-03-21 14:48:24", "%Y-%m-%d %H:%M:%S")

M_ENC5_s = datetime.datetime.strptime("2021-03-21 15:32:25", "%Y-%m-%d %H:%M:%S")
M_ENC5_e=  datetime.datetime.strptime("2021-03-21 15:32:36", "%Y-%m-%d %H:%M:%S")

M_ENC6_s = datetime.datetime.strptime("2021-03-21 18:45:15", "%Y-%m-%d %H:%M:%S")
M_ENC6_e=  datetime.datetime.strptime("2021-03-21 19:27:35", "%Y-%m-%d %H:%M:%S")

M_ENC7_s = datetime.datetime.strptime("2021-03-21 20:04:35", "%Y-%m-%d %H:%M:%S")
M_ENC7_e=  datetime.datetime.strptime("2021-03-21 20:16:38", "%Y-%m-%d %H:%M:%S")

M_ENC8_s = datetime.datetime.strptime("2021-03-21 20:32:56", "%Y-%m-%d %H:%M:%S")
M_ENC8_e=  datetime.datetime.strptime("2021-03-21 20:53:00", "%Y-%m-%d %H:%M:%S")

M_ENC9_s = datetime.datetime.strptime("2021-03-21 21:13:25", "%Y-%m-%d %H:%M:%S")
M_ENC9_e=  datetime.datetime.strptime("2021-03-21 22:08:31", "%Y-%m-%d %H:%M:%S")

M_ENC10_s = datetime.datetime.strptime("2021-03-21 22:24:45", "%Y-%m-%d %H:%M:%S")
M_ENC10_e=  datetime.datetime.strptime("2021-03-21 22:36:09", "%Y-%m-%d %H:%M:%S")




confusion_matrix = []
for i in range(86400):
    #print(time_to_be_detected)
    
    if M_ENC1_s <= time_to_be_detected <= M_ENC1_e or M_ENC2_s <= time_to_be_detected <= M_ENC2_e or M_ENC3_s <= time_to_be_detected <= M_ENC3_e or M_ENC4_s <= time_to_be_detected <= M_ENC4_e or M_ENC5_s <= time_to_be_detected <= M_ENC5_e or M_ENC6_s <= time_to_be_detected <= M_ENC6_e or M_ENC7_s <= time_to_be_detected <= M_ENC7_e or M_ENC8_s <= time_to_be_detected <= M_ENC8_e or M_ENC9_s <= time_to_be_detected <= M_ENC9_e or M_ENC10_s <= time_to_be_detected <= M_ENC10_e:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e:
            #print("True Positive")
            confusion_matrix.append("TP")            
        else:
            #print("False Positive")
            confusion_matrix.append("FP")
    else:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e:
            #print("False Negative")
            confusion_matrix.append("FN")
        else:
            #print("True Negative")
            confusion_matrix.append("TN")    
           
    
    time_to_be_detected = time_to_be_detected + delta
    
confusion_matrix = pd.DataFrame(confusion_matrix, columns = ['confusion_matrix'])
prop_norm_off = confusion_matrix['confusion_matrix'].value_counts(normalize=False).to_string()#change normalize to true
#print("Confusion Matrix")
#print(prop_norm_off)
prop_norm_on = confusion_matrix['confusion_matrix'].value_counts(normalize=True).to_string()#change normalize to true
print("Model testing 40 dpi 3s x Human Detector all SNR")
print()
print("Normalized Confusion Matrix")
print(prop_norm_on)

TN = int(confusion_matrix['confusion_matrix'].value_counts()['TN'])
FN = int(confusion_matrix['confusion_matrix'].value_counts()['FN'])
TP = int(confusion_matrix['confusion_matrix'].value_counts()['TP'])
FP = int(confusion_matrix['confusion_matrix'].value_counts()['FP'])
specificity = TN/(TN + FP)
sensitivity = TP/(FN+TP)
accuracy = (TP+TN)/(TP+TN+FP+FN)
precision = TP/(TP+FP)
print('Specificity:', specificity)
print('Sensitivity:', sensitivity)
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Model testing 40 dpi 3s x Human Detector all SNR
#
# Normalized Confusion Matrix
# TN    0.660451
# FN    0.183356
# TP    0.120938
# FP    0.035255
# Specificity: 0.9493253922041625
# Sensitivity: 0.3974363850747404
# Accuracy: 0.7813888888888889
# Precision: 0.7742867728788441

# %%
#40 dpi 7s all SNR
import pandas as pd
import datetime
time = "2021-3-21 00:00:00.00"
#real_start_time = datetime.fromisoformat(time)
time_actual = datetime.datetime.strptime(time, "%Y-%m-%d %H:%M:%S.%f")
delta = delta = datetime.timedelta(seconds=1)
#print(time_actual)
time_to_be_detected = time_actual
#Human detector encounters SNR >=1
H_ENC1_s = datetime.datetime.strptime("2021-03-21 00:58:22.938328", "%Y-%m-%d %H:%M:%S.%f")
H_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:03:39.952157", "%Y-%m-%d %H:%M:%S.%f")

H_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:31.935836", "%Y-%m-%d %H:%M:%S.%f")
H_ENC2_e=  datetime.datetime.strptime("2021-03-21 04:21:59.049616", "%Y-%m-%d %H:%M:%S.%f")

H_ENC3_s = datetime.datetime.strptime("2021-03-21 04:53:49.078051", "%Y-%m-%d %H:%M:%S.%f")
H_ENC3_e=  datetime.datetime.strptime("2021-03-21 06:49:34.904194", "%Y-%m-%d %H:%M:%S.%f")

H_ENC4_s = datetime.datetime.strptime("2021-03-21 07:24:18.985777", "%Y-%m-%d %H:%M:%S.%f")
H_ENC4_e=  datetime.datetime.strptime("2021-03-21 07:39:28.855199", "%Y-%m-%d %H:%M:%S.%f")

H_ENC5_s = datetime.datetime.strptime("2021-03-21 12:11:50.374341", "%Y-%m-%d %H:%M:%S.%f")
H_ENC5_e=  datetime.datetime.strptime("2021-03-21 12:22:31.117159", "%Y-%m-%d %H:%M:%S.%f")

H_ENC6_s = datetime.datetime.strptime("2021-03-21 12:37:42.023821", "%Y-%m-%d %H:%M:%S.%f")
H_ENC6_e=  datetime.datetime.strptime("2021-03-21 13:06:38.879766", "%Y-%m-%d %H:%M:%S.%f")

H_ENC7_s = datetime.datetime.strptime("2021-03-21 13:22:59.004893", "%Y-%m-%d %H:%M:%S.%f")
H_ENC7_e=  datetime.datetime.strptime("2021-03-21 14:23:26.628424", "%Y-%m-%d %H:%M:%S.%f")

H_ENC8_s = datetime.datetime.strptime("2021-03-21 14:23:35.936122", "%Y-%m-%d %H:%M:%S.%f")
H_ENC8_e=  datetime.datetime.strptime("2021-03-21 15:03:31.143575", "%Y-%m-%d %H:%M:%S.%f")

H_ENC9_s = datetime.datetime.strptime("2021-03-21 18:46:23.912812", "%Y-%m-%d %H:%M:%S.%f")
H_ENC9_e=  datetime.datetime.strptime("2021-03-21 19:30:46.765953", "%Y-%m-%d %H:%M:%S.%f")

H_ENC10_s = datetime.datetime.strptime("2021-03-21 20:15:33.222835", "%Y-%m-%d %H:%M:%S.%f")
H_ENC10_e=  datetime.datetime.strptime("2021-03-21 20:15:42.360361", "%Y-%m-%d %H:%M:%S.%f")

H_ENC11_s = datetime.datetime.strptime("2021-03-21 20:36:44.460596", "%Y-%m-%d %H:%M:%S.%f")
H_ENC11_e=  datetime.datetime.strptime("2021-03-21 20:50:40.901156", "%Y-%m-%d %H:%M:%S.%f")

H_ENC12_s = datetime.datetime.strptime("2021-03-21 21:16:07.103957", "%Y-%m-%d %H:%M:%S.%f")
H_ENC12_e=  datetime.datetime.strptime("2021-03-21 21:48:59.425626", "%Y-%m-%d %H:%M:%S.%f")

H_ENC13_s = datetime.datetime.strptime("2021-03-21 22:30:54.162231", "%Y-%m-%d %H:%M:%S.%f")
H_ENC13_e=  datetime.datetime.strptime("2021-03-21 22:36:18.208851", "%Y-%m-%d %H:%M:%S.%f")

H_ENC14_s = datetime.datetime.strptime("2021-03-21 22:52:18.849871", "%Y-%m-%d %H:%M:%S.%f")
H_ENC14_e=  datetime.datetime.strptime("2021-03-21 22:52:44.870850", "%Y-%m-%d %H:%M:%S.%f")

H_ENC15_s = datetime.datetime.strptime("2021-03-21 23:26:16.257801", "%Y-%m-%d %H:%M:%S.%f")
H_ENC15_e=  datetime.datetime.strptime("2021-03-21 23:26:36.607445", "%Y-%m-%d %H:%M:%S.%f")

H_ENC16_s = datetime.datetime.strptime("2021-03-21 23:57:45.979014", "%Y-%m-%d %H:%M:%S.%f")
H_ENC16_e=  datetime.datetime.strptime("2021-03-21 23:57:46.724934", "%Y-%m-%d %H:%M:%S.%f")
#Model testing 

M_ENC1_s = datetime.datetime.strptime("2021-03-21 01:11:06", "%Y-%m-%d %H:%M:%S")
M_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:11:12", "%Y-%m-%d %H:%M:%S")

M_ENC2_s = datetime.datetime.strptime("2021-03-21 05:17:31", "%Y-%m-%d %H:%M:%S")
M_ENC2_e=  datetime.datetime.strptime("2021-03-21 05:17:37", "%Y-%m-%d %H:%M:%S")

M_ENC3_s = datetime.datetime.strptime("2021-03-21 05:39:00", "%Y-%m-%d %H:%M:%S")
M_ENC3_e=  datetime.datetime.strptime("2021-03-21 05:39:14", "%Y-%m-%d %H:%M:%S")

M_ENC4_s = datetime.datetime.strptime("2021-03-21 07:00:42", "%Y-%m-%d %H:%M:%S")
M_ENC4_e=  datetime.datetime.strptime("2021-03-21 07:05:33", "%Y-%m-%d %H:%M:%S")

M_ENC5_s = datetime.datetime.strptime("2021-03-21 07:38:27", "%Y-%m-%d %H:%M:%S")
M_ENC5_e=  datetime.datetime.strptime("2021-03-21 07:38:33", "%Y-%m-%d %H:%M:%S")

M_ENC6_s = datetime.datetime.strptime("2021-03-21 09:46:46", "%Y-%m-%d %H:%M:%S")
M_ENC6_e=  datetime.datetime.strptime("2021-03-21 09:47:09", "%Y-%m-%d %H:%M:%S")

M_ENC7_s = datetime.datetime.strptime("2021-03-21 12:08:08", "%Y-%m-%d %H:%M:%S")
M_ENC7_e=  datetime.datetime.strptime("2021-03-21 12:08:30", "%Y-%m-%d %H:%M:%S")

M_ENC8_s = datetime.datetime.strptime("2021-03-21 14:40:44", "%Y-%m-%d %H:%M:%S")
M_ENC8_e=  datetime.datetime.strptime("2021-03-21 14:48:22", "%Y-%m-%d %H:%M:%S")

M_ENC9_s = datetime.datetime.strptime("2021-03-21 15:32:13", "%Y-%m-%d %H:%M:%S")
M_ENC9_e=  datetime.datetime.strptime("2021-03-21 15:49:42", "%Y-%m-%d %H:%M:%S")

M_ENC10_s = datetime.datetime.strptime("2021-03-21 16:36:13", "%Y-%m-%d %H:%M:%S")
M_ENC10_e=  datetime.datetime.strptime("2021-03-21 16:36:42", "%Y-%m-%d %H:%M:%S")

M_ENC11_s = datetime.datetime.strptime("2021-03-21 18:45:16", "%Y-%m-%d %H:%M:%S")
M_ENC11_e=  datetime.datetime.strptime("2021-03-21 18:50:21", "%Y-%m-%d %H:%M:%S")

M_ENC12_s = datetime.datetime.strptime("2021-03-21 19:05:44", "%Y-%m-%d %H:%M:%S")
M_ENC12_e=  datetime.datetime.strptime("2021-03-21 19:39:17", "%Y-%m-%d %H:%M:%S")

M_ENC13_s = datetime.datetime.strptime("2021-03-21 20:47:01", "%Y-%m-%d %H:%M:%S")
M_ENC13_e=  datetime.datetime.strptime("2021-03-21 20:47:02", "%Y-%m-%d %H:%M:%S")

M_ENC14_s = datetime.datetime.strptime("2021-03-21 21:29:23", "%Y-%m-%d %H:%M:%S")
M_ENC14_e=  datetime.datetime.strptime("2021-03-21 21:52:15", "%Y-%m-%d %H:%M:%S")

M_ENC15_s = datetime.datetime.strptime("2021-03-21 22:30:38", "%Y-%m-%d %H:%M:%S")
M_ENC15_e=  datetime.datetime.strptime("2021-03-21 22:36:08", "%Y-%m-%d %H:%M:%S")

M_ENC16_s = datetime.datetime.strptime("2021-03-21 23:41:16", "%Y-%m-%d %H:%M:%S")
M_ENC16_e=  datetime.datetime.strptime("2021-03-21 23:41:19", "%Y-%m-%d %H:%M:%S")


confusion_matrix = []
for i in range(86400):
    #print(time_to_be_detected)
    
    if M_ENC1_s <= time_to_be_detected <= M_ENC1_e or M_ENC2_s <= time_to_be_detected <= M_ENC2_e or M_ENC3_s <= time_to_be_detected <= M_ENC3_e or M_ENC4_s <= time_to_be_detected <= M_ENC4_e or M_ENC5_s <= time_to_be_detected <= M_ENC5_e or M_ENC6_s <= time_to_be_detected <= M_ENC6_e or M_ENC7_s <= time_to_be_detected <= M_ENC7_e or M_ENC8_s <= time_to_be_detected <= M_ENC8_e or M_ENC9_s <= time_to_be_detected <= M_ENC9_e or M_ENC10_s <= time_to_be_detected <= M_ENC10_e or M_ENC11_s <= time_to_be_detected <= M_ENC11_e or M_ENC12_s <= time_to_be_detected <= M_ENC12_e or M_ENC13_s <= time_to_be_detected <= M_ENC13_e or M_ENC14_s <= time_to_be_detected <= M_ENC14_e or M_ENC15_s <= time_to_be_detected <= M_ENC15_e or M_ENC16_s <= time_to_be_detected <= M_ENC16_e:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e:
            #print("True Positive")
            confusion_matrix.append("TP")            
        else:
            #print("False Positive")
            confusion_matrix.append("FP")
    else:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e:
            #print("False Negative")
            confusion_matrix.append("FN")
        else:
            #print("True Negative")
            confusion_matrix.append("TN")    
           
    
    time_to_be_detected = time_to_be_detected + delta
    
confusion_matrix = pd.DataFrame(confusion_matrix, columns = ['confusion_matrix'])
prop_norm_off = confusion_matrix['confusion_matrix'].value_counts(normalize=False).to_string()#change normalize to true
#print("Confusion Matrix")
#print(prop_norm_off)
prop_norm_on = confusion_matrix['confusion_matrix'].value_counts(normalize=True).to_string()#change normalize to true
print("Model testing 40 dpi 7s x Human Detector all SNR")
print()
print("Normalized Confusion Matrix")
print(prop_norm_on)

TN = int(confusion_matrix['confusion_matrix'].value_counts()['TN'])
FN = int(confusion_matrix['confusion_matrix'].value_counts()['FN'])
TP = int(confusion_matrix['confusion_matrix'].value_counts()['TP'])
FP = int(confusion_matrix['confusion_matrix'].value_counts()['FP'])
specificity = TN/(TN + FP)
sensitivity = TP/(FN+TP)
accuracy = (TP+TN)/(TP+TN+FP+FN)
precision = TP/(TP+FP)
print('Specificity:', specificity)
print('Sensitivity:', sensitivity)
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Model testing 40 dpi 7s x Human Detector all SNR
#
# Normalized Confusion Matrix
# TN    0.669988
# FN    0.261215
# TP    0.043079
# FP    0.025718
# Specificity: 0.9630338218902328
# Sensitivity: 0.1415693583355521
# Accuracy: 0.7130671296296296
# Precision: 0.6261776581426649

# %%
import pandas as pd
import datetime
time = "2021-3-21 00:00:00.00"
#real_start_time = datetime.fromisoformat(time)
time_actual = datetime.datetime.strptime(time, "%Y-%m-%d %H:%M:%S.%f")
delta = delta = datetime.timedelta(seconds=1)
#print(time_actual)
time_to_be_detected = time_actual
#Human detector encounters SNR >=1
H_ENC1_s = datetime.datetime.strptime("2021-03-21 00:58:22.938328", "%Y-%m-%d %H:%M:%S.%f")
H_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:03:39.952157", "%Y-%m-%d %H:%M:%S.%f")

H_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:31.935836", "%Y-%m-%d %H:%M:%S.%f")
H_ENC2_e=  datetime.datetime.strptime("2021-03-21 04:21:59.049616", "%Y-%m-%d %H:%M:%S.%f")

H_ENC3_s = datetime.datetime.strptime("2021-03-21 04:53:49.078051", "%Y-%m-%d %H:%M:%S.%f")
H_ENC3_e=  datetime.datetime.strptime("2021-03-21 06:49:34.904194", "%Y-%m-%d %H:%M:%S.%f")

H_ENC4_s = datetime.datetime.strptime("2021-03-21 07:24:18.985777", "%Y-%m-%d %H:%M:%S.%f")
H_ENC4_e=  datetime.datetime.strptime("2021-03-21 07:39:28.855199", "%Y-%m-%d %H:%M:%S.%f")

H_ENC5_s = datetime.datetime.strptime("2021-03-21 12:11:50.374341", "%Y-%m-%d %H:%M:%S.%f")
H_ENC5_e=  datetime.datetime.strptime("2021-03-21 12:22:31.117159", "%Y-%m-%d %H:%M:%S.%f")

H_ENC6_s = datetime.datetime.strptime("2021-03-21 12:37:42.023821", "%Y-%m-%d %H:%M:%S.%f")
H_ENC6_e=  datetime.datetime.strptime("2021-03-21 13:06:38.879766", "%Y-%m-%d %H:%M:%S.%f")

H_ENC7_s = datetime.datetime.strptime("2021-03-21 13:22:59.004893", "%Y-%m-%d %H:%M:%S.%f")
H_ENC7_e=  datetime.datetime.strptime("2021-03-21 14:23:26.628424", "%Y-%m-%d %H:%M:%S.%f")

H_ENC8_s = datetime.datetime.strptime("2021-03-21 14:23:35.936122", "%Y-%m-%d %H:%M:%S.%f")
H_ENC8_e=  datetime.datetime.strptime("2021-03-21 15:03:31.143575", "%Y-%m-%d %H:%M:%S.%f")

H_ENC9_s = datetime.datetime.strptime("2021-03-21 18:46:23.912812", "%Y-%m-%d %H:%M:%S.%f")
H_ENC9_e=  datetime.datetime.strptime("2021-03-21 19:30:46.765953", "%Y-%m-%d %H:%M:%S.%f")

H_ENC10_s = datetime.datetime.strptime("2021-03-21 20:15:33.222835", "%Y-%m-%d %H:%M:%S.%f")
H_ENC10_e=  datetime.datetime.strptime("2021-03-21 20:15:42.360361", "%Y-%m-%d %H:%M:%S.%f")

H_ENC11_s = datetime.datetime.strptime("2021-03-21 20:36:44.460596", "%Y-%m-%d %H:%M:%S.%f")
H_ENC11_e=  datetime.datetime.strptime("2021-03-21 20:50:40.901156", "%Y-%m-%d %H:%M:%S.%f")

H_ENC12_s = datetime.datetime.strptime("2021-03-21 21:16:07.103957", "%Y-%m-%d %H:%M:%S.%f")
H_ENC12_e=  datetime.datetime.strptime("2021-03-21 21:48:59.425626", "%Y-%m-%d %H:%M:%S.%f")

H_ENC13_s = datetime.datetime.strptime("2021-03-21 22:30:54.162231", "%Y-%m-%d %H:%M:%S.%f")
H_ENC13_e=  datetime.datetime.strptime("2021-03-21 22:36:18.208851", "%Y-%m-%d %H:%M:%S.%f")

H_ENC14_s = datetime.datetime.strptime("2021-03-21 22:52:18.849871", "%Y-%m-%d %H:%M:%S.%f")
H_ENC14_e=  datetime.datetime.strptime("2021-03-21 22:52:44.870850", "%Y-%m-%d %H:%M:%S.%f")

H_ENC15_s = datetime.datetime.strptime("2021-03-21 23:26:16.257801", "%Y-%m-%d %H:%M:%S.%f")
H_ENC15_e=  datetime.datetime.strptime("2021-03-21 23:26:36.607445", "%Y-%m-%d %H:%M:%S.%f")

H_ENC16_s = datetime.datetime.strptime("2021-03-21 23:57:45.979014", "%Y-%m-%d %H:%M:%S.%f")
H_ENC16_e=  datetime.datetime.strptime("2021-03-21 23:57:46.724934", "%Y-%m-%d %H:%M:%S.%f")
#Model testing 

M_ENC1_s = datetime.datetime.strptime("2021-03-21 00:28:14", "%Y-%m-%d %H:%M:%S")
M_ENC1_e=  datetime.datetime.strptime("2021-03-21 00:31:04", "%Y-%m-%d %H:%M:%S")

M_ENC2_s = datetime.datetime.strptime("2021-03-21 01:11:11", "%Y-%m-%d %H:%M:%S")
M_ENC2_e=  datetime.datetime.strptime("2021-03-21 01:11:12", "%Y-%m-%d %H:%M:%S")

M_ENC3_s = datetime.datetime.strptime("2021-03-21 03:22:42", "%Y-%m-%d %H:%M:%S")
M_ENC3_e=  datetime.datetime.strptime("2021-03-21 03:23:31", "%Y-%m-%d %H:%M:%S")

M_ENC4_s = datetime.datetime.strptime("2021-03-21 05:39:05", "%Y-%m-%d %H:%M:%S")
M_ENC4_e=  datetime.datetime.strptime("2021-03-21 05:39:14", "%Y-%m-%d %H:%M:%S")

M_ENC5_s = datetime.datetime.strptime("2021-03-21 07:00:47", "%Y-%m-%d %H:%M:%S")
M_ENC5_e=  datetime.datetime.strptime("2021-03-21 07:00:48", "%Y-%m-%d %H:%M:%S")

M_ENC6_s = datetime.datetime.strptime("2021-03-21 07:38:32", "%Y-%m-%d %H:%M:%S")
M_ENC6_e=  datetime.datetime.strptime("2021-03-21 07:38:33", "%Y-%m-%d %H:%M:%S")

M_ENC7_s = datetime.datetime.strptime("2021-03-21 09:46:51", "%Y-%m-%d %H:%M:%S")
M_ENC7_e=  datetime.datetime.strptime("2021-03-21 09:47:09", "%Y-%m-%d %H:%M:%S")

M_ENC8_s = datetime.datetime.strptime("2021-03-21 12:03:35", "%Y-%m-%d %H:%M:%S")
M_ENC8_e=  datetime.datetime.strptime("2021-03-21 12:07:48", "%Y-%m-%d %H:%M:%S")

M_ENC9_s = datetime.datetime.strptime("2021-03-21 14:44:59", "%Y-%m-%d %H:%M:%S")
M_ENC9_e=  datetime.datetime.strptime("2021-03-21 14:59:16", "%Y-%m-%d %H:%M:%S")

M_ENC10_s = datetime.datetime.strptime("2021-03-21 15:32:17", "%Y-%m-%d %H:%M:%S")
M_ENC10_e=  datetime.datetime.strptime("2021-03-21 15:32:36", "%Y-%m-%d %H:%M:%S")

M_ENC11_s = datetime.datetime.strptime("2021-03-21 16:36:22", "%Y-%m-%d %H:%M:%S")
M_ENC11_e=  datetime.datetime.strptime("2021-03-21 16:36:49", "%Y-%m-%d %H:%M:%S")

M_ENC12_s = datetime.datetime.strptime("2021-03-21 18:43:00", "%Y-%m-%d %H:%M:%S")
M_ENC12_e=  datetime.datetime.strptime("2021-03-21 19:28:02", "%Y-%m-%d %H:%M:%S")

M_ENC13_s = datetime.datetime.strptime("2021-03-21 20:34:34", "%Y-%m-%d %H:%M:%S")
M_ENC13_e=  datetime.datetime.strptime("2021-03-21 20:53:01", "%Y-%m-%d %H:%M:%S")

M_ENC14_s = datetime.datetime.strptime("2021-03-21 21:10:39", "%Y-%m-%d %H:%M:%S")
M_ENC14_e=  datetime.datetime.strptime("2021-03-21 22:08:32", "%Y-%m-%d %H:%M:%S")

M_ENC15_s = datetime.datetime.strptime("2021-03-21 22:24:46", "%Y-%m-%d %H:%M:%S")
M_ENC15_e=  datetime.datetime.strptime("2021-03-21 22:36:09", "%Y-%m-%d %H:%M:%S")

M_ENC16_s = datetime.datetime.strptime("2021-03-21 23:25:57", "%Y-%m-%d %H:%M:%S")
M_ENC16_e=  datetime.datetime.strptime("2021-03-21 23:37:23", "%Y-%m-%d %H:%M:%S")


confusion_matrix = []
for i in range(86400):
    #print(time_to_be_detected)
    
    if M_ENC1_s <= time_to_be_detected <= M_ENC1_e or M_ENC2_s <= time_to_be_detected <= M_ENC2_e or M_ENC3_s <= time_to_be_detected <= M_ENC3_e or M_ENC4_s <= time_to_be_detected <= M_ENC4_e or M_ENC5_s <= time_to_be_detected <= M_ENC5_e or M_ENC6_s <= time_to_be_detected <= M_ENC6_e or M_ENC7_s <= time_to_be_detected <= M_ENC7_e or M_ENC8_s <= time_to_be_detected <= M_ENC8_e or M_ENC9_s <= time_to_be_detected <= M_ENC9_e or M_ENC10_s <= time_to_be_detected <= M_ENC10_e or M_ENC11_s <= time_to_be_detected <= M_ENC11_e or M_ENC12_s <= time_to_be_detected <= M_ENC12_e or M_ENC13_s <= time_to_be_detected <= M_ENC13_e or M_ENC14_s <= time_to_be_detected <= M_ENC14_e or M_ENC15_s <= time_to_be_detected <= M_ENC15_e or M_ENC16_s <= time_to_be_detected <= M_ENC16_e:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e:
            #print("True Positive")
            confusion_matrix.append("TP")            
        else:
            #print("False Positive")
            confusion_matrix.append("FP")
    else:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e:
            #print("False Negative")
            confusion_matrix.append("FN")
        else:
            #print("True Negative")
            confusion_matrix.append("TN")    
           
    
    time_to_be_detected = time_to_be_detected + delta
    
confusion_matrix = pd.DataFrame(confusion_matrix, columns = ['confusion_matrix'])
prop_norm_off = confusion_matrix['confusion_matrix'].value_counts(normalize=False).to_string()#change normalize to true
#print("Confusion Matrix")
#print(prop_norm_off)
prop_norm_on = confusion_matrix['confusion_matrix'].value_counts(normalize=True).to_string()#change normalize to true
print("Model testing 90 dpi 2s Transfer learning x Human Detector all SNR")
print()
print("Normalized Confusion Matrix")
print(prop_norm_on)

TN = int(confusion_matrix['confusion_matrix'].value_counts()['TN'])
FN = int(confusion_matrix['confusion_matrix'].value_counts()['FN'])
TP = int(confusion_matrix['confusion_matrix'].value_counts()['TP'])
FP = int(confusion_matrix['confusion_matrix'].value_counts()['FP'])
specificity = TN/(TN + FP)
sensitivity = TP/(FN+TP)
accuracy = (TP+TN)/(TP+TN+FP+FN)
precision = TP/(TP+FP)
print('Specificity:', specificity)
print('Sensitivity:', sensitivity)
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Model testing 90 dpi 2s Transfer learning x Human Detector all SNR
#
# Normalized Confusion Matrix
# TN    0.655081
# FN    0.228345
# TP    0.075949
# FP    0.040625
# Specificity: 0.941606082283851
# Sensitivity: 0.24959111483017002
# Accuracy: 0.7310300925925926
# Precision: 0.6515091342335186

# %%
import pandas as pd
import datetime
time = "2021-3-21 00:00:00.00"
#real_start_time = datetime.fromisoformat(time)
time_actual = datetime.datetime.strptime(time, "%Y-%m-%d %H:%M:%S.%f")
delta = delta = datetime.timedelta(seconds=1)
#print(time_actual)
time_to_be_detected = time_actual
#Human detector encounters SNR >=1
H_ENC1_s = datetime.datetime.strptime("2021-03-21 00:58:22.938328", "%Y-%m-%d %H:%M:%S.%f")
H_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:03:39.952157", "%Y-%m-%d %H:%M:%S.%f")

H_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:31.935836", "%Y-%m-%d %H:%M:%S.%f")
H_ENC2_e=  datetime.datetime.strptime("2021-03-21 04:21:59.049616", "%Y-%m-%d %H:%M:%S.%f")

H_ENC3_s = datetime.datetime.strptime("2021-03-21 04:53:49.078051", "%Y-%m-%d %H:%M:%S.%f")
H_ENC3_e=  datetime.datetime.strptime("2021-03-21 06:49:34.904194", "%Y-%m-%d %H:%M:%S.%f")

H_ENC4_s = datetime.datetime.strptime("2021-03-21 07:24:18.985777", "%Y-%m-%d %H:%M:%S.%f")
H_ENC4_e=  datetime.datetime.strptime("2021-03-21 07:39:28.855199", "%Y-%m-%d %H:%M:%S.%f")

H_ENC5_s = datetime.datetime.strptime("2021-03-21 12:11:50.374341", "%Y-%m-%d %H:%M:%S.%f")
H_ENC5_e=  datetime.datetime.strptime("2021-03-21 12:22:31.117159", "%Y-%m-%d %H:%M:%S.%f")

H_ENC6_s = datetime.datetime.strptime("2021-03-21 12:37:42.023821", "%Y-%m-%d %H:%M:%S.%f")
H_ENC6_e=  datetime.datetime.strptime("2021-03-21 13:06:38.879766", "%Y-%m-%d %H:%M:%S.%f")

H_ENC7_s = datetime.datetime.strptime("2021-03-21 13:22:59.004893", "%Y-%m-%d %H:%M:%S.%f")
H_ENC7_e=  datetime.datetime.strptime("2021-03-21 14:23:26.628424", "%Y-%m-%d %H:%M:%S.%f")

H_ENC8_s = datetime.datetime.strptime("2021-03-21 14:23:35.936122", "%Y-%m-%d %H:%M:%S.%f")
H_ENC8_e=  datetime.datetime.strptime("2021-03-21 15:03:31.143575", "%Y-%m-%d %H:%M:%S.%f")

H_ENC9_s = datetime.datetime.strptime("2021-03-21 18:46:23.912812", "%Y-%m-%d %H:%M:%S.%f")
H_ENC9_e=  datetime.datetime.strptime("2021-03-21 19:30:46.765953", "%Y-%m-%d %H:%M:%S.%f")

H_ENC10_s = datetime.datetime.strptime("2021-03-21 20:15:33.222835", "%Y-%m-%d %H:%M:%S.%f")
H_ENC10_e=  datetime.datetime.strptime("2021-03-21 20:15:42.360361", "%Y-%m-%d %H:%M:%S.%f")

H_ENC11_s = datetime.datetime.strptime("2021-03-21 20:36:44.460596", "%Y-%m-%d %H:%M:%S.%f")
H_ENC11_e=  datetime.datetime.strptime("2021-03-21 20:50:40.901156", "%Y-%m-%d %H:%M:%S.%f")

H_ENC12_s = datetime.datetime.strptime("2021-03-21 21:16:07.103957", "%Y-%m-%d %H:%M:%S.%f")
H_ENC12_e=  datetime.datetime.strptime("2021-03-21 21:48:59.425626", "%Y-%m-%d %H:%M:%S.%f")

H_ENC13_s = datetime.datetime.strptime("2021-03-21 22:30:54.162231", "%Y-%m-%d %H:%M:%S.%f")
H_ENC13_e=  datetime.datetime.strptime("2021-03-21 22:36:18.208851", "%Y-%m-%d %H:%M:%S.%f")

H_ENC14_s = datetime.datetime.strptime("2021-03-21 22:52:18.849871", "%Y-%m-%d %H:%M:%S.%f")
H_ENC14_e=  datetime.datetime.strptime("2021-03-21 22:52:44.870850", "%Y-%m-%d %H:%M:%S.%f")

H_ENC15_s = datetime.datetime.strptime("2021-03-21 23:26:16.257801", "%Y-%m-%d %H:%M:%S.%f")
H_ENC15_e=  datetime.datetime.strptime("2021-03-21 23:26:36.607445", "%Y-%m-%d %H:%M:%S.%f")

H_ENC16_s = datetime.datetime.strptime("2021-03-21 23:57:45.979014", "%Y-%m-%d %H:%M:%S.%f")
H_ENC16_e=  datetime.datetime.strptime("2021-03-21 23:57:46.724934", "%Y-%m-%d %H:%M:%S.%f")
#Model testing 

M_ENC1_s = datetime.datetime.strptime("2021-03-21 05:39:04", "%Y-%m-%d %H:%M:%S")
M_ENC1_e=  datetime.datetime.strptime("2021-03-21 05:39:14", "%Y-%m-%d %H:%M:%S")

M_ENC2_s = datetime.datetime.strptime("2021-03-21 09:46:50", "%Y-%m-%d %H:%M:%S")
M_ENC2_e=  datetime.datetime.strptime("2021-03-21 09:47:09", "%Y-%m-%d %H:%M:%S")

M_ENC3_s = datetime.datetime.strptime("2021-03-21 11:52:18", "%Y-%m-%d %H:%M:%S")
M_ENC3_e=  datetime.datetime.strptime("2021-03-21 12:08:31", "%Y-%m-%d %H:%M:%S")

M_ENC4_s = datetime.datetime.strptime("2021-03-21 13:36:27", "%Y-%m-%d %H:%M:%S")
M_ENC4_e=  datetime.datetime.strptime("2021-03-21 14:17:29", "%Y-%m-%d %H:%M:%S")

M_ENC5_s = datetime.datetime.strptime("2021-03-21 14:36:14", "%Y-%m-%d %H:%M:%S")
M_ENC5_e=  datetime.datetime.strptime("2021-03-21 14:59:16", "%Y-%m-%d %H:%M:%S")

M_ENC6_s = datetime.datetime.strptime("2021-03-21 15:24:57", "%Y-%m-%d %H:%M:%S")
M_ENC6_e=  datetime.datetime.strptime("2021-03-21 15:49:45", "%Y-%m-%d %H:%M:%S")

M_ENC7_s = datetime.datetime.strptime("2021-03-21 16:36:21", "%Y-%m-%d %H:%M:%S")
M_ENC7_e=  datetime.datetime.strptime("2021-03-21 16:37:25", "%Y-%m-%d %H:%M:%S")

M_ENC8_s = datetime.datetime.strptime("2021-03-21 18:42:59", "%Y-%m-%d %H:%M:%S")
M_ENC8_e=  datetime.datetime.strptime("2021-03-21 19:46:53", "%Y-%m-%d %H:%M:%S")

M_ENC9_s = datetime.datetime.strptime("2021-03-21 20:32:56", "%Y-%m-%d %H:%M:%S")
M_ENC9_e=  datetime.datetime.strptime("2021-03-21 20:53:01", "%Y-%m-%d %H:%M:%S")

M_ENC10_s = datetime.datetime.strptime("2021-03-21 21:12:47", "%Y-%m-%d %H:%M:%S")
M_ENC10_e=  datetime.datetime.strptime("2021-03-21 22:09:07", "%Y-%m-%d %H:%M:%S")

M_ENC11_s = datetime.datetime.strptime("2021-03-21 22:24:45", "%Y-%m-%d %H:%M:%S")
M_ENC11_e=  datetime.datetime.strptime("2021-03-21 22:36:09", "%Y-%m-%d %H:%M:%S")

M_ENC12_s = datetime.datetime.strptime("2021-03-21 23:11:35", "%Y-%m-%d %H:%M:%S")
M_ENC12_e=  datetime.datetime.strptime("2021-03-21 23:37:46", "%Y-%m-%d %H:%M:%S")

confusion_matrix = []
for i in range(86400):
    #print(time_to_be_detected)
    
    if M_ENC1_s <= time_to_be_detected <= M_ENC1_e or M_ENC2_s <= time_to_be_detected <= M_ENC2_e or M_ENC3_s <= time_to_be_detected <= M_ENC3_e or M_ENC4_s <= time_to_be_detected <= M_ENC4_e or M_ENC5_s <= time_to_be_detected <= M_ENC5_e or M_ENC6_s <= time_to_be_detected <= M_ENC6_e or M_ENC7_s <= time_to_be_detected <= M_ENC7_e or M_ENC8_s <= time_to_be_detected <= M_ENC8_e or M_ENC9_s <= time_to_be_detected <= M_ENC9_e or M_ENC10_s <= time_to_be_detected <= M_ENC10_e:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e:
            #print("True Positive")
            confusion_matrix.append("TP")            
        else:
            #print("False Positive")
            confusion_matrix.append("FP")
    else:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e:
            #print("False Negative")
            confusion_matrix.append("FN")
        else:
            #print("True Negative")
            confusion_matrix.append("TN")    
           
    
    time_to_be_detected = time_to_be_detected + delta
    
confusion_matrix = pd.DataFrame(confusion_matrix, columns = ['confusion_matrix'])
prop_norm_off = confusion_matrix['confusion_matrix'].value_counts(normalize=False).to_string()#change normalize to true
#print("Confusion Matrix")
#print(prop_norm_off)
prop_norm_on = confusion_matrix['confusion_matrix'].value_counts(normalize=True).to_string()#change normalize to true
print("Model testing 40 dpi 3s Transfer learning x Human Detector all SNR")
print()
print("Normalized Confusion Matrix")
print(prop_norm_on)

TN = int(confusion_matrix['confusion_matrix'].value_counts()['TN'])
FN = int(confusion_matrix['confusion_matrix'].value_counts()['FN'])
TP = int(confusion_matrix['confusion_matrix'].value_counts()['TP'])
FP = int(confusion_matrix['confusion_matrix'].value_counts()['FP'])
specificity = TN/(TN + FP)
sensitivity = TP/(FN+TP)
accuracy = (TP+TN)/(TP+TN+FP+FN)
precision = TP/(TP+FP)
print('Specificity:', specificity)
print('Sensitivity:', sensitivity)
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Model testing 40 dpi 3s Transfer learning x Human Detector all SNR
#
# Normalized Confusion Matrix
# TN    0.632060
# FN    0.196331
# TP    0.107963
# FP    0.063646
# Specificity: 0.9085161955780332
# Sensitivity: 0.3547982199231676
# Accuracy: 0.7400231481481482
# Precision: 0.6291225467053349

# %%
import pandas as pd
import datetime
time = "2021-3-21 00:00:00.00"
#real_start_time = datetime.fromisoformat(time)
time_actual = datetime.datetime.strptime(time, "%Y-%m-%d %H:%M:%S.%f")
delta = delta = datetime.timedelta(seconds=1)
#print(time_actual)
time_to_be_detected = time_actual
#Human detector encounters SNR >=1
H_ENC1_s = datetime.datetime.strptime("2021-03-21 00:58:22.938328", "%Y-%m-%d %H:%M:%S.%f")
H_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:03:39.952157", "%Y-%m-%d %H:%M:%S.%f")

H_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:31.935836", "%Y-%m-%d %H:%M:%S.%f")
H_ENC2_e=  datetime.datetime.strptime("2021-03-21 04:21:59.049616", "%Y-%m-%d %H:%M:%S.%f")

H_ENC3_s = datetime.datetime.strptime("2021-03-21 04:53:49.078051", "%Y-%m-%d %H:%M:%S.%f")
H_ENC3_e=  datetime.datetime.strptime("2021-03-21 06:49:34.904194", "%Y-%m-%d %H:%M:%S.%f")

H_ENC4_s = datetime.datetime.strptime("2021-03-21 07:24:18.985777", "%Y-%m-%d %H:%M:%S.%f")
H_ENC4_e=  datetime.datetime.strptime("2021-03-21 07:39:28.855199", "%Y-%m-%d %H:%M:%S.%f")

H_ENC5_s = datetime.datetime.strptime("2021-03-21 12:11:50.374341", "%Y-%m-%d %H:%M:%S.%f")
H_ENC5_e=  datetime.datetime.strptime("2021-03-21 12:22:31.117159", "%Y-%m-%d %H:%M:%S.%f")

H_ENC6_s = datetime.datetime.strptime("2021-03-21 12:37:42.023821", "%Y-%m-%d %H:%M:%S.%f")
H_ENC6_e=  datetime.datetime.strptime("2021-03-21 13:06:38.879766", "%Y-%m-%d %H:%M:%S.%f")

H_ENC7_s = datetime.datetime.strptime("2021-03-21 13:22:59.004893", "%Y-%m-%d %H:%M:%S.%f")
H_ENC7_e=  datetime.datetime.strptime("2021-03-21 14:23:26.628424", "%Y-%m-%d %H:%M:%S.%f")

H_ENC8_s = datetime.datetime.strptime("2021-03-21 14:23:35.936122", "%Y-%m-%d %H:%M:%S.%f")
H_ENC8_e=  datetime.datetime.strptime("2021-03-21 15:03:31.143575", "%Y-%m-%d %H:%M:%S.%f")

H_ENC9_s = datetime.datetime.strptime("2021-03-21 18:46:23.912812", "%Y-%m-%d %H:%M:%S.%f")
H_ENC9_e=  datetime.datetime.strptime("2021-03-21 19:30:46.765953", "%Y-%m-%d %H:%M:%S.%f")

H_ENC10_s = datetime.datetime.strptime("2021-03-21 20:15:33.222835", "%Y-%m-%d %H:%M:%S.%f")
H_ENC10_e=  datetime.datetime.strptime("2021-03-21 20:15:42.360361", "%Y-%m-%d %H:%M:%S.%f")

H_ENC11_s = datetime.datetime.strptime("2021-03-21 20:36:44.460596", "%Y-%m-%d %H:%M:%S.%f")
H_ENC11_e=  datetime.datetime.strptime("2021-03-21 20:50:40.901156", "%Y-%m-%d %H:%M:%S.%f")

H_ENC12_s = datetime.datetime.strptime("2021-03-21 21:16:07.103957", "%Y-%m-%d %H:%M:%S.%f")
H_ENC12_e=  datetime.datetime.strptime("2021-03-21 21:48:59.425626", "%Y-%m-%d %H:%M:%S.%f")

H_ENC13_s = datetime.datetime.strptime("2021-03-21 22:30:54.162231", "%Y-%m-%d %H:%M:%S.%f")
H_ENC13_e=  datetime.datetime.strptime("2021-03-21 22:36:18.208851", "%Y-%m-%d %H:%M:%S.%f")

H_ENC14_s = datetime.datetime.strptime("2021-03-21 22:52:18.849871", "%Y-%m-%d %H:%M:%S.%f")
H_ENC14_e=  datetime.datetime.strptime("2021-03-21 22:52:44.870850", "%Y-%m-%d %H:%M:%S.%f")

H_ENC15_s = datetime.datetime.strptime("2021-03-21 23:26:16.257801", "%Y-%m-%d %H:%M:%S.%f")
H_ENC15_e=  datetime.datetime.strptime("2021-03-21 23:26:36.607445", "%Y-%m-%d %H:%M:%S.%f")

H_ENC16_s = datetime.datetime.strptime("2021-03-21 23:57:45.979014", "%Y-%m-%d %H:%M:%S.%f")
H_ENC16_e=  datetime.datetime.strptime("2021-03-21 23:57:46.724934", "%Y-%m-%d %H:%M:%S.%f")
#Model testing 

M_ENC1_s = datetime.datetime.strptime("2021-03-21 01:17:39.799000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:22:23", "%Y-%m-%d %H:%M:%S")

M_ENC2_s = datetime.datetime.strptime("2021-03-21 01:40:21", "%Y-%m-%d %H:%M:%S")
M_ENC2_e=  datetime.datetime.strptime("2021-03-21 01:43:01.100000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC3_s = datetime.datetime.strptime("2021-03-21 02:53:55.700000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC3_e=  datetime.datetime.strptime("2021-03-21 03:22:18.600000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC4_s = datetime.datetime.strptime("2021-03-21 03:39:45", "%Y-%m-%d %H:%M:%S")
M_ENC4_e=  datetime.datetime.strptime("2021-03-21 04:27:04", "%Y-%m-%d %H:%M:%S")

M_ENC5_s = datetime.datetime.strptime("2021-03-21 10:37:46.600000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC5_e=  datetime.datetime.strptime("2021-03-21 11:00:22.500000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC6_s = datetime.datetime.strptime("2021-03-21 11:26:46.900000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC6_e=  datetime.datetime.strptime("2021-03-21 13:02:59.500000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC7_s = datetime.datetime.strptime("2021-03-21 17:06:09", "%Y-%m-%d %H:%M:%S")
M_ENC7_e=  datetime.datetime.strptime("2021-03-21 17:14:32", "%Y-%m-%d %H:%M:%S")

M_ENC8_s = datetime.datetime.strptime("2021-03-21 20:46:29.800000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC8_e=  datetime.datetime.strptime("2021-03-21 21:12:19.600000", "%Y-%m-%d %H:%M:%S.%f")


confusion_matrix = []
for i in range(86400):
    #print(time_to_be_detected)
    
    if M_ENC1_s <= time_to_be_detected <= M_ENC1_e or M_ENC2_s <= time_to_be_detected <= M_ENC2_e or M_ENC3_s <= time_to_be_detected <= M_ENC3_e or M_ENC4_s <= time_to_be_detected <= M_ENC4_e or M_ENC5_s <= time_to_be_detected <= M_ENC5_e or M_ENC6_s <= time_to_be_detected <= M_ENC6_e or M_ENC7_s <= time_to_be_detected <= M_ENC7_e or M_ENC8_s <= time_to_be_detected <= M_ENC8_e:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e:
            #print("True Positive")
            confusion_matrix.append("TP")            
        else:
            #print("False Positive")
            confusion_matrix.append("FP")
    else:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e:
            #print("False Negative")
            confusion_matrix.append("FN")
        else:
            #print("True Negative")
            confusion_matrix.append("TN")    
           
    
    time_to_be_detected = time_to_be_detected + delta
    
confusion_matrix = pd.DataFrame(confusion_matrix, columns = ['confusion_matrix'])
prop_norm_off = confusion_matrix['confusion_matrix'].value_counts(normalize=False).to_string()#change normalize to true
#print("Confusion Matrix")
#print(prop_norm_off)
prop_norm_on = confusion_matrix['confusion_matrix'].value_counts(normalize=True).to_string()#change normalize to true
print("Model testing PAMGuard WMD x Human Detector all SNR")
print()
print("Normalized Confusion Matrix")
print(prop_norm_on)

TN = int(confusion_matrix['confusion_matrix'].value_counts()['TN'])
FN = int(confusion_matrix['confusion_matrix'].value_counts()['FN'])
TP = int(confusion_matrix['confusion_matrix'].value_counts()['TP'])
FP = int(confusion_matrix['confusion_matrix'].value_counts()['FP'])
specificity = TN/(TN + FP)
sensitivity = TP/(FN+TP)
accuracy = (TP+TN)/(TP+TN+FP+FN)
precision = TP/(TP+FP)
print('Specificity:', specificity)
print('Sensitivity:', sensitivity)
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Model testing PAMGuard WMD x Human Detector all SNR
#
# Normalized Confusion Matrix
# TN    0.592234
# FN    0.243750
# FP    0.103472
# TP    0.060544
# Specificity: 0.8512701924836547
# Sensitivity: 0.19896542543075577
# Accuracy: 0.6527777777777778
# Precision: 0.3691341472020323

# %%
#Now, SNR > 1

# %%
import pandas as pd
import datetime
time = "2021-3-21 00:00:00.00"
#real_start_time = datetime.fromisoformat(time)
time_actual = datetime.datetime.strptime(time, "%Y-%m-%d %H:%M:%S.%f")
delta = delta = datetime.timedelta(seconds=1)
#print(time_actual)
time_to_be_detected = time_actual
#Human detector encounters SNR >=1
H_ENC1_s = datetime.datetime.strptime("2021-03-21 00:58:47.486945", "%Y-%m-%d %H:%M:%S.%f")
H_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:03:14.374073", "%Y-%m-%d %H:%M:%S.%f")

H_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:31.935836", "%Y-%m-%d %H:%M:%S.%f")
H_ENC2_e=  datetime.datetime.strptime("2021-03-21 03:22:45.836374", "%Y-%m-%d %H:%M:%S.%f")

H_ENC3_s = datetime.datetime.strptime("2021-03-21 03:40:16.056164", "%Y-%m-%d %H:%M:%S.%f")
H_ENC3_e=  datetime.datetime.strptime("2021-03-21 03:51:34.742141", "%Y-%m-%d %H:%M:%S.%f")

H_ENC4_s = datetime.datetime.strptime("2021-03-21 04:53:49.078051", "%Y-%m-%d %H:%M:%S.%f")
H_ENC4_e=  datetime.datetime.strptime("2021-03-21 05:53:25.625585", "%Y-%m-%d %H:%M:%S.%f")

H_ENC5_s = datetime.datetime.strptime("2021-03-21 06:11:00.072346", "%Y-%m-%d %H:%M:%S.%f")
H_ENC5_e=  datetime.datetime.strptime("2021-03-21 06:18:05.634234", "%Y-%m-%d %H:%M:%S.%f")

H_ENC6_s = datetime.datetime.strptime("2021-03-21 06:46:53.207224", "%Y-%m-%d %H:%M:%S.%f")
H_ENC6_e=  datetime.datetime.strptime("2021-03-21 06:49:34.904194", "%Y-%m-%d %H:%M:%S.%f")

H_ENC7_s = datetime.datetime.strptime("2021-03-21 07:35:41.622116", "%Y-%m-%d %H:%M:%S.%f")
H_ENC7_e=  datetime.datetime.strptime("2021-03-21 07:36:33.988652", "%Y-%m-%d %H:%M:%S.%f")

H_ENC8_s = datetime.datetime.strptime("2021-03-21 12:13:06.729857", "%Y-%m-%d %H:%M:%S.%f")
H_ENC8_e=  datetime.datetime.strptime("2021-03-21 12:13:07.055390", "%Y-%m-%d %H:%M:%S.%f")

H_ENC9_s = datetime.datetime.strptime("2021-03-21 12:37:42.023821", "%Y-%m-%d %H:%M:%S.%f")
H_ENC9_e=  datetime.datetime.strptime("2021-03-21 13:00:17.237988", "%Y-%m-%d %H:%M:%S.%f")

H_ENC10_s = datetime.datetime.strptime("2021-03-21 13:25:28.957795", "%Y-%m-%d %H:%M:%S.%f")
H_ENC10_e=  datetime.datetime.strptime("2021-03-21 14:06:54.100459", "%Y-%m-%d %H:%M:%S.%f")

H_ENC11_s = datetime.datetime.strptime("2021-03-21 18:46:23.912812", "%Y-%m-%d %H:%M:%S.%f")
H_ENC11_e=  datetime.datetime.strptime("2021-03-21 19:30:46.765953", "%Y-%m-%d %H:%M:%S.%f")

H_ENC12_s = datetime.datetime.strptime("2021-03-21 20:15:33.222835", "%Y-%m-%d %H:%M:%S.%f")
H_ENC12_e=  datetime.datetime.strptime("2021-03-21 20:15:42.360361", "%Y-%m-%d %H:%M:%S.%f")

H_ENC13_s = datetime.datetime.strptime("2021-03-21 20:36:44.460596", "%Y-%m-%d %H:%M:%S.%f")
H_ENC13_e=  datetime.datetime.strptime("2021-03-21 20:50:40.901156", "%Y-%m-%d %H:%M:%S.%f")

H_ENC14_s = datetime.datetime.strptime("2021-03-21 21:16:07.103957", "%Y-%m-%d %H:%M:%S.%f")
H_ENC14_e=  datetime.datetime.strptime("2021-03-21 21:48:59.425626", "%Y-%m-%d %H:%M:%S.%f")

H_ENC15_s = datetime.datetime.strptime("2021-03-21 22:30:54.162231", "%Y-%m-%d %H:%M:%S.%f")
H_ENC15_e=  datetime.datetime.strptime("2021-03-21 22:36:18.208851", "%Y-%m-%d %H:%M:%S.%f")

H_ENC16_s = datetime.datetime.strptime("2021-03-21 22:52:18.849871", "%Y-%m-%d %H:%M:%S.%f")
H_ENC16_e=  datetime.datetime.strptime("2021-03-21 22:52:44.870850", "%Y-%m-%d %H:%M:%S.%f")

H_ENC17_s = datetime.datetime.strptime("2021-03-21 23:26:16.257801", "%Y-%m-%d %H:%M:%S.%f")
H_ENC17_e=  datetime.datetime.strptime("2021-03-21 23:26:36.607445", "%Y-%m-%d %H:%M:%S.%f")

H_ENC18_s = datetime.datetime.strptime("2021-03-21 23:57:45.979014", "%Y-%m-%d %H:%M:%S.%f")
H_ENC18_e=  datetime.datetime.strptime("2021-03-21 23:57:46.724934", "%Y-%m-%d %H:%M:%S.%f")

#Model testing 

M_ENC1_s = datetime.datetime.strptime("2021-03-21 01:00:52", "%Y-%m-%d %H:%M:%S")
M_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:03:13", "%Y-%m-%d %H:%M:%S")

M_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:30", "%Y-%m-%d %H:%M:%S")
M_ENC2_e=  datetime.datetime.strptime("2021-03-21 03:19:00", "%Y-%m-%d %H:%M:%S")

M_ENC3_s = datetime.datetime.strptime("2021-03-21 03:41:08", "%Y-%m-%d %H:%M:%S")
M_ENC3_e=  datetime.datetime.strptime("2021-03-21 03:41:09", "%Y-%m-%d %H:%M:%S")

M_ENC4_s = datetime.datetime.strptime("2021-03-21 04:53:47", "%Y-%m-%d %H:%M:%S")
M_ENC4_e=  datetime.datetime.strptime("2021-03-21 05:12:30", "%Y-%m-%d %H:%M:%S")

M_ENC5_s = datetime.datetime.strptime("2021-03-21 05:39:13", "%Y-%m-%d %H:%M:%S")
M_ENC5_e=  datetime.datetime.strptime("2021-03-21 05:53:23", "%Y-%m-%d %H:%M:%S")

M_ENC6_s = datetime.datetime.strptime("2021-03-21 06:16:55", "%Y-%m-%d %H:%M:%S")
M_ENC6_e=  datetime.datetime.strptime("2021-03-21 06:17:26", "%Y-%m-%d %H:%M:%S")

M_ENC7_s = datetime.datetime.strptime("2021-03-21 06:47:10", "%Y-%m-%d %H:%M:%S")
M_ENC7_e=  datetime.datetime.strptime("2021-03-21 06:47:18", "%Y-%m-%d %H:%M:%S")

M_ENC8_s = datetime.datetime.strptime("2021-03-21 09:33:41", "%Y-%m-%d %H:%M:%S")
M_ENC8_e=  datetime.datetime.strptime("2021-03-21 09:47:09", "%Y-%m-%d %H:%M:%S")

M_ENC9_s = datetime.datetime.strptime("2021-03-21 10:20:43", "%Y-%m-%d %H:%M:%S")
M_ENC9_e=  datetime.datetime.strptime("2021-03-21 10:21:59", "%Y-%m-%d %H:%M:%S")

M_ENC10_s = datetime.datetime.strptime("2021-03-21 11:51:30", "%Y-%m-%d %H:%M:%S")
M_ENC10_e=  datetime.datetime.strptime("2021-03-21 11:51:40", "%Y-%m-%d %H:%M:%S")

M_ENC11_s = datetime.datetime.strptime("2021-03-21 12:07:33", "%Y-%m-%d %H:%M:%S")
M_ENC11_e=  datetime.datetime.strptime("2021-03-21 12:08:30", "%Y-%m-%d %H:%M:%S")

M_ENC12_s = datetime.datetime.strptime("2021-03-21 12:36:30", "%Y-%m-%d %H:%M:%S")
M_ENC12_e=  datetime.datetime.strptime("2021-03-21 13:00:13", "%Y-%m-%d %H:%M:%S")

M_ENC13_s = datetime.datetime.strptime("2021-03-21 13:28:01", "%Y-%m-%d %H:%M:%S")
M_ENC13_e=  datetime.datetime.strptime("2021-03-21 15:02:53", "%Y-%m-%d %H:%M:%S")

M_ENC14_s = datetime.datetime.strptime("2021-03-21 15:32:20", "%Y-%m-%d %H:%M:%S")
M_ENC14_e=  datetime.datetime.strptime("2021-03-21 15:32:36", "%Y-%m-%d %H:%M:%S")

M_ENC15_s = datetime.datetime.strptime("2021-03-21 16:36:21", "%Y-%m-%d %H:%M:%S")
M_ENC15_e=  datetime.datetime.strptime("2021-03-21 16:36:24", "%Y-%m-%d %H:%M:%S")

M_ENC16_s = datetime.datetime.strptime("2021-03-21 18:48:23", "%Y-%m-%d %H:%M:%S")
M_ENC16_e=  datetime.datetime.strptime("2021-03-21 19:39:20", "%Y-%m-%d %H:%M:%S")

M_ENC17_s = datetime.datetime.strptime("2021-03-21 20:06:36", "%Y-%m-%d %H:%M:%S")
M_ENC17_e=  datetime.datetime.strptime("2021-03-21 20:06:37", "%Y-%m-%d %H:%M:%S")

M_ENC18_s = datetime.datetime.strptime("2021-03-21 20:36:20", "%Y-%m-%d %H:%M:%S")
M_ENC18_e=  datetime.datetime.strptime("2021-03-21 20:50:20", "%Y-%m-%d %H:%M:%S")

M_ENC19_s = datetime.datetime.strptime("2021-03-21 21:16:05", "%Y-%m-%d %H:%M:%S")
M_ENC19_e=  datetime.datetime.strptime("2021-03-21 21:53:08", "%Y-%m-%d %H:%M:%S")

M_ENC20_s = datetime.datetime.strptime("2021-03-21 22:26:46", "%Y-%m-%d %H:%M:%S")
M_ENC20_e=  datetime.datetime.strptime("2021-03-21 22:36:09", "%Y-%m-%d %H:%M:%S")

M_ENC21_s = datetime.datetime.strptime("2021-03-21 22:51:17", "%Y-%m-%d %H:%M:%S")
M_ENC21_e=  datetime.datetime.strptime("2021-03-21 22:51:18", "%Y-%m-%d %H:%M:%S")


confusion_matrix = []
for i in range(86400):
    #print(time_to_be_detected)
    
    if M_ENC1_s <= time_to_be_detected <= M_ENC1_e or M_ENC2_s <= time_to_be_detected <= M_ENC2_e or M_ENC3_s <= time_to_be_detected <= M_ENC3_e or M_ENC4_s <= time_to_be_detected <= M_ENC4_e or M_ENC5_s <= time_to_be_detected <= M_ENC5_e or M_ENC6_s <= time_to_be_detected <= M_ENC6_e or M_ENC7_s <= time_to_be_detected <= M_ENC7_e or M_ENC8_s <= time_to_be_detected <= M_ENC8_e or M_ENC9_s <= time_to_be_detected <= M_ENC9_e or M_ENC10_s <= time_to_be_detected <= M_ENC10_e or M_ENC11_s <= time_to_be_detected <= M_ENC11_e or M_ENC12_s <= time_to_be_detected <= M_ENC12_e or M_ENC13_s <= time_to_be_detected <= M_ENC13_e or M_ENC14_s <= time_to_be_detected <= M_ENC14_e or M_ENC15_s <= time_to_be_detected <= M_ENC15_e or M_ENC16_s <= time_to_be_detected <= M_ENC16_e or M_ENC17_s <= time_to_be_detected <= M_ENC17_e or M_ENC18_s <= time_to_be_detected <= M_ENC18_e or M_ENC19_s <= time_to_be_detected <= M_ENC19_e or M_ENC20_s <= time_to_be_detected <= M_ENC20_e or M_ENC21_s <= time_to_be_detected <= M_ENC21_e:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e or H_ENC17_s <= time_to_be_detected <= H_ENC17_e or H_ENC18_s <= time_to_be_detected <= H_ENC18_e:
            #print("True Positive")
            confusion_matrix.append("TP")            
        else:
            #print("False Positive")
            confusion_matrix.append("FP")
    else:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e or H_ENC17_s <= time_to_be_detected <= H_ENC17_e or H_ENC18_s <= time_to_be_detected <= H_ENC18_e:
            #print("False Negative")
            confusion_matrix.append("FN")
        else:
            #print("True Negative")
            confusion_matrix.append("TN")    
           
    
    time_to_be_detected = time_to_be_detected + delta
    
confusion_matrix = pd.DataFrame(confusion_matrix, columns = ['confusion_matrix'])
prop_norm_off = confusion_matrix['confusion_matrix'].value_counts(normalize=False).to_string()#change normalize to true
#print("Confusion Matrix")
#print(prop_norm_off)
prop_norm_on = confusion_matrix['confusion_matrix'].value_counts(normalize=True).to_string()#change normalize to true
print("Model testing 2s 70 DPI x Human Detector SNR > 1")
print()
print("Normalized Confusion Matrix")
print(prop_norm_on)

TN = int(confusion_matrix['confusion_matrix'].value_counts()['TN'])
FN = int(confusion_matrix['confusion_matrix'].value_counts()['FN'])
TP = int(confusion_matrix['confusion_matrix'].value_counts()['TP'])
FP = int(confusion_matrix['confusion_matrix'].value_counts()['FP'])
specificity = TN/(TN + FP)
sensitivity = TP/(FN+TP)
accuracy = (TP+TN)/(TP+TN+FP+FN)
precision = TP/(TP+FP)
print('Specificity:', specificity)
print('Sensitivity:', sensitivity)
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Model testing 2s 70 DPI x Human Detector SNR > 1
#
# Normalized Confusion Matrix
# TN    0.761308
# TP    0.134005
# FP    0.063160
# FN    0.041528
# Specificity: 0.923393323412977
# Sensitivity: 0.7634181722273506
# Accuracy: 0.8953125
# Precision: 0.6796595245083651

# %%
import pandas as pd
import datetime
time = "2021-3-21 00:00:00.00"
#real_start_time = datetime.fromisoformat(time)
time_actual = datetime.datetime.strptime(time, "%Y-%m-%d %H:%M:%S.%f")
delta = delta = datetime.timedelta(seconds=1)
#print(time_actual)
time_to_be_detected = time_actual
#Human detector encounters SNR >=1
H_ENC1_s = datetime.datetime.strptime("2021-03-21 00:58:47.486945", "%Y-%m-%d %H:%M:%S.%f")
H_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:03:14.374073", "%Y-%m-%d %H:%M:%S.%f")

H_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:31.935836", "%Y-%m-%d %H:%M:%S.%f")
H_ENC2_e=  datetime.datetime.strptime("2021-03-21 03:22:45.836374", "%Y-%m-%d %H:%M:%S.%f")

H_ENC3_s = datetime.datetime.strptime("2021-03-21 03:40:16.056164", "%Y-%m-%d %H:%M:%S.%f")
H_ENC3_e=  datetime.datetime.strptime("2021-03-21 03:51:34.742141", "%Y-%m-%d %H:%M:%S.%f")

H_ENC4_s = datetime.datetime.strptime("2021-03-21 04:53:49.078051", "%Y-%m-%d %H:%M:%S.%f")
H_ENC4_e=  datetime.datetime.strptime("2021-03-21 05:53:25.625585", "%Y-%m-%d %H:%M:%S.%f")

H_ENC5_s = datetime.datetime.strptime("2021-03-21 06:11:00.072346", "%Y-%m-%d %H:%M:%S.%f")
H_ENC5_e=  datetime.datetime.strptime("2021-03-21 06:18:05.634234", "%Y-%m-%d %H:%M:%S.%f")

H_ENC6_s = datetime.datetime.strptime("2021-03-21 06:46:53.207224", "%Y-%m-%d %H:%M:%S.%f")
H_ENC6_e=  datetime.datetime.strptime("2021-03-21 06:49:34.904194", "%Y-%m-%d %H:%M:%S.%f")

H_ENC7_s = datetime.datetime.strptime("2021-03-21 07:35:41.622116", "%Y-%m-%d %H:%M:%S.%f")
H_ENC7_e=  datetime.datetime.strptime("2021-03-21 07:36:33.988652", "%Y-%m-%d %H:%M:%S.%f")

H_ENC8_s = datetime.datetime.strptime("2021-03-21 12:13:06.729857", "%Y-%m-%d %H:%M:%S.%f")
H_ENC8_e=  datetime.datetime.strptime("2021-03-21 12:13:07.055390", "%Y-%m-%d %H:%M:%S.%f")

H_ENC9_s = datetime.datetime.strptime("2021-03-21 12:37:42.023821", "%Y-%m-%d %H:%M:%S.%f")
H_ENC9_e=  datetime.datetime.strptime("2021-03-21 13:00:17.237988", "%Y-%m-%d %H:%M:%S.%f")

H_ENC10_s = datetime.datetime.strptime("2021-03-21 13:25:28.957795", "%Y-%m-%d %H:%M:%S.%f")
H_ENC10_e=  datetime.datetime.strptime("2021-03-21 14:06:54.100459", "%Y-%m-%d %H:%M:%S.%f")

H_ENC11_s = datetime.datetime.strptime("2021-03-21 18:46:23.912812", "%Y-%m-%d %H:%M:%S.%f")
H_ENC11_e=  datetime.datetime.strptime("2021-03-21 19:30:46.765953", "%Y-%m-%d %H:%M:%S.%f")

H_ENC12_s = datetime.datetime.strptime("2021-03-21 20:15:33.222835", "%Y-%m-%d %H:%M:%S.%f")
H_ENC12_e=  datetime.datetime.strptime("2021-03-21 20:15:42.360361", "%Y-%m-%d %H:%M:%S.%f")

H_ENC13_s = datetime.datetime.strptime("2021-03-21 20:36:44.460596", "%Y-%m-%d %H:%M:%S.%f")
H_ENC13_e=  datetime.datetime.strptime("2021-03-21 20:50:40.901156", "%Y-%m-%d %H:%M:%S.%f")

H_ENC14_s = datetime.datetime.strptime("2021-03-21 21:16:07.103957", "%Y-%m-%d %H:%M:%S.%f")
H_ENC14_e=  datetime.datetime.strptime("2021-03-21 21:48:59.425626", "%Y-%m-%d %H:%M:%S.%f")

H_ENC15_s = datetime.datetime.strptime("2021-03-21 22:30:54.162231", "%Y-%m-%d %H:%M:%S.%f")
H_ENC15_e=  datetime.datetime.strptime("2021-03-21 22:36:18.208851", "%Y-%m-%d %H:%M:%S.%f")

H_ENC16_s = datetime.datetime.strptime("2021-03-21 22:52:18.849871", "%Y-%m-%d %H:%M:%S.%f")
H_ENC16_e=  datetime.datetime.strptime("2021-03-21 22:52:44.870850", "%Y-%m-%d %H:%M:%S.%f")

H_ENC17_s = datetime.datetime.strptime("2021-03-21 23:26:16.257801", "%Y-%m-%d %H:%M:%S.%f")
H_ENC17_e=  datetime.datetime.strptime("2021-03-21 23:26:36.607445", "%Y-%m-%d %H:%M:%S.%f")

H_ENC18_s = datetime.datetime.strptime("2021-03-21 23:57:45.979014", "%Y-%m-%d %H:%M:%S.%f")
H_ENC18_e=  datetime.datetime.strptime("2021-03-21 23:57:46.724934", "%Y-%m-%d %H:%M:%S.%f")

#Model testing 80 dpi 2s

M_ENC1_s = datetime.datetime.strptime("2021-03-21 03:17:30", "%Y-%m-%d %H:%M:%S")
M_ENC1_e=  datetime.datetime.strptime("2021-03-21 03:17:31", "%Y-%m-%d %H:%M:%S")

M_ENC2_s = datetime.datetime.strptime("2021-03-21 05:39:13", "%Y-%m-%d %H:%M:%S")
M_ENC2_e=  datetime.datetime.strptime("2021-03-21 05:39:14", "%Y-%m-%d %H:%M:%S")

M_ENC3_s = datetime.datetime.strptime("2021-03-21 09:46:52", "%Y-%m-%d %H:%M:%S")
M_ENC3_e=  datetime.datetime.strptime("2021-03-21 09:47:09", "%Y-%m-%d %H:%M:%S")

M_ENC4_s = datetime.datetime.strptime("2021-03-21 11:51:30", "%Y-%m-%d %H:%M:%S")
M_ENC4_e=  datetime.datetime.strptime("2021-03-21 11:51:31", "%Y-%m-%d %H:%M:%S")

M_ENC5_s = datetime.datetime.strptime("2021-03-21 12:36:40", "%Y-%m-%d %H:%M:%S")
M_ENC5_e=  datetime.datetime.strptime("2021-03-21 12:49:16", "%Y-%m-%d %H:%M:%S")

M_ENC6_s = datetime.datetime.strptime("2021-03-21 13:30:27", "%Y-%m-%d %H:%M:%S")
M_ENC6_e=  datetime.datetime.strptime("2021-03-21 15:02:53", "%Y-%m-%d %H:%M:%S")

M_ENC7_s = datetime.datetime.strptime("2021-03-21 15:32:21", "%Y-%m-%d %H:%M:%S")
M_ENC7_e=  datetime.datetime.strptime("2021-03-21 15:32:36", "%Y-%m-%d %H:%M:%S")

M_ENC8_s = datetime.datetime.strptime("2021-03-21 16:36:22", "%Y-%m-%d %H:%M:%S")
M_ENC8_e=  datetime.datetime.strptime("2021-03-21 16:36:23", "%Y-%m-%d %H:%M:%S")

M_ENC9_s = datetime.datetime.strptime("2021-03-21 18:48:24", "%Y-%m-%d %H:%M:%S")
M_ENC9_e=  datetime.datetime.strptime("2021-03-21 18:50:26", "%Y-%m-%d %H:%M:%S")

M_ENC10_s = datetime.datetime.strptime("2021-03-21 19:05:47", "%Y-%m-%d %H:%M:%S")
M_ENC10_e=  datetime.datetime.strptime("2021-03-21 19:27:36", "%Y-%m-%d %H:%M:%S")

M_ENC11_s = datetime.datetime.strptime("2021-03-21 20:34:43", "%Y-%m-%d %H:%M:%S")
M_ENC11_e=  datetime.datetime.strptime("2021-03-21 20:50:45", "%Y-%m-%d %H:%M:%S")

M_ENC12_s = datetime.datetime.strptime("2021-03-21 21:17:14", "%Y-%m-%d %H:%M:%S")
M_ENC12_e=  datetime.datetime.strptime("2021-03-21 21:51:47", "%Y-%m-%d %H:%M:%S")

M_ENC13_s = datetime.datetime.strptime("2021-03-21 22:08:31", "%Y-%m-%d %H:%M:%S")
M_ENC13_e=  datetime.datetime.strptime("2021-03-21 22:08:32", "%Y-%m-%d %H:%M:%S")

M_ENC14_s = datetime.datetime.strptime("2021-03-21 22:30:48", "%Y-%m-%d %H:%M:%S")
M_ENC14_e=  datetime.datetime.strptime("2021-03-21 22:36:09", "%Y-%m-%d %H:%M:%S")

confusion_matrix = []
for i in range(86400):
    #print(time_to_be_detected)
    
    if M_ENC1_s <= time_to_be_detected <= M_ENC1_e or M_ENC2_s <= time_to_be_detected <= M_ENC2_e or M_ENC3_s <= time_to_be_detected <= M_ENC3_e or M_ENC4_s <= time_to_be_detected <= M_ENC4_e or M_ENC5_s <= time_to_be_detected <= M_ENC5_e or M_ENC6_s <= time_to_be_detected <= M_ENC6_e or M_ENC7_s <= time_to_be_detected <= M_ENC7_e or M_ENC8_s <= time_to_be_detected <= M_ENC8_e or M_ENC9_s <= time_to_be_detected <= M_ENC9_e or M_ENC10_s <= time_to_be_detected <= M_ENC10_e or M_ENC11_s <= time_to_be_detected <= M_ENC11_e or M_ENC12_s <= time_to_be_detected <= M_ENC12_e or M_ENC13_s <= time_to_be_detected <= M_ENC13_e or M_ENC14_s <= time_to_be_detected <= M_ENC14_e:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e or H_ENC17_s <= time_to_be_detected <= H_ENC17_e or H_ENC18_s <= time_to_be_detected <= H_ENC18_e:
            #print("True Positive")
            confusion_matrix.append("TP")            
        else:
            #print("False Positive")
            confusion_matrix.append("FP")
    else:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e or H_ENC17_s <= time_to_be_detected <= H_ENC17_e or H_ENC18_s <= time_to_be_detected <= H_ENC18_e:
            #print("False Negative")
            confusion_matrix.append("FN")
        else:
            #print("True Negative")
            confusion_matrix.append("TN")    
           
    
    time_to_be_detected = time_to_be_detected + delta
    
confusion_matrix = pd.DataFrame(confusion_matrix, columns = ['confusion_matrix'])
prop_norm_off = confusion_matrix['confusion_matrix'].value_counts(normalize=False).to_string()#change normalize to true
#print("Confusion Matrix")
#print(prop_norm_off)
prop_norm_on = confusion_matrix['confusion_matrix'].value_counts(normalize=True).to_string()#change normalize to true
print("Model testing 80 dpi 2s x Human Detector SNR > 1")
print()
print("Normalized Confusion Matrix")
print(prop_norm_on)

TN = int(confusion_matrix['confusion_matrix'].value_counts()['TN'])
FN = int(confusion_matrix['confusion_matrix'].value_counts()['FN'])
TP = int(confusion_matrix['confusion_matrix'].value_counts()['TP'])
FP = int(confusion_matrix['confusion_matrix'].value_counts()['FP'])
specificity = TN/(TN + FP)
sensitivity = TP/(FN+TP)
accuracy = (TP+TN)/(TP+TN+FP+FN)
precision = TP/(TP+FP)
print('Specificity:', specificity)
print('Sensitivity:', sensitivity)
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Model testing 80 dpi 2s x Human Detector SNR > 1
#
# Normalized Confusion Matrix
# TN    0.780880
# FN    0.090185
# TP    0.085347
# FP    0.043588
# Specificity: 0.9471319875340427
# Sensitivity: 0.4862191744692074
# Accuracy: 0.8662268518518519
# Precision: 0.6619389587073609

# %%
import pandas as pd
import datetime
time = "2021-3-21 00:00:00.00"
#real_start_time = datetime.fromisoformat(time)
time_actual = datetime.datetime.strptime(time, "%Y-%m-%d %H:%M:%S.%f")
delta = delta = datetime.timedelta(seconds=1)
#print(time_actual)
time_to_be_detected = time_actual
#Human detector encounters SNR >=1
H_ENC1_s = datetime.datetime.strptime("2021-03-21 00:58:47.486945", "%Y-%m-%d %H:%M:%S.%f")
H_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:03:14.374073", "%Y-%m-%d %H:%M:%S.%f")

H_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:31.935836", "%Y-%m-%d %H:%M:%S.%f")
H_ENC2_e=  datetime.datetime.strptime("2021-03-21 03:22:45.836374", "%Y-%m-%d %H:%M:%S.%f")

H_ENC3_s = datetime.datetime.strptime("2021-03-21 03:40:16.056164", "%Y-%m-%d %H:%M:%S.%f")
H_ENC3_e=  datetime.datetime.strptime("2021-03-21 03:51:34.742141", "%Y-%m-%d %H:%M:%S.%f")

H_ENC4_s = datetime.datetime.strptime("2021-03-21 04:53:49.078051", "%Y-%m-%d %H:%M:%S.%f")
H_ENC4_e=  datetime.datetime.strptime("2021-03-21 05:53:25.625585", "%Y-%m-%d %H:%M:%S.%f")

H_ENC5_s = datetime.datetime.strptime("2021-03-21 06:11:00.072346", "%Y-%m-%d %H:%M:%S.%f")
H_ENC5_e=  datetime.datetime.strptime("2021-03-21 06:18:05.634234", "%Y-%m-%d %H:%M:%S.%f")

H_ENC6_s = datetime.datetime.strptime("2021-03-21 06:46:53.207224", "%Y-%m-%d %H:%M:%S.%f")
H_ENC6_e=  datetime.datetime.strptime("2021-03-21 06:49:34.904194", "%Y-%m-%d %H:%M:%S.%f")

H_ENC7_s = datetime.datetime.strptime("2021-03-21 07:35:41.622116", "%Y-%m-%d %H:%M:%S.%f")
H_ENC7_e=  datetime.datetime.strptime("2021-03-21 07:36:33.988652", "%Y-%m-%d %H:%M:%S.%f")

H_ENC8_s = datetime.datetime.strptime("2021-03-21 12:13:06.729857", "%Y-%m-%d %H:%M:%S.%f")
H_ENC8_e=  datetime.datetime.strptime("2021-03-21 12:13:07.055390", "%Y-%m-%d %H:%M:%S.%f")

H_ENC9_s = datetime.datetime.strptime("2021-03-21 12:37:42.023821", "%Y-%m-%d %H:%M:%S.%f")
H_ENC9_e=  datetime.datetime.strptime("2021-03-21 13:00:17.237988", "%Y-%m-%d %H:%M:%S.%f")

H_ENC10_s = datetime.datetime.strptime("2021-03-21 13:25:28.957795", "%Y-%m-%d %H:%M:%S.%f")
H_ENC10_e=  datetime.datetime.strptime("2021-03-21 14:06:54.100459", "%Y-%m-%d %H:%M:%S.%f")

H_ENC11_s = datetime.datetime.strptime("2021-03-21 18:46:23.912812", "%Y-%m-%d %H:%M:%S.%f")
H_ENC11_e=  datetime.datetime.strptime("2021-03-21 19:30:46.765953", "%Y-%m-%d %H:%M:%S.%f")

H_ENC12_s = datetime.datetime.strptime("2021-03-21 20:15:33.222835", "%Y-%m-%d %H:%M:%S.%f")
H_ENC12_e=  datetime.datetime.strptime("2021-03-21 20:15:42.360361", "%Y-%m-%d %H:%M:%S.%f")

H_ENC13_s = datetime.datetime.strptime("2021-03-21 20:36:44.460596", "%Y-%m-%d %H:%M:%S.%f")
H_ENC13_e=  datetime.datetime.strptime("2021-03-21 20:50:40.901156", "%Y-%m-%d %H:%M:%S.%f")

H_ENC14_s = datetime.datetime.strptime("2021-03-21 21:16:07.103957", "%Y-%m-%d %H:%M:%S.%f")
H_ENC14_e=  datetime.datetime.strptime("2021-03-21 21:48:59.425626", "%Y-%m-%d %H:%M:%S.%f")

H_ENC15_s = datetime.datetime.strptime("2021-03-21 22:30:54.162231", "%Y-%m-%d %H:%M:%S.%f")
H_ENC15_e=  datetime.datetime.strptime("2021-03-21 22:36:18.208851", "%Y-%m-%d %H:%M:%S.%f")

H_ENC16_s = datetime.datetime.strptime("2021-03-21 22:52:18.849871", "%Y-%m-%d %H:%M:%S.%f")
H_ENC16_e=  datetime.datetime.strptime("2021-03-21 22:52:44.870850", "%Y-%m-%d %H:%M:%S.%f")

H_ENC17_s = datetime.datetime.strptime("2021-03-21 23:26:16.257801", "%Y-%m-%d %H:%M:%S.%f")
H_ENC17_e=  datetime.datetime.strptime("2021-03-21 23:26:36.607445", "%Y-%m-%d %H:%M:%S.%f")

H_ENC18_s = datetime.datetime.strptime("2021-03-21 23:57:45.979014", "%Y-%m-%d %H:%M:%S.%f")
H_ENC18_e=  datetime.datetime.strptime("2021-03-21 23:57:46.724934", "%Y-%m-%d %H:%M:%S.%f")

#Model testing 80 dpi 2s

M_ENC1_s = datetime.datetime.strptime("2021-03-21 05:39:13", "%Y-%m-%d %H:%M:%S")
M_ENC1_e=  datetime.datetime.strptime("2021-03-21 05:39:14", "%Y-%m-%d %H:%M:%S")

M_ENC2_s = datetime.datetime.strptime("2021-03-21 09:46:51", "%Y-%m-%d %H:%M:%S")
M_ENC2_e=  datetime.datetime.strptime("2021-03-21 09:47:09", "%Y-%m-%d %H:%M:%S")

M_ENC3_s = datetime.datetime.strptime("2021-03-21 13:55:22", "%Y-%m-%d %H:%M:%S")
M_ENC3_e=  datetime.datetime.strptime("2021-03-21 14:18:56", "%Y-%m-%d %H:%M:%S")

M_ENC4_s = datetime.datetime.strptime("2021-03-21 14:37:00", "%Y-%m-%d %H:%M:%S")
M_ENC4_e=  datetime.datetime.strptime("2021-03-21 14:46:09", "%Y-%m-%d %H:%M:%S")

M_ENC5_s = datetime.datetime.strptime("2021-03-21 15:32:26", "%Y-%m-%d %H:%M:%S")
M_ENC5_e=  datetime.datetime.strptime("2021-03-21 15:32:36", "%Y-%m-%d %H:%M:%S")

M_ENC6_s = datetime.datetime.strptime("2021-03-21 18:49:28", "%Y-%m-%d %H:%M:%S")
M_ENC6_e=  datetime.datetime.strptime("2021-03-21 19:27:34", "%Y-%m-%d %H:%M:%S")

M_ENC7_s = datetime.datetime.strptime("2021-03-21 20:36:39", "%Y-%m-%d %H:%M:%S")
M_ENC7_e=  datetime.datetime.strptime("2021-03-21 20:50:19", "%Y-%m-%d %H:%M:%S")

M_ENC8_s = datetime.datetime.strptime("2021-03-21 21:19:42", "%Y-%m-%d %H:%M:%S")
M_ENC8_e=  datetime.datetime.strptime("2021-03-21 21:50:23", "%Y-%m-%d %H:%M:%S")

M_ENC9_s = datetime.datetime.strptime("2021-03-21 22:30:48", "%Y-%m-%d %H:%M:%S")
M_ENC9_e=  datetime.datetime.strptime("2021-03-21 22:36:06", "%Y-%m-%d %H:%M:%S")

confusion_matrix = []
for i in range(86400):
    #print(time_to_be_detected)
    
    if M_ENC1_s <= time_to_be_detected <= M_ENC1_e or M_ENC2_s <= time_to_be_detected <= M_ENC2_e or M_ENC3_s <= time_to_be_detected <= M_ENC3_e or M_ENC4_s <= time_to_be_detected <= M_ENC4_e or M_ENC5_s <= time_to_be_detected <= M_ENC5_e or M_ENC6_s <= time_to_be_detected <= M_ENC6_e or M_ENC7_s <= time_to_be_detected <= M_ENC7_e or M_ENC8_s <= time_to_be_detected <= M_ENC8_e or M_ENC9_s <= time_to_be_detected <= M_ENC9_e:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e or H_ENC17_s <= time_to_be_detected <= H_ENC17_e or H_ENC18_s <= time_to_be_detected <= H_ENC18_e:
            #print("True Positive")
            confusion_matrix.append("TP")            
        else:
            #print("False Positive")
            confusion_matrix.append("FP")
    else:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e or H_ENC17_s <= time_to_be_detected <= H_ENC17_e or H_ENC18_s <= time_to_be_detected <= H_ENC18_e:
            #print("False Negative")
            confusion_matrix.append("FN")
        else:
            #print("True Negative")
            confusion_matrix.append("TN")    
           
    
    time_to_be_detected = time_to_be_detected + delta
    
confusion_matrix = pd.DataFrame(confusion_matrix, columns = ['confusion_matrix'])
prop_norm_off = confusion_matrix['confusion_matrix'].value_counts(normalize=False).to_string()#change normalize to true
#print("Confusion Matrix")
#print(prop_norm_off)
prop_norm_on = confusion_matrix['confusion_matrix'].value_counts(normalize=True).to_string()#change normalize to true
print("Model testing 90 dpi 2s x Human Detector SNR > 1")
print()
print("Normalized Confusion Matrix")
print(prop_norm_on)

TN = int(confusion_matrix['confusion_matrix'].value_counts()['TN'])
FN = int(confusion_matrix['confusion_matrix'].value_counts()['FN'])
TP = int(confusion_matrix['confusion_matrix'].value_counts()['TP'])
FP = int(confusion_matrix['confusion_matrix'].value_counts()['FP'])
specificity = TN/(TN + FP)
sensitivity = TP/(FN+TP)
accuracy = (TP+TN)/(TP+TN+FP+FN)
precision = TP/(TP+FP)
print('Specificity:', specificity)
print('Sensitivity:', sensitivity)
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Model testing 90 dpi 2s x Human Detector SNR > 1
#
# Normalized Confusion Matrix
# TN    0.808275
# FN    0.107627
# TP    0.067905
# FP    0.016192
# Specificity: 0.9803605020074684
# Sensitivity: 0.3868521693261242
# Accuracy: 0.8761805555555555
# Precision: 0.8074593999449491

# %%
import pandas as pd
import datetime
time = "2021-3-21 00:00:00.00"
#real_start_time = datetime.fromisoformat(time)
time_actual = datetime.datetime.strptime(time, "%Y-%m-%d %H:%M:%S.%f")
delta = delta = datetime.timedelta(seconds=1)
#print(time_actual)
time_to_be_detected = time_actual
#Human detector encounters SNR >=1
H_ENC1_s = datetime.datetime.strptime("2021-03-21 00:58:47.486945", "%Y-%m-%d %H:%M:%S.%f")
H_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:03:14.374073", "%Y-%m-%d %H:%M:%S.%f")

H_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:31.935836", "%Y-%m-%d %H:%M:%S.%f")
H_ENC2_e=  datetime.datetime.strptime("2021-03-21 03:22:45.836374", "%Y-%m-%d %H:%M:%S.%f")

H_ENC3_s = datetime.datetime.strptime("2021-03-21 03:40:16.056164", "%Y-%m-%d %H:%M:%S.%f")
H_ENC3_e=  datetime.datetime.strptime("2021-03-21 03:51:34.742141", "%Y-%m-%d %H:%M:%S.%f")

H_ENC4_s = datetime.datetime.strptime("2021-03-21 04:53:49.078051", "%Y-%m-%d %H:%M:%S.%f")
H_ENC4_e=  datetime.datetime.strptime("2021-03-21 05:53:25.625585", "%Y-%m-%d %H:%M:%S.%f")

H_ENC5_s = datetime.datetime.strptime("2021-03-21 06:11:00.072346", "%Y-%m-%d %H:%M:%S.%f")
H_ENC5_e=  datetime.datetime.strptime("2021-03-21 06:18:05.634234", "%Y-%m-%d %H:%M:%S.%f")

H_ENC6_s = datetime.datetime.strptime("2021-03-21 06:46:53.207224", "%Y-%m-%d %H:%M:%S.%f")
H_ENC6_e=  datetime.datetime.strptime("2021-03-21 06:49:34.904194", "%Y-%m-%d %H:%M:%S.%f")

H_ENC7_s = datetime.datetime.strptime("2021-03-21 07:35:41.622116", "%Y-%m-%d %H:%M:%S.%f")
H_ENC7_e=  datetime.datetime.strptime("2021-03-21 07:36:33.988652", "%Y-%m-%d %H:%M:%S.%f")

H_ENC8_s = datetime.datetime.strptime("2021-03-21 12:13:06.729857", "%Y-%m-%d %H:%M:%S.%f")
H_ENC8_e=  datetime.datetime.strptime("2021-03-21 12:13:07.055390", "%Y-%m-%d %H:%M:%S.%f")

H_ENC9_s = datetime.datetime.strptime("2021-03-21 12:37:42.023821", "%Y-%m-%d %H:%M:%S.%f")
H_ENC9_e=  datetime.datetime.strptime("2021-03-21 13:00:17.237988", "%Y-%m-%d %H:%M:%S.%f")

H_ENC10_s = datetime.datetime.strptime("2021-03-21 13:25:28.957795", "%Y-%m-%d %H:%M:%S.%f")
H_ENC10_e=  datetime.datetime.strptime("2021-03-21 14:06:54.100459", "%Y-%m-%d %H:%M:%S.%f")

H_ENC11_s = datetime.datetime.strptime("2021-03-21 18:46:23.912812", "%Y-%m-%d %H:%M:%S.%f")
H_ENC11_e=  datetime.datetime.strptime("2021-03-21 19:30:46.765953", "%Y-%m-%d %H:%M:%S.%f")

H_ENC12_s = datetime.datetime.strptime("2021-03-21 20:15:33.222835", "%Y-%m-%d %H:%M:%S.%f")
H_ENC12_e=  datetime.datetime.strptime("2021-03-21 20:15:42.360361", "%Y-%m-%d %H:%M:%S.%f")

H_ENC13_s = datetime.datetime.strptime("2021-03-21 20:36:44.460596", "%Y-%m-%d %H:%M:%S.%f")
H_ENC13_e=  datetime.datetime.strptime("2021-03-21 20:50:40.901156", "%Y-%m-%d %H:%M:%S.%f")

H_ENC14_s = datetime.datetime.strptime("2021-03-21 21:16:07.103957", "%Y-%m-%d %H:%M:%S.%f")
H_ENC14_e=  datetime.datetime.strptime("2021-03-21 21:48:59.425626", "%Y-%m-%d %H:%M:%S.%f")

H_ENC15_s = datetime.datetime.strptime("2021-03-21 22:30:54.162231", "%Y-%m-%d %H:%M:%S.%f")
H_ENC15_e=  datetime.datetime.strptime("2021-03-21 22:36:18.208851", "%Y-%m-%d %H:%M:%S.%f")

H_ENC16_s = datetime.datetime.strptime("2021-03-21 22:52:18.849871", "%Y-%m-%d %H:%M:%S.%f")
H_ENC16_e=  datetime.datetime.strptime("2021-03-21 22:52:44.870850", "%Y-%m-%d %H:%M:%S.%f")

H_ENC17_s = datetime.datetime.strptime("2021-03-21 23:26:16.257801", "%Y-%m-%d %H:%M:%S.%f")
H_ENC17_e=  datetime.datetime.strptime("2021-03-21 23:26:36.607445", "%Y-%m-%d %H:%M:%S.%f")

H_ENC18_s = datetime.datetime.strptime("2021-03-21 23:57:45.979014", "%Y-%m-%d %H:%M:%S.%f")
H_ENC18_e=  datetime.datetime.strptime("2021-03-21 23:57:46.724934", "%Y-%m-%d %H:%M:%S.%f")

#Model testing 80 dpi 2s

M_ENC1_s = datetime.datetime.strptime("2021-03-21 01:00:23", "%Y-%m-%d %H:%M:%S")
M_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:00:52", "%Y-%m-%d %H:%M:%S")

M_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:30", "%Y-%m-%d %H:%M:%S")
M_ENC2_e=  datetime.datetime.strptime("2021-03-21 03:28:58", "%Y-%m-%d %H:%M:%S")

M_ENC3_s = datetime.datetime.strptime("2021-03-21 05:39:13", "%Y-%m-%d %H:%M:%S")
M_ENC3_e=  datetime.datetime.strptime("2021-03-21 05:39:14", "%Y-%m-%d %H:%M:%S")

M_ENC4_s = datetime.datetime.strptime("2021-03-21 09:46:52", "%Y-%m-%d %H:%M:%S")
M_ENC4_e=  datetime.datetime.strptime("2021-03-21 09:47:09", "%Y-%m-%d %H:%M:%S")

M_ENC5_s = datetime.datetime.strptime("2021-03-21 12:08:22", "%Y-%m-%d %H:%M:%S")
M_ENC5_e=  datetime.datetime.strptime("2021-03-21 12:08:25", "%Y-%m-%d %H:%M:%S")

M_ENC6_s = datetime.datetime.strptime("2021-03-21 12:37:38", "%Y-%m-%d %H:%M:%S")
M_ENC6_e=  datetime.datetime.strptime("2021-03-21 12:51:23", "%Y-%m-%d %H:%M:%S")

M_ENC7_s = datetime.datetime.strptime("2021-03-21 13:27:31", "%Y-%m-%d %H:%M:%S")
M_ENC7_e=  datetime.datetime.strptime("2021-03-21 15:02:52", "%Y-%m-%d %H:%M:%S")

M_ENC8_s = datetime.datetime.strptime("2021-03-21 15:32:26", "%Y-%m-%d %H:%M:%S")
M_ENC8_e=  datetime.datetime.strptime("2021-03-21 15:32:36", "%Y-%m-%d %H:%M:%S")

M_ENC9_s = datetime.datetime.strptime("2021-03-21 18:48:31", "%Y-%m-%d %H:%M:%S")
M_ENC9_e=  datetime.datetime.strptime("2021-03-21 18:50:26", "%Y-%m-%d %H:%M:%S")

M_ENC10_s = datetime.datetime.strptime("2021-03-21 19:05:46", "%Y-%m-%d %H:%M:%S")
M_ENC10_e=  datetime.datetime.strptime("2021-03-21 19:27:26", "%Y-%m-%d %H:%M:%S")

M_ENC11_s = datetime.datetime.strptime("2021-03-21 20:19:48", "%Y-%m-%d %H:%M:%S")
M_ENC11_e=  datetime.datetime.strptime("2021-03-21 20:50:45", "%Y-%m-%d %H:%M:%S")

M_ENC12_s = datetime.datetime.strptime("2021-03-21 21:16:39", "%Y-%m-%d %H:%M:%S")
M_ENC12_e=  datetime.datetime.strptime("2021-03-21 22:08:31", "%Y-%m-%d %H:%M:%S")

M_ENC13_s = datetime.datetime.strptime("2021-03-21 22:31:51", "%Y-%m-%d %H:%M:%S")
M_ENC13_e=  datetime.datetime.strptime("2021-03-21 22:36:09", "%Y-%m-%d %H:%M:%S")

M_ENC14_s = datetime.datetime.strptime("2021-03-21 23:47:35", "%Y-%m-%d %H:%M:%S")
M_ENC14_e=  datetime.datetime.strptime("2021-03-21 23:57:40", "%Y-%m-%d %H:%M:%S")

confusion_matrix = []
for i in range(86400):
    #print(time_to_be_detected)
    
    if M_ENC1_s <= time_to_be_detected <= M_ENC1_e or M_ENC2_s <= time_to_be_detected <= M_ENC2_e or M_ENC3_s <= time_to_be_detected <= M_ENC3_e or M_ENC4_s <= time_to_be_detected <= M_ENC4_e or M_ENC5_s <= time_to_be_detected <= M_ENC5_e or M_ENC6_s <= time_to_be_detected <= M_ENC6_e or M_ENC7_s <= time_to_be_detected <= M_ENC7_e or M_ENC8_s <= time_to_be_detected <= M_ENC8_e or M_ENC9_s <= time_to_be_detected <= M_ENC9_e or M_ENC10_s <= time_to_be_detected <= M_ENC10_e or M_ENC11_s <= time_to_be_detected <= M_ENC11_e or M_ENC12_s <= time_to_be_detected <= M_ENC12_e or M_ENC13_s <= time_to_be_detected <= M_ENC13_e or M_ENC14_s <= time_to_be_detected <= M_ENC14_e:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e or H_ENC17_s <= time_to_be_detected <= H_ENC17_e or H_ENC18_s <= time_to_be_detected <= H_ENC18_e:
            #print("True Positive")
            confusion_matrix.append("TP")            
        else:
            #print("False Positive")
            confusion_matrix.append("FP")
    else:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e or H_ENC17_s <= time_to_be_detected <= H_ENC17_e or H_ENC18_s <= time_to_be_detected <= H_ENC18_e:
            #print("False Negative")
            confusion_matrix.append("FN")
        else:
            #print("True Negative")
            confusion_matrix.append("TN")    
           
    
    time_to_be_detected = time_to_be_detected + delta
    
confusion_matrix = pd.DataFrame(confusion_matrix, columns = ['confusion_matrix'])
prop_norm_off = confusion_matrix['confusion_matrix'].value_counts(normalize=False).to_string()#change normalize to true
#print("Confusion Matrix")
#print(prop_norm_off)
prop_norm_on = confusion_matrix['confusion_matrix'].value_counts(normalize=True).to_string()#change normalize to true
print("Model testing 100 dpi 2s x Human Detector SNR > 1")
print()
print("Normalized Confusion Matrix")
print(prop_norm_on)

TN = int(confusion_matrix['confusion_matrix'].value_counts()['TN'])
FN = int(confusion_matrix['confusion_matrix'].value_counts()['FN'])
TP = int(confusion_matrix['confusion_matrix'].value_counts()['TP'])
FP = int(confusion_matrix['confusion_matrix'].value_counts()['FP'])
specificity = TN/(TN + FP)
sensitivity = TP/(FN+TP)
accuracy = (TP+TN)/(TP+TN+FP+FN)
precision = TP/(TP+FP)
print('Specificity:', specificity)
print('Sensitivity:', sensitivity)
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Model testing 100 dpi 2s x Human Detector SNR > 1
#
# Normalized Confusion Matrix
# TN    0.748414
# TP    0.092407
# FN    0.083125
# FP    0.076053
# Specificity: 0.907754723867816
# Sensitivity: 0.5264407226691283
# Accuracy: 0.8408217592592593
# Precision: 0.5485400206114737

# %%
import pandas as pd
import datetime
time = "2021-3-21 00:00:00.00"
#real_start_time = datetime.fromisoformat(time)
time_actual = datetime.datetime.strptime(time, "%Y-%m-%d %H:%M:%S.%f")
delta = delta = datetime.timedelta(seconds=1)
#print(time_actual)
time_to_be_detected = time_actual
#Human detector encounters SNR >=1
H_ENC1_s = datetime.datetime.strptime("2021-03-21 00:58:47.486945", "%Y-%m-%d %H:%M:%S.%f")
H_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:03:14.374073", "%Y-%m-%d %H:%M:%S.%f")

H_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:31.935836", "%Y-%m-%d %H:%M:%S.%f")
H_ENC2_e=  datetime.datetime.strptime("2021-03-21 03:22:45.836374", "%Y-%m-%d %H:%M:%S.%f")

H_ENC3_s = datetime.datetime.strptime("2021-03-21 03:40:16.056164", "%Y-%m-%d %H:%M:%S.%f")
H_ENC3_e=  datetime.datetime.strptime("2021-03-21 03:51:34.742141", "%Y-%m-%d %H:%M:%S.%f")

H_ENC4_s = datetime.datetime.strptime("2021-03-21 04:53:49.078051", "%Y-%m-%d %H:%M:%S.%f")
H_ENC4_e=  datetime.datetime.strptime("2021-03-21 05:53:25.625585", "%Y-%m-%d %H:%M:%S.%f")

H_ENC5_s = datetime.datetime.strptime("2021-03-21 06:11:00.072346", "%Y-%m-%d %H:%M:%S.%f")
H_ENC5_e=  datetime.datetime.strptime("2021-03-21 06:18:05.634234", "%Y-%m-%d %H:%M:%S.%f")

H_ENC6_s = datetime.datetime.strptime("2021-03-21 06:46:53.207224", "%Y-%m-%d %H:%M:%S.%f")
H_ENC6_e=  datetime.datetime.strptime("2021-03-21 06:49:34.904194", "%Y-%m-%d %H:%M:%S.%f")

H_ENC7_s = datetime.datetime.strptime("2021-03-21 07:35:41.622116", "%Y-%m-%d %H:%M:%S.%f")
H_ENC7_e=  datetime.datetime.strptime("2021-03-21 07:36:33.988652", "%Y-%m-%d %H:%M:%S.%f")

H_ENC8_s = datetime.datetime.strptime("2021-03-21 12:13:06.729857", "%Y-%m-%d %H:%M:%S.%f")
H_ENC8_e=  datetime.datetime.strptime("2021-03-21 12:13:07.055390", "%Y-%m-%d %H:%M:%S.%f")

H_ENC9_s = datetime.datetime.strptime("2021-03-21 12:37:42.023821", "%Y-%m-%d %H:%M:%S.%f")
H_ENC9_e=  datetime.datetime.strptime("2021-03-21 13:00:17.237988", "%Y-%m-%d %H:%M:%S.%f")

H_ENC10_s = datetime.datetime.strptime("2021-03-21 13:25:28.957795", "%Y-%m-%d %H:%M:%S.%f")
H_ENC10_e=  datetime.datetime.strptime("2021-03-21 14:06:54.100459", "%Y-%m-%d %H:%M:%S.%f")

H_ENC11_s = datetime.datetime.strptime("2021-03-21 18:46:23.912812", "%Y-%m-%d %H:%M:%S.%f")
H_ENC11_e=  datetime.datetime.strptime("2021-03-21 19:30:46.765953", "%Y-%m-%d %H:%M:%S.%f")

H_ENC12_s = datetime.datetime.strptime("2021-03-21 20:15:33.222835", "%Y-%m-%d %H:%M:%S.%f")
H_ENC12_e=  datetime.datetime.strptime("2021-03-21 20:15:42.360361", "%Y-%m-%d %H:%M:%S.%f")

H_ENC13_s = datetime.datetime.strptime("2021-03-21 20:36:44.460596", "%Y-%m-%d %H:%M:%S.%f")
H_ENC13_e=  datetime.datetime.strptime("2021-03-21 20:50:40.901156", "%Y-%m-%d %H:%M:%S.%f")

H_ENC14_s = datetime.datetime.strptime("2021-03-21 21:16:07.103957", "%Y-%m-%d %H:%M:%S.%f")
H_ENC14_e=  datetime.datetime.strptime("2021-03-21 21:48:59.425626", "%Y-%m-%d %H:%M:%S.%f")

H_ENC15_s = datetime.datetime.strptime("2021-03-21 22:30:54.162231", "%Y-%m-%d %H:%M:%S.%f")
H_ENC15_e=  datetime.datetime.strptime("2021-03-21 22:36:18.208851", "%Y-%m-%d %H:%M:%S.%f")

H_ENC16_s = datetime.datetime.strptime("2021-03-21 22:52:18.849871", "%Y-%m-%d %H:%M:%S.%f")
H_ENC16_e=  datetime.datetime.strptime("2021-03-21 22:52:44.870850", "%Y-%m-%d %H:%M:%S.%f")

H_ENC17_s = datetime.datetime.strptime("2021-03-21 23:26:16.257801", "%Y-%m-%d %H:%M:%S.%f")
H_ENC17_e=  datetime.datetime.strptime("2021-03-21 23:26:36.607445", "%Y-%m-%d %H:%M:%S.%f")

H_ENC18_s = datetime.datetime.strptime("2021-03-21 23:57:45.979014", "%Y-%m-%d %H:%M:%S.%f")
H_ENC18_e=  datetime.datetime.strptime("2021-03-21 23:57:46.724934", "%Y-%m-%d %H:%M:%S.%f")

#Model testing 80 dpi 2s

M_ENC1_s = datetime.datetime.strptime("2021-03-21 09:46:50", "%Y-%m-%d %H:%M:%S")
M_ENC1_e=  datetime.datetime.strptime("2021-03-21 09:47:09", "%Y-%m-%d %H:%M:%S")

M_ENC2_s = datetime.datetime.strptime("2021-03-21 10:21:12", "%Y-%m-%d %H:%M:%S")
M_ENC2_e=  datetime.datetime.strptime("2021-03-21 10:22:34", "%Y-%m-%d %H:%M:%S")

M_ENC3_s = datetime.datetime.strptime("2021-03-21 12:07:27", "%Y-%m-%d %H:%M:%S")
M_ENC3_e=  datetime.datetime.strptime("2021-03-21 12:08:30", "%Y-%m-%d %H:%M:%S")

M_ENC4_s = datetime.datetime.strptime("2021-03-21 13:27:31", "%Y-%m-%d %H:%M:%S")
M_ENC4_e=  datetime.datetime.strptime("2021-03-21 14:48:24", "%Y-%m-%d %H:%M:%S")

M_ENC5_s = datetime.datetime.strptime("2021-03-21 15:32:25", "%Y-%m-%d %H:%M:%S")
M_ENC5_e=  datetime.datetime.strptime("2021-03-21 15:32:36", "%Y-%m-%d %H:%M:%S")

M_ENC6_s = datetime.datetime.strptime("2021-03-21 18:45:15", "%Y-%m-%d %H:%M:%S")
M_ENC6_e=  datetime.datetime.strptime("2021-03-21 19:27:35", "%Y-%m-%d %H:%M:%S")

M_ENC7_s = datetime.datetime.strptime("2021-03-21 20:04:35", "%Y-%m-%d %H:%M:%S")
M_ENC7_e=  datetime.datetime.strptime("2021-03-21 20:16:38", "%Y-%m-%d %H:%M:%S")

M_ENC8_s = datetime.datetime.strptime("2021-03-21 20:32:56", "%Y-%m-%d %H:%M:%S")
M_ENC8_e=  datetime.datetime.strptime("2021-03-21 20:53:00", "%Y-%m-%d %H:%M:%S")

M_ENC9_s = datetime.datetime.strptime("2021-03-21 21:13:25", "%Y-%m-%d %H:%M:%S")
M_ENC9_e=  datetime.datetime.strptime("2021-03-21 22:08:31", "%Y-%m-%d %H:%M:%S")

M_ENC10_s = datetime.datetime.strptime("2021-03-21 22:24:45", "%Y-%m-%d %H:%M:%S")
M_ENC10_e=  datetime.datetime.strptime("2021-03-21 22:36:09", "%Y-%m-%d %H:%M:%S")

confusion_matrix = []
for i in range(86400):
    #print(time_to_be_detected)
    
    if M_ENC1_s <= time_to_be_detected <= M_ENC1_e or M_ENC2_s <= time_to_be_detected <= M_ENC2_e or M_ENC3_s <= time_to_be_detected <= M_ENC3_e or M_ENC4_s <= time_to_be_detected <= M_ENC4_e or M_ENC5_s <= time_to_be_detected <= M_ENC5_e or M_ENC6_s <= time_to_be_detected <= M_ENC6_e or M_ENC7_s <= time_to_be_detected <= M_ENC7_e or M_ENC8_s <= time_to_be_detected <= M_ENC8_e or M_ENC9_s <= time_to_be_detected <= M_ENC9_e or M_ENC10_s <= time_to_be_detected <= M_ENC10_e:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e or H_ENC17_s <= time_to_be_detected <= H_ENC17_e or H_ENC18_s <= time_to_be_detected <= H_ENC18_e:
            #print("True Positive")
            confusion_matrix.append("TP")            
        else:
            #print("False Positive")
            confusion_matrix.append("FP")
    else:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e or H_ENC17_s <= time_to_be_detected <= H_ENC17_e or H_ENC18_s <= time_to_be_detected <= H_ENC18_e:
            #print("False Negative")
            confusion_matrix.append("FN")
        else:
            #print("True Negative")
            confusion_matrix.append("TN")    
           
    
    time_to_be_detected = time_to_be_detected + delta
    
confusion_matrix = pd.DataFrame(confusion_matrix, columns = ['confusion_matrix'])
prop_norm_off = confusion_matrix['confusion_matrix'].value_counts(normalize=False).to_string()#change normalize to true
#print("Confusion Matrix")
#print(prop_norm_off)
prop_norm_on = confusion_matrix['confusion_matrix'].value_counts(normalize=True).to_string()#change normalize to true
print("Model testing 40 dpi 3s x Human Detector SNR > 1")
print()
print("Normalized Confusion Matrix")
print(prop_norm_on)

TN = int(confusion_matrix['confusion_matrix'].value_counts()['TN'])
FN = int(confusion_matrix['confusion_matrix'].value_counts()['FN'])
TP = int(confusion_matrix['confusion_matrix'].value_counts()['TP'])
FP = int(confusion_matrix['confusion_matrix'].value_counts()['FP'])
specificity = TN/(TN + FP)
sensitivity = TP/(FN+TP)
accuracy = (TP+TN)/(TP+TN+FP+FN)
precision = TP/(TP+FP)
print('Specificity:', specificity)
print('Sensitivity:', sensitivity)
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Model testing 40 dpi 3s x Human Detector SNR > 1
#
# Normalized Confusion Matrix
# TN    0.760498
# TP    0.092222
# FN    0.083310
# FP    0.063970
# Specificity: 0.9224106466013421
# Sensitivity: 0.5253857312409337
# Accuracy: 0.8527199074074074
# Precision: 0.5904409040385328

# %%
import pandas as pd
import datetime
time = "2021-3-21 00:00:00.00"
#real_start_time = datetime.fromisoformat(time)
time_actual = datetime.datetime.strptime(time, "%Y-%m-%d %H:%M:%S.%f")
delta = delta = datetime.timedelta(seconds=1)
#print(time_actual)
time_to_be_detected = time_actual
#Human detector encounters SNR >=1
H_ENC1_s = datetime.datetime.strptime("2021-03-21 00:58:47.486945", "%Y-%m-%d %H:%M:%S.%f")
H_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:03:14.374073", "%Y-%m-%d %H:%M:%S.%f")

H_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:31.935836", "%Y-%m-%d %H:%M:%S.%f")
H_ENC2_e=  datetime.datetime.strptime("2021-03-21 03:22:45.836374", "%Y-%m-%d %H:%M:%S.%f")

H_ENC3_s = datetime.datetime.strptime("2021-03-21 03:40:16.056164", "%Y-%m-%d %H:%M:%S.%f")
H_ENC3_e=  datetime.datetime.strptime("2021-03-21 03:51:34.742141", "%Y-%m-%d %H:%M:%S.%f")

H_ENC4_s = datetime.datetime.strptime("2021-03-21 04:53:49.078051", "%Y-%m-%d %H:%M:%S.%f")
H_ENC4_e=  datetime.datetime.strptime("2021-03-21 05:53:25.625585", "%Y-%m-%d %H:%M:%S.%f")

H_ENC5_s = datetime.datetime.strptime("2021-03-21 06:11:00.072346", "%Y-%m-%d %H:%M:%S.%f")
H_ENC5_e=  datetime.datetime.strptime("2021-03-21 06:18:05.634234", "%Y-%m-%d %H:%M:%S.%f")

H_ENC6_s = datetime.datetime.strptime("2021-03-21 06:46:53.207224", "%Y-%m-%d %H:%M:%S.%f")
H_ENC6_e=  datetime.datetime.strptime("2021-03-21 06:49:34.904194", "%Y-%m-%d %H:%M:%S.%f")

H_ENC7_s = datetime.datetime.strptime("2021-03-21 07:35:41.622116", "%Y-%m-%d %H:%M:%S.%f")
H_ENC7_e=  datetime.datetime.strptime("2021-03-21 07:36:33.988652", "%Y-%m-%d %H:%M:%S.%f")

H_ENC8_s = datetime.datetime.strptime("2021-03-21 12:13:06.729857", "%Y-%m-%d %H:%M:%S.%f")
H_ENC8_e=  datetime.datetime.strptime("2021-03-21 12:13:07.055390", "%Y-%m-%d %H:%M:%S.%f")

H_ENC9_s = datetime.datetime.strptime("2021-03-21 12:37:42.023821", "%Y-%m-%d %H:%M:%S.%f")
H_ENC9_e=  datetime.datetime.strptime("2021-03-21 13:00:17.237988", "%Y-%m-%d %H:%M:%S.%f")

H_ENC10_s = datetime.datetime.strptime("2021-03-21 13:25:28.957795", "%Y-%m-%d %H:%M:%S.%f")
H_ENC10_e=  datetime.datetime.strptime("2021-03-21 14:06:54.100459", "%Y-%m-%d %H:%M:%S.%f")

H_ENC11_s = datetime.datetime.strptime("2021-03-21 18:46:23.912812", "%Y-%m-%d %H:%M:%S.%f")
H_ENC11_e=  datetime.datetime.strptime("2021-03-21 19:30:46.765953", "%Y-%m-%d %H:%M:%S.%f")

H_ENC12_s = datetime.datetime.strptime("2021-03-21 20:15:33.222835", "%Y-%m-%d %H:%M:%S.%f")
H_ENC12_e=  datetime.datetime.strptime("2021-03-21 20:15:42.360361", "%Y-%m-%d %H:%M:%S.%f")

H_ENC13_s = datetime.datetime.strptime("2021-03-21 20:36:44.460596", "%Y-%m-%d %H:%M:%S.%f")
H_ENC13_e=  datetime.datetime.strptime("2021-03-21 20:50:40.901156", "%Y-%m-%d %H:%M:%S.%f")

H_ENC14_s = datetime.datetime.strptime("2021-03-21 21:16:07.103957", "%Y-%m-%d %H:%M:%S.%f")
H_ENC14_e=  datetime.datetime.strptime("2021-03-21 21:48:59.425626", "%Y-%m-%d %H:%M:%S.%f")

H_ENC15_s = datetime.datetime.strptime("2021-03-21 22:30:54.162231", "%Y-%m-%d %H:%M:%S.%f")
H_ENC15_e=  datetime.datetime.strptime("2021-03-21 22:36:18.208851", "%Y-%m-%d %H:%M:%S.%f")

H_ENC16_s = datetime.datetime.strptime("2021-03-21 22:52:18.849871", "%Y-%m-%d %H:%M:%S.%f")
H_ENC16_e=  datetime.datetime.strptime("2021-03-21 22:52:44.870850", "%Y-%m-%d %H:%M:%S.%f")

H_ENC17_s = datetime.datetime.strptime("2021-03-21 23:26:16.257801", "%Y-%m-%d %H:%M:%S.%f")
H_ENC17_e=  datetime.datetime.strptime("2021-03-21 23:26:36.607445", "%Y-%m-%d %H:%M:%S.%f")

H_ENC18_s = datetime.datetime.strptime("2021-03-21 23:57:45.979014", "%Y-%m-%d %H:%M:%S.%f")
H_ENC18_e=  datetime.datetime.strptime("2021-03-21 23:57:46.724934", "%Y-%m-%d %H:%M:%S.%f")

#Model testing 80 dpi 2s

M_ENC1_s = datetime.datetime.strptime("2021-03-21 01:11:06", "%Y-%m-%d %H:%M:%S")
M_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:11:12", "%Y-%m-%d %H:%M:%S")

M_ENC2_s = datetime.datetime.strptime("2021-03-21 05:17:31", "%Y-%m-%d %H:%M:%S")
M_ENC2_e=  datetime.datetime.strptime("2021-03-21 05:17:37", "%Y-%m-%d %H:%M:%S")

M_ENC3_s = datetime.datetime.strptime("2021-03-21 05:39:00", "%Y-%m-%d %H:%M:%S")
M_ENC3_e=  datetime.datetime.strptime("2021-03-21 05:39:14", "%Y-%m-%d %H:%M:%S")

M_ENC4_s = datetime.datetime.strptime("2021-03-21 07:00:42", "%Y-%m-%d %H:%M:%S")
M_ENC4_e=  datetime.datetime.strptime("2021-03-21 07:05:33", "%Y-%m-%d %H:%M:%S")

M_ENC5_s = datetime.datetime.strptime("2021-03-21 07:38:27", "%Y-%m-%d %H:%M:%S")
M_ENC5_e=  datetime.datetime.strptime("2021-03-21 07:38:33", "%Y-%m-%d %H:%M:%S")

M_ENC6_s = datetime.datetime.strptime("2021-03-21 09:46:46", "%Y-%m-%d %H:%M:%S")
M_ENC6_e=  datetime.datetime.strptime("2021-03-21 09:47:09", "%Y-%m-%d %H:%M:%S")

M_ENC7_s = datetime.datetime.strptime("2021-03-21 12:08:08", "%Y-%m-%d %H:%M:%S")
M_ENC7_e=  datetime.datetime.strptime("2021-03-21 12:08:30", "%Y-%m-%d %H:%M:%S")

M_ENC8_s = datetime.datetime.strptime("2021-03-21 14:40:44", "%Y-%m-%d %H:%M:%S")
M_ENC8_e=  datetime.datetime.strptime("2021-03-21 14:48:22", "%Y-%m-%d %H:%M:%S")

M_ENC9_s = datetime.datetime.strptime("2021-03-21 15:32:13", "%Y-%m-%d %H:%M:%S")
M_ENC9_e=  datetime.datetime.strptime("2021-03-21 15:49:42", "%Y-%m-%d %H:%M:%S")

M_ENC10_s = datetime.datetime.strptime("2021-03-21 16:36:13", "%Y-%m-%d %H:%M:%S")
M_ENC10_e=  datetime.datetime.strptime("2021-03-21 16:36:42", "%Y-%m-%d %H:%M:%S")

M_ENC11_s = datetime.datetime.strptime("2021-03-21 18:45:16", "%Y-%m-%d %H:%M:%S")
M_ENC11_e=  datetime.datetime.strptime("2021-03-21 18:50:21", "%Y-%m-%d %H:%M:%S")

M_ENC12_s = datetime.datetime.strptime("2021-03-21 19:05:44", "%Y-%m-%d %H:%M:%S")
M_ENC12_e=  datetime.datetime.strptime("2021-03-21 19:39:17", "%Y-%m-%d %H:%M:%S")

M_ENC13_s = datetime.datetime.strptime("2021-03-21 20:47:01", "%Y-%m-%d %H:%M:%S")
M_ENC13_e=  datetime.datetime.strptime("2021-03-21 20:47:02", "%Y-%m-%d %H:%M:%S")

M_ENC14_s = datetime.datetime.strptime("2021-03-21 21:29:23", "%Y-%m-%d %H:%M:%S")
M_ENC14_e=  datetime.datetime.strptime("2021-03-21 21:52:15", "%Y-%m-%d %H:%M:%S")

M_ENC15_s = datetime.datetime.strptime("2021-03-21 22:30:38", "%Y-%m-%d %H:%M:%S")
M_ENC15_e=  datetime.datetime.strptime("2021-03-21 22:36:08", "%Y-%m-%d %H:%M:%S")

M_ENC16_s = datetime.datetime.strptime("2021-03-21 23:41:16", "%Y-%m-%d %H:%M:%S")
M_ENC16_e=  datetime.datetime.strptime("2021-03-21 23:41:19", "%Y-%m-%d %H:%M:%S")

confusion_matrix = []
for i in range(86400):
    #print(time_to_be_detected)
    
    if M_ENC1_s <= time_to_be_detected <= M_ENC1_e or M_ENC2_s <= time_to_be_detected <= M_ENC2_e or M_ENC3_s <= time_to_be_detected <= M_ENC3_e or M_ENC4_s <= time_to_be_detected <= M_ENC4_e or M_ENC5_s <= time_to_be_detected <= M_ENC5_e or M_ENC6_s <= time_to_be_detected <= M_ENC6_e or M_ENC7_s <= time_to_be_detected <= M_ENC7_e or M_ENC8_s <= time_to_be_detected <= M_ENC8_e or M_ENC9_s <= time_to_be_detected <= M_ENC9_e or M_ENC10_s <= time_to_be_detected <= M_ENC10_e or M_ENC11_s <= time_to_be_detected <= M_ENC11_e or M_ENC12_s <= time_to_be_detected <= M_ENC12_e or M_ENC13_s <= time_to_be_detected <= M_ENC13_e or M_ENC14_s <= time_to_be_detected <= M_ENC14_e or M_ENC15_s <= time_to_be_detected <= M_ENC15_e or M_ENC16_s <= time_to_be_detected <= M_ENC16_e:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e or H_ENC17_s <= time_to_be_detected <= H_ENC17_e or H_ENC18_s <= time_to_be_detected <= H_ENC18_e:
            #print("True Positive")
            confusion_matrix.append("TP")            
        else:
            #print("False Positive")
            confusion_matrix.append("FP")
    else:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e or H_ENC17_s <= time_to_be_detected <= H_ENC17_e or H_ENC18_s <= time_to_be_detected <= H_ENC18_e:
            #print("False Negative")
            confusion_matrix.append("FN")
        else:
            #print("True Negative")
            confusion_matrix.append("TN")    
           
    
    time_to_be_detected = time_to_be_detected + delta
    
confusion_matrix = pd.DataFrame(confusion_matrix, columns = ['confusion_matrix'])
prop_norm_off = confusion_matrix['confusion_matrix'].value_counts(normalize=False).to_string()#change normalize to true
#print("Confusion Matrix")
#print(prop_norm_off)
prop_norm_on = confusion_matrix['confusion_matrix'].value_counts(normalize=True).to_string()#change normalize to true
print("Model testing 40 dpi 7s x Human Detector SNR > 1")
print()
print("Normalized Confusion Matrix")
print(prop_norm_on)

TN = int(confusion_matrix['confusion_matrix'].value_counts()['TN'])
FN = int(confusion_matrix['confusion_matrix'].value_counts()['FN'])
TP = int(confusion_matrix['confusion_matrix'].value_counts()['TP'])
FP = int(confusion_matrix['confusion_matrix'].value_counts()['FP'])
specificity = TN/(TN + FP)
sensitivity = TP/(FN+TP)
accuracy = (TP+TN)/(TP+TN+FP+FN)
precision = TP/(TP+FP)
print('Specificity:', specificity)
print('Sensitivity:', sensitivity)
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Model testing 40 dpi 7s x Human Detector SNR > 1
#
# Normalized Confusion Matrix
# TN    0.793356
# FN    0.137847
# TP    0.037685
# FP    0.031111
# Specificity: 0.9622652104332201
# Sensitivity: 0.21469075563761045
# Accuracy: 0.8310416666666667
# Precision: 0.5477792732166891

# %%
import pandas as pd
import datetime
time = "2021-3-21 00:00:00.00"
#real_start_time = datetime.fromisoformat(time)
time_actual = datetime.datetime.strptime(time, "%Y-%m-%d %H:%M:%S.%f")
delta = delta = datetime.timedelta(seconds=1)
#print(time_actual)
time_to_be_detected = time_actual
#Human detector encounters SNR >=1
H_ENC1_s = datetime.datetime.strptime("2021-03-21 00:58:47.486945", "%Y-%m-%d %H:%M:%S.%f")
H_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:03:14.374073", "%Y-%m-%d %H:%M:%S.%f")

H_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:31.935836", "%Y-%m-%d %H:%M:%S.%f")
H_ENC2_e=  datetime.datetime.strptime("2021-03-21 03:22:45.836374", "%Y-%m-%d %H:%M:%S.%f")

H_ENC3_s = datetime.datetime.strptime("2021-03-21 03:40:16.056164", "%Y-%m-%d %H:%M:%S.%f")
H_ENC3_e=  datetime.datetime.strptime("2021-03-21 03:51:34.742141", "%Y-%m-%d %H:%M:%S.%f")

H_ENC4_s = datetime.datetime.strptime("2021-03-21 04:53:49.078051", "%Y-%m-%d %H:%M:%S.%f")
H_ENC4_e=  datetime.datetime.strptime("2021-03-21 05:53:25.625585", "%Y-%m-%d %H:%M:%S.%f")

H_ENC5_s = datetime.datetime.strptime("2021-03-21 06:11:00.072346", "%Y-%m-%d %H:%M:%S.%f")
H_ENC5_e=  datetime.datetime.strptime("2021-03-21 06:18:05.634234", "%Y-%m-%d %H:%M:%S.%f")

H_ENC6_s = datetime.datetime.strptime("2021-03-21 06:46:53.207224", "%Y-%m-%d %H:%M:%S.%f")
H_ENC6_e=  datetime.datetime.strptime("2021-03-21 06:49:34.904194", "%Y-%m-%d %H:%M:%S.%f")

H_ENC7_s = datetime.datetime.strptime("2021-03-21 07:35:41.622116", "%Y-%m-%d %H:%M:%S.%f")
H_ENC7_e=  datetime.datetime.strptime("2021-03-21 07:36:33.988652", "%Y-%m-%d %H:%M:%S.%f")

H_ENC8_s = datetime.datetime.strptime("2021-03-21 12:13:06.729857", "%Y-%m-%d %H:%M:%S.%f")
H_ENC8_e=  datetime.datetime.strptime("2021-03-21 12:13:07.055390", "%Y-%m-%d %H:%M:%S.%f")

H_ENC9_s = datetime.datetime.strptime("2021-03-21 12:37:42.023821", "%Y-%m-%d %H:%M:%S.%f")
H_ENC9_e=  datetime.datetime.strptime("2021-03-21 13:00:17.237988", "%Y-%m-%d %H:%M:%S.%f")

H_ENC10_s = datetime.datetime.strptime("2021-03-21 13:25:28.957795", "%Y-%m-%d %H:%M:%S.%f")
H_ENC10_e=  datetime.datetime.strptime("2021-03-21 14:06:54.100459", "%Y-%m-%d %H:%M:%S.%f")

H_ENC11_s = datetime.datetime.strptime("2021-03-21 18:46:23.912812", "%Y-%m-%d %H:%M:%S.%f")
H_ENC11_e=  datetime.datetime.strptime("2021-03-21 19:30:46.765953", "%Y-%m-%d %H:%M:%S.%f")

H_ENC12_s = datetime.datetime.strptime("2021-03-21 20:15:33.222835", "%Y-%m-%d %H:%M:%S.%f")
H_ENC12_e=  datetime.datetime.strptime("2021-03-21 20:15:42.360361", "%Y-%m-%d %H:%M:%S.%f")

H_ENC13_s = datetime.datetime.strptime("2021-03-21 20:36:44.460596", "%Y-%m-%d %H:%M:%S.%f")
H_ENC13_e=  datetime.datetime.strptime("2021-03-21 20:50:40.901156", "%Y-%m-%d %H:%M:%S.%f")

H_ENC14_s = datetime.datetime.strptime("2021-03-21 21:16:07.103957", "%Y-%m-%d %H:%M:%S.%f")
H_ENC14_e=  datetime.datetime.strptime("2021-03-21 21:48:59.425626", "%Y-%m-%d %H:%M:%S.%f")

H_ENC15_s = datetime.datetime.strptime("2021-03-21 22:30:54.162231", "%Y-%m-%d %H:%M:%S.%f")
H_ENC15_e=  datetime.datetime.strptime("2021-03-21 22:36:18.208851", "%Y-%m-%d %H:%M:%S.%f")

H_ENC16_s = datetime.datetime.strptime("2021-03-21 22:52:18.849871", "%Y-%m-%d %H:%M:%S.%f")
H_ENC16_e=  datetime.datetime.strptime("2021-03-21 22:52:44.870850", "%Y-%m-%d %H:%M:%S.%f")

H_ENC17_s = datetime.datetime.strptime("2021-03-21 23:26:16.257801", "%Y-%m-%d %H:%M:%S.%f")
H_ENC17_e=  datetime.datetime.strptime("2021-03-21 23:26:36.607445", "%Y-%m-%d %H:%M:%S.%f")

H_ENC18_s = datetime.datetime.strptime("2021-03-21 23:57:45.979014", "%Y-%m-%d %H:%M:%S.%f")
H_ENC18_e=  datetime.datetime.strptime("2021-03-21 23:57:46.724934", "%Y-%m-%d %H:%M:%S.%f")

#Model testing 80 dpi 2s

M_ENC1_s = datetime.datetime.strptime("2021-03-21 00:28:14", "%Y-%m-%d %H:%M:%S")
M_ENC1_e=  datetime.datetime.strptime("2021-03-21 00:31:04", "%Y-%m-%d %H:%M:%S")

M_ENC2_s = datetime.datetime.strptime("2021-03-21 01:11:11", "%Y-%m-%d %H:%M:%S")
M_ENC2_e=  datetime.datetime.strptime("2021-03-21 01:11:12", "%Y-%m-%d %H:%M:%S")

M_ENC3_s = datetime.datetime.strptime("2021-03-21 03:22:42", "%Y-%m-%d %H:%M:%S")
M_ENC3_e=  datetime.datetime.strptime("2021-03-21 03:23:31", "%Y-%m-%d %H:%M:%S")

M_ENC4_s = datetime.datetime.strptime("2021-03-21 05:39:05", "%Y-%m-%d %H:%M:%S")
M_ENC4_e=  datetime.datetime.strptime("2021-03-21 05:39:14", "%Y-%m-%d %H:%M:%S")

M_ENC5_s = datetime.datetime.strptime("2021-03-21 07:00:47", "%Y-%m-%d %H:%M:%S")
M_ENC5_e=  datetime.datetime.strptime("2021-03-21 07:00:48", "%Y-%m-%d %H:%M:%S")

M_ENC6_s = datetime.datetime.strptime("2021-03-21 07:38:32", "%Y-%m-%d %H:%M:%S")
M_ENC6_e=  datetime.datetime.strptime("2021-03-21 07:38:33", "%Y-%m-%d %H:%M:%S")

M_ENC7_s = datetime.datetime.strptime("2021-03-21 09:46:51", "%Y-%m-%d %H:%M:%S")
M_ENC7_e=  datetime.datetime.strptime("2021-03-21 09:47:09", "%Y-%m-%d %H:%M:%S")

M_ENC8_s = datetime.datetime.strptime("2021-03-21 12:03:35", "%Y-%m-%d %H:%M:%S")
M_ENC8_e=  datetime.datetime.strptime("2021-03-21 12:07:48", "%Y-%m-%d %H:%M:%S")

M_ENC9_s = datetime.datetime.strptime("2021-03-21 14:44:59", "%Y-%m-%d %H:%M:%S")
M_ENC9_e=  datetime.datetime.strptime("2021-03-21 14:59:16", "%Y-%m-%d %H:%M:%S")

M_ENC10_s = datetime.datetime.strptime("2021-03-21 15:32:17", "%Y-%m-%d %H:%M:%S")
M_ENC10_e=  datetime.datetime.strptime("2021-03-21 15:32:36", "%Y-%m-%d %H:%M:%S")

M_ENC11_s = datetime.datetime.strptime("2021-03-21 16:36:22", "%Y-%m-%d %H:%M:%S")
M_ENC11_e=  datetime.datetime.strptime("2021-03-21 16:36:49", "%Y-%m-%d %H:%M:%S")

M_ENC12_s = datetime.datetime.strptime("2021-03-21 18:43:00", "%Y-%m-%d %H:%M:%S")
M_ENC12_e=  datetime.datetime.strptime("2021-03-21 19:28:02", "%Y-%m-%d %H:%M:%S")

M_ENC13_s = datetime.datetime.strptime("2021-03-21 20:34:34", "%Y-%m-%d %H:%M:%S")
M_ENC13_e=  datetime.datetime.strptime("2021-03-21 20:53:01", "%Y-%m-%d %H:%M:%S")

M_ENC14_s = datetime.datetime.strptime("2021-03-21 21:10:39", "%Y-%m-%d %H:%M:%S")
M_ENC14_e=  datetime.datetime.strptime("2021-03-21 22:08:32", "%Y-%m-%d %H:%M:%S")

M_ENC15_s = datetime.datetime.strptime("2021-03-21 22:24:46", "%Y-%m-%d %H:%M:%S")
M_ENC15_e=  datetime.datetime.strptime("2021-03-21 22:36:09", "%Y-%m-%d %H:%M:%S")

M_ENC16_s = datetime.datetime.strptime("2021-03-21 23:25:57", "%Y-%m-%d %H:%M:%S")
M_ENC16_e=  datetime.datetime.strptime("2021-03-21 23:37:23", "%Y-%m-%d %H:%M:%S")

confusion_matrix = []
for i in range(86400):
    #print(time_to_be_detected)
    
    if M_ENC1_s <= time_to_be_detected <= M_ENC1_e or M_ENC2_s <= time_to_be_detected <= M_ENC2_e or M_ENC3_s <= time_to_be_detected <= M_ENC3_e or M_ENC4_s <= time_to_be_detected <= M_ENC4_e or M_ENC5_s <= time_to_be_detected <= M_ENC5_e or M_ENC6_s <= time_to_be_detected <= M_ENC6_e or M_ENC7_s <= time_to_be_detected <= M_ENC7_e or M_ENC8_s <= time_to_be_detected <= M_ENC8_e or M_ENC9_s <= time_to_be_detected <= M_ENC9_e or M_ENC10_s <= time_to_be_detected <= M_ENC10_e or M_ENC11_s <= time_to_be_detected <= M_ENC11_e or M_ENC12_s <= time_to_be_detected <= M_ENC12_e or M_ENC13_s <= time_to_be_detected <= M_ENC13_e or M_ENC14_s <= time_to_be_detected <= M_ENC14_e or M_ENC15_s <= time_to_be_detected <= M_ENC15_e or M_ENC16_s <= time_to_be_detected <= M_ENC16_e:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e or H_ENC17_s <= time_to_be_detected <= H_ENC17_e or H_ENC18_s <= time_to_be_detected <= H_ENC18_e:
            #print("True Positive")
            confusion_matrix.append("TP")            
        else:
            #print("False Positive")
            confusion_matrix.append("FP")
    else:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e or H_ENC17_s <= time_to_be_detected <= H_ENC17_e or H_ENC18_s <= time_to_be_detected <= H_ENC18_e:
            #print("False Negative")
            confusion_matrix.append("FN")
        else:
            #print("True Negative")
            confusion_matrix.append("TN")    
           
    
    time_to_be_detected = time_to_be_detected + delta
    
confusion_matrix = pd.DataFrame(confusion_matrix, columns = ['confusion_matrix'])
prop_norm_off = confusion_matrix['confusion_matrix'].value_counts(normalize=False).to_string()#change normalize to true
#print("Confusion Matrix")
#print(prop_norm_off)
prop_norm_on = confusion_matrix['confusion_matrix'].value_counts(normalize=True).to_string()#change normalize to true
print("Model testing 90 dpi 2s Transfer Learning x Human Detector SNR > 1")
print()
print("Normalized Confusion Matrix")
print(prop_norm_on)

TN = int(confusion_matrix['confusion_matrix'].value_counts()['TN'])
FN = int(confusion_matrix['confusion_matrix'].value_counts()['FN'])
TP = int(confusion_matrix['confusion_matrix'].value_counts()['TP'])
FP = int(confusion_matrix['confusion_matrix'].value_counts()['FP'])
specificity = TN/(TN + FP)
sensitivity = TP/(FN+TP)
accuracy = (TP+TN)/(TP+TN+FP+FN)
precision = TP/(TP+FP)
print('Specificity:', specificity)
print('Sensitivity:', sensitivity)
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Model testing 90 dpi 2s Transfer Learning x Human Detector SNR > 1
#
# Normalized Confusion Matrix
# TN    0.773356
# FN    0.110069
# TP    0.065463
# FP    0.051111
# Specificity: 0.9380071314260044
# Sensitivity: 0.3729394698668073
# Accuracy: 0.8388194444444445
# Precision: 0.5615567911040509

# %%
import pandas as pd
import datetime
time = "2021-3-21 00:00:00.00"
#real_start_time = datetime.fromisoformat(time)
time_actual = datetime.datetime.strptime(time, "%Y-%m-%d %H:%M:%S.%f")
delta = delta = datetime.timedelta(seconds=1)
#print(time_actual)
time_to_be_detected = time_actual
#Human detector encounters SNR >=1
H_ENC1_s = datetime.datetime.strptime("2021-03-21 00:58:47.486945", "%Y-%m-%d %H:%M:%S.%f")
H_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:03:14.374073", "%Y-%m-%d %H:%M:%S.%f")

H_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:31.935836", "%Y-%m-%d %H:%M:%S.%f")
H_ENC2_e=  datetime.datetime.strptime("2021-03-21 03:22:45.836374", "%Y-%m-%d %H:%M:%S.%f")

H_ENC3_s = datetime.datetime.strptime("2021-03-21 03:40:16.056164", "%Y-%m-%d %H:%M:%S.%f")
H_ENC3_e=  datetime.datetime.strptime("2021-03-21 03:51:34.742141", "%Y-%m-%d %H:%M:%S.%f")

H_ENC4_s = datetime.datetime.strptime("2021-03-21 04:53:49.078051", "%Y-%m-%d %H:%M:%S.%f")
H_ENC4_e=  datetime.datetime.strptime("2021-03-21 05:53:25.625585", "%Y-%m-%d %H:%M:%S.%f")

H_ENC5_s = datetime.datetime.strptime("2021-03-21 06:11:00.072346", "%Y-%m-%d %H:%M:%S.%f")
H_ENC5_e=  datetime.datetime.strptime("2021-03-21 06:18:05.634234", "%Y-%m-%d %H:%M:%S.%f")

H_ENC6_s = datetime.datetime.strptime("2021-03-21 06:46:53.207224", "%Y-%m-%d %H:%M:%S.%f")
H_ENC6_e=  datetime.datetime.strptime("2021-03-21 06:49:34.904194", "%Y-%m-%d %H:%M:%S.%f")

H_ENC7_s = datetime.datetime.strptime("2021-03-21 07:35:41.622116", "%Y-%m-%d %H:%M:%S.%f")
H_ENC7_e=  datetime.datetime.strptime("2021-03-21 07:36:33.988652", "%Y-%m-%d %H:%M:%S.%f")

H_ENC8_s = datetime.datetime.strptime("2021-03-21 12:13:06.729857", "%Y-%m-%d %H:%M:%S.%f")
H_ENC8_e=  datetime.datetime.strptime("2021-03-21 12:13:07.055390", "%Y-%m-%d %H:%M:%S.%f")

H_ENC9_s = datetime.datetime.strptime("2021-03-21 12:37:42.023821", "%Y-%m-%d %H:%M:%S.%f")
H_ENC9_e=  datetime.datetime.strptime("2021-03-21 13:00:17.237988", "%Y-%m-%d %H:%M:%S.%f")

H_ENC10_s = datetime.datetime.strptime("2021-03-21 13:25:28.957795", "%Y-%m-%d %H:%M:%S.%f")
H_ENC10_e=  datetime.datetime.strptime("2021-03-21 14:06:54.100459", "%Y-%m-%d %H:%M:%S.%f")

H_ENC11_s = datetime.datetime.strptime("2021-03-21 18:46:23.912812", "%Y-%m-%d %H:%M:%S.%f")
H_ENC11_e=  datetime.datetime.strptime("2021-03-21 19:30:46.765953", "%Y-%m-%d %H:%M:%S.%f")

H_ENC12_s = datetime.datetime.strptime("2021-03-21 20:15:33.222835", "%Y-%m-%d %H:%M:%S.%f")
H_ENC12_e=  datetime.datetime.strptime("2021-03-21 20:15:42.360361", "%Y-%m-%d %H:%M:%S.%f")

H_ENC13_s = datetime.datetime.strptime("2021-03-21 20:36:44.460596", "%Y-%m-%d %H:%M:%S.%f")
H_ENC13_e=  datetime.datetime.strptime("2021-03-21 20:50:40.901156", "%Y-%m-%d %H:%M:%S.%f")

H_ENC14_s = datetime.datetime.strptime("2021-03-21 21:16:07.103957", "%Y-%m-%d %H:%M:%S.%f")
H_ENC14_e=  datetime.datetime.strptime("2021-03-21 21:48:59.425626", "%Y-%m-%d %H:%M:%S.%f")

H_ENC15_s = datetime.datetime.strptime("2021-03-21 22:30:54.162231", "%Y-%m-%d %H:%M:%S.%f")
H_ENC15_e=  datetime.datetime.strptime("2021-03-21 22:36:18.208851", "%Y-%m-%d %H:%M:%S.%f")

H_ENC16_s = datetime.datetime.strptime("2021-03-21 22:52:18.849871", "%Y-%m-%d %H:%M:%S.%f")
H_ENC16_e=  datetime.datetime.strptime("2021-03-21 22:52:44.870850", "%Y-%m-%d %H:%M:%S.%f")

H_ENC17_s = datetime.datetime.strptime("2021-03-21 23:26:16.257801", "%Y-%m-%d %H:%M:%S.%f")
H_ENC17_e=  datetime.datetime.strptime("2021-03-21 23:26:36.607445", "%Y-%m-%d %H:%M:%S.%f")

H_ENC18_s = datetime.datetime.strptime("2021-03-21 23:57:45.979014", "%Y-%m-%d %H:%M:%S.%f")
H_ENC18_e=  datetime.datetime.strptime("2021-03-21 23:57:46.724934", "%Y-%m-%d %H:%M:%S.%f")

#Model testing 80 dpi 2s

M_ENC1_s = datetime.datetime.strptime("2021-03-21 05:39:04", "%Y-%m-%d %H:%M:%S")
M_ENC1_e=  datetime.datetime.strptime("2021-03-21 05:39:14", "%Y-%m-%d %H:%M:%S")

M_ENC2_s = datetime.datetime.strptime("2021-03-21 09:46:50", "%Y-%m-%d %H:%M:%S")
M_ENC2_e=  datetime.datetime.strptime("2021-03-21 09:47:09", "%Y-%m-%d %H:%M:%S")

M_ENC3_s = datetime.datetime.strptime("2021-03-21 11:52:18", "%Y-%m-%d %H:%M:%S")
M_ENC3_e=  datetime.datetime.strptime("2021-03-21 12:08:31", "%Y-%m-%d %H:%M:%S")

M_ENC4_s = datetime.datetime.strptime("2021-03-21 13:36:27", "%Y-%m-%d %H:%M:%S")
M_ENC4_e=  datetime.datetime.strptime("2021-03-21 14:17:29", "%Y-%m-%d %H:%M:%S")

M_ENC5_s = datetime.datetime.strptime("2021-03-21 14:36:14", "%Y-%m-%d %H:%M:%S")
M_ENC5_e=  datetime.datetime.strptime("2021-03-21 14:59:16", "%Y-%m-%d %H:%M:%S")

M_ENC6_s = datetime.datetime.strptime("2021-03-21 15:24:57", "%Y-%m-%d %H:%M:%S")
M_ENC6_e=  datetime.datetime.strptime("2021-03-21 15:49:45", "%Y-%m-%d %H:%M:%S")

M_ENC7_s = datetime.datetime.strptime("2021-03-21 16:36:21", "%Y-%m-%d %H:%M:%S")
M_ENC7_e=  datetime.datetime.strptime("2021-03-21 16:37:25", "%Y-%m-%d %H:%M:%S")

M_ENC8_s = datetime.datetime.strptime("2021-03-21 18:42:59", "%Y-%m-%d %H:%M:%S")
M_ENC8_e=  datetime.datetime.strptime("2021-03-21 19:46:53", "%Y-%m-%d %H:%M:%S")

M_ENC9_s = datetime.datetime.strptime("2021-03-21 20:32:56", "%Y-%m-%d %H:%M:%S")
M_ENC9_e=  datetime.datetime.strptime("2021-03-21 20:53:01", "%Y-%m-%d %H:%M:%S")

M_ENC10_s = datetime.datetime.strptime("2021-03-21 21:12:47", "%Y-%m-%d %H:%M:%S")
M_ENC10_e=  datetime.datetime.strptime("2021-03-21 22:09:07", "%Y-%m-%d %H:%M:%S")

M_ENC11_s = datetime.datetime.strptime("2021-03-21 22:24:45", "%Y-%m-%d %H:%M:%S")
M_ENC11_e=  datetime.datetime.strptime("2021-03-21 22:36:09", "%Y-%m-%d %H:%M:%S")

M_ENC12_s = datetime.datetime.strptime("2021-03-21 23:11:35", "%Y-%m-%d %H:%M:%S")
M_ENC12_e=  datetime.datetime.strptime("2021-03-21 23:37:46", "%Y-%m-%d %H:%M:%S")

confusion_matrix = []
for i in range(86400):
    #print(time_to_be_detected)
    
    if M_ENC1_s <= time_to_be_detected <= M_ENC1_e or M_ENC2_s <= time_to_be_detected <= M_ENC2_e or M_ENC3_s <= time_to_be_detected <= M_ENC3_e or M_ENC4_s <= time_to_be_detected <= M_ENC4_e or M_ENC5_s <= time_to_be_detected <= M_ENC5_e or M_ENC6_s <= time_to_be_detected <= M_ENC6_e or M_ENC7_s <= time_to_be_detected <= M_ENC7_e or M_ENC8_s <= time_to_be_detected <= M_ENC8_e or M_ENC9_s <= time_to_be_detected <= M_ENC9_e or M_ENC10_s <= time_to_be_detected <= M_ENC10_e or M_ENC11_s <= time_to_be_detected <= M_ENC11_e or M_ENC12_s <= time_to_be_detected <= M_ENC12_e:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e or H_ENC17_s <= time_to_be_detected <= H_ENC17_e or H_ENC18_s <= time_to_be_detected <= H_ENC18_e:
            #print("True Positive")
            confusion_matrix.append("TP")            
        else:
            #print("False Positive")
            confusion_matrix.append("FP")
    else:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e or H_ENC17_s <= time_to_be_detected <= H_ENC17_e or H_ENC18_s <= time_to_be_detected <= H_ENC18_e:
            #print("False Negative")
            confusion_matrix.append("FN")
        else:
            #print("True Negative")
            confusion_matrix.append("TN")    
           
    
    time_to_be_detected = time_to_be_detected + delta
    
confusion_matrix = pd.DataFrame(confusion_matrix, columns = ['confusion_matrix'])
prop_norm_off = confusion_matrix['confusion_matrix'].value_counts(normalize=False).to_string()#change normalize to true
#print("Confusion Matrix")
#print(prop_norm_off)
prop_norm_on = confusion_matrix['confusion_matrix'].value_counts(normalize=True).to_string()#change normalize to true
print("Model testing 40 dpi 3s Transfer Learning x Human Detector SNR > 1")
print()
print("Normalized Confusion Matrix")
print(prop_norm_on)

TN = int(confusion_matrix['confusion_matrix'].value_counts()['TN'])
FN = int(confusion_matrix['confusion_matrix'].value_counts()['FN'])
TP = int(confusion_matrix['confusion_matrix'].value_counts()['TP'])
FP = int(confusion_matrix['confusion_matrix'].value_counts()['FP'])
specificity = TN/(TN + FP)
sensitivity = TP/(FN+TP)
accuracy = (TP+TN)/(TP+TN+FP+FN)
precision = TP/(TP+FP)
print('Specificity:', specificity)
print('Sensitivity:', sensitivity)
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Model testing 40 dpi 3s Transfer Learning x Human Detector SNR > 1
#
# Normalized Confusion Matrix
# TN    0.715220
# FP    0.109248
# TP    0.088484
# FN    0.087049
# Specificity: 0.8674930510711177
# Sensitivity: 0.5040880917842543
# Accuracy: 0.8037037037037037
# Precision: 0.44749473191290096

# %%
import pandas as pd
import datetime
time = "2021-3-21 00:00:00.00"
#real_start_time = datetime.fromisoformat(time)
time_actual = datetime.datetime.strptime(time, "%Y-%m-%d %H:%M:%S.%f")
delta = delta = datetime.timedelta(seconds=1)
#print(time_actual)
time_to_be_detected = time_actual
#Human detector encounters SNR >=1
H_ENC1_s = datetime.datetime.strptime("2021-03-21 00:58:47.486945", "%Y-%m-%d %H:%M:%S.%f")
H_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:03:14.374073", "%Y-%m-%d %H:%M:%S.%f")

H_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:31.935836", "%Y-%m-%d %H:%M:%S.%f")
H_ENC2_e=  datetime.datetime.strptime("2021-03-21 03:22:45.836374", "%Y-%m-%d %H:%M:%S.%f")

H_ENC3_s = datetime.datetime.strptime("2021-03-21 03:40:16.056164", "%Y-%m-%d %H:%M:%S.%f")
H_ENC3_e=  datetime.datetime.strptime("2021-03-21 03:51:34.742141", "%Y-%m-%d %H:%M:%S.%f")

H_ENC4_s = datetime.datetime.strptime("2021-03-21 04:53:49.078051", "%Y-%m-%d %H:%M:%S.%f")
H_ENC4_e=  datetime.datetime.strptime("2021-03-21 05:53:25.625585", "%Y-%m-%d %H:%M:%S.%f")

H_ENC5_s = datetime.datetime.strptime("2021-03-21 06:11:00.072346", "%Y-%m-%d %H:%M:%S.%f")
H_ENC5_e=  datetime.datetime.strptime("2021-03-21 06:18:05.634234", "%Y-%m-%d %H:%M:%S.%f")

H_ENC6_s = datetime.datetime.strptime("2021-03-21 06:46:53.207224", "%Y-%m-%d %H:%M:%S.%f")
H_ENC6_e=  datetime.datetime.strptime("2021-03-21 06:49:34.904194", "%Y-%m-%d %H:%M:%S.%f")

H_ENC7_s = datetime.datetime.strptime("2021-03-21 07:35:41.622116", "%Y-%m-%d %H:%M:%S.%f")
H_ENC7_e=  datetime.datetime.strptime("2021-03-21 07:36:33.988652", "%Y-%m-%d %H:%M:%S.%f")

H_ENC8_s = datetime.datetime.strptime("2021-03-21 12:13:06.729857", "%Y-%m-%d %H:%M:%S.%f")
H_ENC8_e=  datetime.datetime.strptime("2021-03-21 12:13:07.055390", "%Y-%m-%d %H:%M:%S.%f")

H_ENC9_s = datetime.datetime.strptime("2021-03-21 12:37:42.023821", "%Y-%m-%d %H:%M:%S.%f")
H_ENC9_e=  datetime.datetime.strptime("2021-03-21 13:00:17.237988", "%Y-%m-%d %H:%M:%S.%f")

H_ENC10_s = datetime.datetime.strptime("2021-03-21 13:25:28.957795", "%Y-%m-%d %H:%M:%S.%f")
H_ENC10_e=  datetime.datetime.strptime("2021-03-21 14:06:54.100459", "%Y-%m-%d %H:%M:%S.%f")

H_ENC11_s = datetime.datetime.strptime("2021-03-21 18:46:23.912812", "%Y-%m-%d %H:%M:%S.%f")
H_ENC11_e=  datetime.datetime.strptime("2021-03-21 19:30:46.765953", "%Y-%m-%d %H:%M:%S.%f")

H_ENC12_s = datetime.datetime.strptime("2021-03-21 20:15:33.222835", "%Y-%m-%d %H:%M:%S.%f")
H_ENC12_e=  datetime.datetime.strptime("2021-03-21 20:15:42.360361", "%Y-%m-%d %H:%M:%S.%f")

H_ENC13_s = datetime.datetime.strptime("2021-03-21 20:36:44.460596", "%Y-%m-%d %H:%M:%S.%f")
H_ENC13_e=  datetime.datetime.strptime("2021-03-21 20:50:40.901156", "%Y-%m-%d %H:%M:%S.%f")

H_ENC14_s = datetime.datetime.strptime("2021-03-21 21:16:07.103957", "%Y-%m-%d %H:%M:%S.%f")
H_ENC14_e=  datetime.datetime.strptime("2021-03-21 21:48:59.425626", "%Y-%m-%d %H:%M:%S.%f")

H_ENC15_s = datetime.datetime.strptime("2021-03-21 22:30:54.162231", "%Y-%m-%d %H:%M:%S.%f")
H_ENC15_e=  datetime.datetime.strptime("2021-03-21 22:36:18.208851", "%Y-%m-%d %H:%M:%S.%f")

H_ENC16_s = datetime.datetime.strptime("2021-03-21 22:52:18.849871", "%Y-%m-%d %H:%M:%S.%f")
H_ENC16_e=  datetime.datetime.strptime("2021-03-21 22:52:44.870850", "%Y-%m-%d %H:%M:%S.%f")

H_ENC17_s = datetime.datetime.strptime("2021-03-21 23:26:16.257801", "%Y-%m-%d %H:%M:%S.%f")
H_ENC17_e=  datetime.datetime.strptime("2021-03-21 23:26:36.607445", "%Y-%m-%d %H:%M:%S.%f")

H_ENC18_s = datetime.datetime.strptime("2021-03-21 23:57:45.979014", "%Y-%m-%d %H:%M:%S.%f")
H_ENC18_e=  datetime.datetime.strptime("2021-03-21 23:57:46.724934", "%Y-%m-%d %H:%M:%S.%f")

#Model testing 80 dpi 2s

M_ENC1_s = datetime.datetime.strptime("2021-03-21 01:17:39.799000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:22:23", "%Y-%m-%d %H:%M:%S")

M_ENC2_s = datetime.datetime.strptime("2021-03-21 01:40:21", "%Y-%m-%d %H:%M:%S")
M_ENC2_e=  datetime.datetime.strptime("2021-03-21 01:43:01.100000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC3_s = datetime.datetime.strptime("2021-03-21 02:53:55.700000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC3_e=  datetime.datetime.strptime("2021-03-21 03:22:18.600000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC4_s = datetime.datetime.strptime("2021-03-21 03:39:45", "%Y-%m-%d %H:%M:%S")
M_ENC4_e=  datetime.datetime.strptime("2021-03-21 04:27:04", "%Y-%m-%d %H:%M:%S")

M_ENC5_s = datetime.datetime.strptime("2021-03-21 10:37:46.600000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC5_e=  datetime.datetime.strptime("2021-03-21 11:00:22.500000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC6_s = datetime.datetime.strptime("2021-03-21 11:26:46.900000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC6_e=  datetime.datetime.strptime("2021-03-21 13:02:59.500000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC7_s = datetime.datetime.strptime("2021-03-21 17:06:09", "%Y-%m-%d %H:%M:%S")
M_ENC7_e=  datetime.datetime.strptime("2021-03-21 17:14:32", "%Y-%m-%d %H:%M:%S")

M_ENC8_s = datetime.datetime.strptime("2021-03-21 20:46:29.800000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC8_e=  datetime.datetime.strptime("2021-03-21 21:12:19.600000", "%Y-%m-%d %H:%M:%S.%f")

confusion_matrix = []
for i in range(86400):
    #print(time_to_be_detected)
    
    if M_ENC1_s <= time_to_be_detected <= M_ENC1_e or M_ENC2_s <= time_to_be_detected <= M_ENC2_e or M_ENC3_s <= time_to_be_detected <= M_ENC3_e or M_ENC4_s <= time_to_be_detected <= M_ENC4_e or M_ENC5_s <= time_to_be_detected <= M_ENC5_e or M_ENC6_s <= time_to_be_detected <= M_ENC6_e or M_ENC7_s <= time_to_be_detected <= M_ENC7_e or M_ENC8_s <= time_to_be_detected <= M_ENC8_e:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e or H_ENC17_s <= time_to_be_detected <= H_ENC17_e or H_ENC18_s <= time_to_be_detected <= H_ENC18_e:
            #print("True Positive")
            confusion_matrix.append("TP")            
        else:
            #print("False Positive")
            confusion_matrix.append("FP")
    else:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e or H_ENC17_s <= time_to_be_detected <= H_ENC17_e or H_ENC18_s <= time_to_be_detected <= H_ENC18_e:
            #print("False Negative")
            confusion_matrix.append("FN")
        else:
            #print("True Negative")
            confusion_matrix.append("TN")    
           
    
    time_to_be_detected = time_to_be_detected + delta
    
confusion_matrix = pd.DataFrame(confusion_matrix, columns = ['confusion_matrix'])
prop_norm_off = confusion_matrix['confusion_matrix'].value_counts(normalize=False).to_string()#change normalize to true
#print("Confusion Matrix")
#print(prop_norm_off)
prop_norm_on = confusion_matrix['confusion_matrix'].value_counts(normalize=True).to_string()#change normalize to true
print("Model testing PAMGuard WMD x Human Detector SNR > 1")
print()
print("Normalized Confusion Matrix")
print(prop_norm_on)

TN = int(confusion_matrix['confusion_matrix'].value_counts()['TN'])
FN = int(confusion_matrix['confusion_matrix'].value_counts()['FN'])
TP = int(confusion_matrix['confusion_matrix'].value_counts()['TP'])
FP = int(confusion_matrix['confusion_matrix'].value_counts()['FP'])
specificity = TN/(TN + FP)
sensitivity = TP/(FN+TP)
accuracy = (TP+TN)/(TP+TN+FP+FN)
precision = TP/(TP+FP)
print('Specificity:', specificity)
print('Sensitivity:', sensitivity)
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Model testing PAMGuard WMD x Human Detector SNR > 1
#
# Normalized Confusion Matrix
# TN    0.690220
# FN    0.145764
# FP    0.134248
# TP    0.029769
# Specificity: 0.8371704523120982
# Sensitivity: 0.16958987208228934
# Accuracy: 0.7199884259259259
# Precision: 0.18149742431726765

# %%
import pandas as pd
import datetime
time = "2021-3-21 00:00:00.00"
#real_start_time = datetime.fromisoformat(time)
time_actual = datetime.datetime.strptime(time, "%Y-%m-%d %H:%M:%S.%f")
delta = delta = datetime.timedelta(seconds=1)
#print(time_actual)
time_to_be_detected = time_actual
#Human detector encounters SNR >=1
H_ENC1_s = datetime.datetime.strptime("2021-03-21 00:58:47.486945", "%Y-%m-%d %H:%M:%S.%f")
H_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:03:14.374073", "%Y-%m-%d %H:%M:%S.%f")

H_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:31.935836", "%Y-%m-%d %H:%M:%S.%f")
H_ENC2_e=  datetime.datetime.strptime("2021-03-21 03:22:45.836374", "%Y-%m-%d %H:%M:%S.%f")

H_ENC3_s = datetime.datetime.strptime("2021-03-21 03:40:16.056164", "%Y-%m-%d %H:%M:%S.%f")
H_ENC3_e=  datetime.datetime.strptime("2021-03-21 03:51:34.742141", "%Y-%m-%d %H:%M:%S.%f")

H_ENC4_s = datetime.datetime.strptime("2021-03-21 04:53:49.078051", "%Y-%m-%d %H:%M:%S.%f")
H_ENC4_e=  datetime.datetime.strptime("2021-03-21 05:53:25.625585", "%Y-%m-%d %H:%M:%S.%f")

H_ENC5_s = datetime.datetime.strptime("2021-03-21 06:11:00.072346", "%Y-%m-%d %H:%M:%S.%f")
H_ENC5_e=  datetime.datetime.strptime("2021-03-21 06:18:05.634234", "%Y-%m-%d %H:%M:%S.%f")

H_ENC6_s = datetime.datetime.strptime("2021-03-21 06:46:53.207224", "%Y-%m-%d %H:%M:%S.%f")
H_ENC6_e=  datetime.datetime.strptime("2021-03-21 06:49:34.904194", "%Y-%m-%d %H:%M:%S.%f")

H_ENC7_s = datetime.datetime.strptime("2021-03-21 07:35:41.622116", "%Y-%m-%d %H:%M:%S.%f")
H_ENC7_e=  datetime.datetime.strptime("2021-03-21 07:36:33.988652", "%Y-%m-%d %H:%M:%S.%f")

H_ENC8_s = datetime.datetime.strptime("2021-03-21 12:13:06.729857", "%Y-%m-%d %H:%M:%S.%f")
H_ENC8_e=  datetime.datetime.strptime("2021-03-21 12:13:07.055390", "%Y-%m-%d %H:%M:%S.%f")

H_ENC9_s = datetime.datetime.strptime("2021-03-21 12:37:42.023821", "%Y-%m-%d %H:%M:%S.%f")
H_ENC9_e=  datetime.datetime.strptime("2021-03-21 13:00:17.237988", "%Y-%m-%d %H:%M:%S.%f")

H_ENC10_s = datetime.datetime.strptime("2021-03-21 13:25:28.957795", "%Y-%m-%d %H:%M:%S.%f")
H_ENC10_e=  datetime.datetime.strptime("2021-03-21 14:06:54.100459", "%Y-%m-%d %H:%M:%S.%f")

H_ENC11_s = datetime.datetime.strptime("2021-03-21 18:46:23.912812", "%Y-%m-%d %H:%M:%S.%f")
H_ENC11_e=  datetime.datetime.strptime("2021-03-21 19:30:46.765953", "%Y-%m-%d %H:%M:%S.%f")

H_ENC12_s = datetime.datetime.strptime("2021-03-21 20:15:33.222835", "%Y-%m-%d %H:%M:%S.%f")
H_ENC12_e=  datetime.datetime.strptime("2021-03-21 20:15:42.360361", "%Y-%m-%d %H:%M:%S.%f")

H_ENC13_s = datetime.datetime.strptime("2021-03-21 20:36:44.460596", "%Y-%m-%d %H:%M:%S.%f")
H_ENC13_e=  datetime.datetime.strptime("2021-03-21 20:50:40.901156", "%Y-%m-%d %H:%M:%S.%f")

H_ENC14_s = datetime.datetime.strptime("2021-03-21 21:16:07.103957", "%Y-%m-%d %H:%M:%S.%f")
H_ENC14_e=  datetime.datetime.strptime("2021-03-21 21:48:59.425626", "%Y-%m-%d %H:%M:%S.%f")

H_ENC15_s = datetime.datetime.strptime("2021-03-21 22:30:54.162231", "%Y-%m-%d %H:%M:%S.%f")
H_ENC15_e=  datetime.datetime.strptime("2021-03-21 22:36:18.208851", "%Y-%m-%d %H:%M:%S.%f")

H_ENC16_s = datetime.datetime.strptime("2021-03-21 22:52:18.849871", "%Y-%m-%d %H:%M:%S.%f")
H_ENC16_e=  datetime.datetime.strptime("2021-03-21 22:52:44.870850", "%Y-%m-%d %H:%M:%S.%f")

H_ENC17_s = datetime.datetime.strptime("2021-03-21 23:26:16.257801", "%Y-%m-%d %H:%M:%S.%f")
H_ENC17_e=  datetime.datetime.strptime("2021-03-21 23:26:36.607445", "%Y-%m-%d %H:%M:%S.%f")

H_ENC18_s = datetime.datetime.strptime("2021-03-21 23:57:45.979014", "%Y-%m-%d %H:%M:%S.%f")
H_ENC18_e=  datetime.datetime.strptime("2021-03-21 23:57:46.724934", "%Y-%m-%d %H:%M:%S.%f")

#Model testing 80 dpi 2s

M_ENC1_s = datetime.datetime.strptime("2021-03-21 01:17:39.799000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:22:23", "%Y-%m-%d %H:%M:%S")

M_ENC2_s = datetime.datetime.strptime("2021-03-21 01:40:21", "%Y-%m-%d %H:%M:%S")
M_ENC2_e=  datetime.datetime.strptime("2021-03-21 01:43:01.100000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC3_s = datetime.datetime.strptime("2021-03-21 02:53:55.700000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC3_e=  datetime.datetime.strptime("2021-03-21 03:22:18.600000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC4_s = datetime.datetime.strptime("2021-03-21 03:39:45", "%Y-%m-%d %H:%M:%S")
M_ENC4_e=  datetime.datetime.strptime("2021-03-21 04:27:04", "%Y-%m-%d %H:%M:%S")

M_ENC5_s = datetime.datetime.strptime("2021-03-21 04:46:57.600000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC5_e=  datetime.datetime.strptime("2021-03-21 04:49:30.400000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC6_s = datetime.datetime.strptime("2021-03-21 08:06:31.100000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC6_e=  datetime.datetime.strptime("2021-03-21 08:29:28.100000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC7_s = datetime.datetime.strptime("2021-03-21 08:53:31.600000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC7_e=  datetime.datetime.strptime("2021-03-21 08:57:19.799000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC8_s = datetime.datetime.strptime("2021-03-21 10:37:46.600000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC8_e=  datetime.datetime.strptime("2021-03-21 11:00:22.500000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC9_s = datetime.datetime.strptime("2021-03-21 11:26:46.900000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC9_e=  datetime.datetime.strptime("2021-03-21 13:02:59.500000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC10_s = datetime.datetime.strptime("2021-03-21 17:06:09", "%Y-%m-%d %H:%M:%S")
M_ENC10_e=  datetime.datetime.strptime("2021-03-21 17:14:32", "%Y-%m-%d %H:%M:%S")

M_ENC11_s = datetime.datetime.strptime("2021-03-21 20:46:29.800000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC11_e=  datetime.datetime.strptime("2021-03-21 21:12:19.600000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC12_s = datetime.datetime.strptime("2021-03-21 21:40:03.800000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC12_e=  datetime.datetime.strptime("2021-03-21 21:56:36.200000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC13_s = datetime.datetime.strptime("2021-03-21 22:33:09.800000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC13_e=  datetime.datetime.strptime("2021-03-22 00:01:24.100000", "%Y-%m-%d %H:%M:%S.%f")

confusion_matrix = []
for i in range(86400):
    #print(time_to_be_detected)
    
    if M_ENC1_s <= time_to_be_detected <= M_ENC1_e or M_ENC2_s <= time_to_be_detected <= M_ENC2_e or M_ENC3_s <= time_to_be_detected <= M_ENC3_e or M_ENC4_s <= time_to_be_detected <= M_ENC4_e or M_ENC5_s <= time_to_be_detected <= M_ENC5_e or M_ENC6_s <= time_to_be_detected <= M_ENC6_e or M_ENC7_s <= time_to_be_detected <= M_ENC7_e or M_ENC8_s <= time_to_be_detected <= M_ENC8_e or M_ENC9_s <= time_to_be_detected <= M_ENC9_e or M_ENC10_s <= time_to_be_detected <= M_ENC10_e or M_ENC11_s <= time_to_be_detected <= M_ENC11_e or M_ENC12_s <= time_to_be_detected <= M_ENC12_e or M_ENC13_s <= time_to_be_detected <= M_ENC13_e:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e or H_ENC17_s <= time_to_be_detected <= H_ENC17_e or H_ENC18_s <= time_to_be_detected <= H_ENC18_e:
            #print("True Positive")
            confusion_matrix.append("TP")            
        else:
            #print("False Positive")
            confusion_matrix.append("FP")
    else:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e or H_ENC17_s <= time_to_be_detected <= H_ENC17_e or H_ENC18_s <= time_to_be_detected <= H_ENC18_e:
            #print("False Negative")
            confusion_matrix.append("FN")
        else:
            #print("True Negative")
            confusion_matrix.append("TN")    
           
    
    time_to_be_detected = time_to_be_detected + delta
    
confusion_matrix = pd.DataFrame(confusion_matrix, columns = ['confusion_matrix'])
prop_norm_off = confusion_matrix['confusion_matrix'].value_counts(normalize=False).to_string()#change normalize to true
#print("Confusion Matrix")
#print(prop_norm_off)
prop_norm_on = confusion_matrix['confusion_matrix'].value_counts(normalize=True).to_string()#change normalize to true
print("Model testing PAMGuard WMD x Human Detector SNR > 1 ENCOUNTERS WITH MORE THAN ONE DETECTION")
print()
print("Normalized Confusion Matrix")
print(prop_norm_on)

TN = int(confusion_matrix['confusion_matrix'].value_counts()['TN'])
FN = int(confusion_matrix['confusion_matrix'].value_counts()['FN'])
TP = int(confusion_matrix['confusion_matrix'].value_counts()['TP'])
FP = int(confusion_matrix['confusion_matrix'].value_counts()['FP'])
specificity = TN/(TN + FP)
sensitivity = TP/(FN+TP)
accuracy = (TP+TN)/(TP+TN+FP+FN)
precision = TP/(TP+FP)
print('Specificity:', specificity)
print('Sensitivity:', sensitivity)
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Model testing PAMGuard WMD x Human Detector SNR > 1 ENCOUNTERS WITH MORE THAN ONE DETECTION
#
# Normalized Confusion Matrix
# TN    0.607014
# FP    0.217454
# FN    0.136829
# TP    0.038704
# Specificity: 0.7362495437571946
# Sensitivity: 0.220493208492681
# Accuracy: 0.6457175925925925
# Precision: 0.15109343936381708

# %%
import pandas as pd
import datetime
time = "2021-3-21 00:00:00.00"
#real_start_time = datetime.fromisoformat(time)
time_actual = datetime.datetime.strptime(time, "%Y-%m-%d %H:%M:%S.%f")
delta = delta = datetime.timedelta(seconds=1)
#print(time_actual)
time_to_be_detected = time_actual
#Human detector encounters SNR >=1
H_ENC1_s = datetime.datetime.strptime("2021-03-21 00:58:22.938328", "%Y-%m-%d %H:%M:%S.%f")
H_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:03:39.952157", "%Y-%m-%d %H:%M:%S.%f")

H_ENC2_s = datetime.datetime.strptime("2021-03-21 03:17:31.935836", "%Y-%m-%d %H:%M:%S.%f")
H_ENC2_e=  datetime.datetime.strptime("2021-03-21 04:21:59.049616", "%Y-%m-%d %H:%M:%S.%f")

H_ENC3_s = datetime.datetime.strptime("2021-03-21 04:53:49.078051", "%Y-%m-%d %H:%M:%S.%f")
H_ENC3_e=  datetime.datetime.strptime("2021-03-21 06:49:34.904194", "%Y-%m-%d %H:%M:%S.%f")

H_ENC4_s = datetime.datetime.strptime("2021-03-21 07:24:18.985777", "%Y-%m-%d %H:%M:%S.%f")
H_ENC4_e=  datetime.datetime.strptime("2021-03-21 07:39:28.855199", "%Y-%m-%d %H:%M:%S.%f")

H_ENC5_s = datetime.datetime.strptime("2021-03-21 12:11:50.374341", "%Y-%m-%d %H:%M:%S.%f")
H_ENC5_e=  datetime.datetime.strptime("2021-03-21 12:22:31.117159", "%Y-%m-%d %H:%M:%S.%f")

H_ENC6_s = datetime.datetime.strptime("2021-03-21 12:37:42.023821", "%Y-%m-%d %H:%M:%S.%f")
H_ENC6_e=  datetime.datetime.strptime("2021-03-21 13:06:38.879766", "%Y-%m-%d %H:%M:%S.%f")

H_ENC7_s = datetime.datetime.strptime("2021-03-21 13:22:59.004893", "%Y-%m-%d %H:%M:%S.%f")
H_ENC7_e=  datetime.datetime.strptime("2021-03-21 14:23:26.628424", "%Y-%m-%d %H:%M:%S.%f")

H_ENC8_s = datetime.datetime.strptime("2021-03-21 14:23:35.936122", "%Y-%m-%d %H:%M:%S.%f")
H_ENC8_e=  datetime.datetime.strptime("2021-03-21 15:03:31.143575", "%Y-%m-%d %H:%M:%S.%f")

H_ENC9_s = datetime.datetime.strptime("2021-03-21 18:46:23.912812", "%Y-%m-%d %H:%M:%S.%f")
H_ENC9_e=  datetime.datetime.strptime("2021-03-21 19:30:46.765953", "%Y-%m-%d %H:%M:%S.%f")

H_ENC10_s = datetime.datetime.strptime("2021-03-21 20:15:33.222835", "%Y-%m-%d %H:%M:%S.%f")
H_ENC10_e=  datetime.datetime.strptime("2021-03-21 20:15:42.360361", "%Y-%m-%d %H:%M:%S.%f")

H_ENC11_s = datetime.datetime.strptime("2021-03-21 20:36:44.460596", "%Y-%m-%d %H:%M:%S.%f")
H_ENC11_e=  datetime.datetime.strptime("2021-03-21 20:50:40.901156", "%Y-%m-%d %H:%M:%S.%f")

H_ENC12_s = datetime.datetime.strptime("2021-03-21 21:16:07.103957", "%Y-%m-%d %H:%M:%S.%f")
H_ENC12_e=  datetime.datetime.strptime("2021-03-21 21:48:59.425626", "%Y-%m-%d %H:%M:%S.%f")

H_ENC13_s = datetime.datetime.strptime("2021-03-21 22:30:54.162231", "%Y-%m-%d %H:%M:%S.%f")
H_ENC13_e=  datetime.datetime.strptime("2021-03-21 22:36:18.208851", "%Y-%m-%d %H:%M:%S.%f")

H_ENC14_s = datetime.datetime.strptime("2021-03-21 22:52:18.849871", "%Y-%m-%d %H:%M:%S.%f")
H_ENC14_e=  datetime.datetime.strptime("2021-03-21 22:52:44.870850", "%Y-%m-%d %H:%M:%S.%f")

H_ENC15_s = datetime.datetime.strptime("2021-03-21 23:26:16.257801", "%Y-%m-%d %H:%M:%S.%f")
H_ENC15_e=  datetime.datetime.strptime("2021-03-21 23:26:36.607445", "%Y-%m-%d %H:%M:%S.%f")

H_ENC16_s = datetime.datetime.strptime("2021-03-21 23:57:45.979014", "%Y-%m-%d %H:%M:%S.%f")
H_ENC16_e=  datetime.datetime.strptime("2021-03-21 23:57:46.724934", "%Y-%m-%d %H:%M:%S.%f")
#Model testing 

M_ENC1_s = datetime.datetime.strptime("2021-03-21 01:17:39.799000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC1_e=  datetime.datetime.strptime("2021-03-21 01:22:23", "%Y-%m-%d %H:%M:%S")

M_ENC2_s = datetime.datetime.strptime("2021-03-21 01:40:21", "%Y-%m-%d %H:%M:%S")
M_ENC2_e=  datetime.datetime.strptime("2021-03-21 01:43:01.100000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC3_s = datetime.datetime.strptime("2021-03-21 02:53:55.700000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC3_e=  datetime.datetime.strptime("2021-03-21 03:22:18.600000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC4_s = datetime.datetime.strptime("2021-03-21 03:39:45", "%Y-%m-%d %H:%M:%S")
M_ENC4_e=  datetime.datetime.strptime("2021-03-21 04:27:04", "%Y-%m-%d %H:%M:%S")

M_ENC5_s = datetime.datetime.strptime("2021-03-21 04:46:57.600000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC5_e=  datetime.datetime.strptime("2021-03-21 04:49:30.400000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC6_s = datetime.datetime.strptime("2021-03-21 08:06:31.100000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC6_e=  datetime.datetime.strptime("2021-03-21 08:29:28.100000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC7_s = datetime.datetime.strptime("2021-03-21 08:53:31.600000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC7_e=  datetime.datetime.strptime("2021-03-21 08:57:19.799000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC8_s = datetime.datetime.strptime("2021-03-21 10:37:46.600000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC8_e=  datetime.datetime.strptime("2021-03-21 11:00:22.500000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC9_s = datetime.datetime.strptime("2021-03-21 11:26:46.900000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC9_e=  datetime.datetime.strptime("2021-03-21 13:02:59.500000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC10_s = datetime.datetime.strptime("2021-03-21 17:06:09", "%Y-%m-%d %H:%M:%S")
M_ENC10_e=  datetime.datetime.strptime("2021-03-21 17:14:32", "%Y-%m-%d %H:%M:%S")

M_ENC11_s = datetime.datetime.strptime("2021-03-21 20:46:29.800000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC11_e=  datetime.datetime.strptime("2021-03-21 21:12:19.600000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC12_s = datetime.datetime.strptime("2021-03-21 21:40:03.800000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC12_e=  datetime.datetime.strptime("2021-03-21 21:56:36.200000", "%Y-%m-%d %H:%M:%S.%f")

M_ENC13_s = datetime.datetime.strptime("2021-03-21 22:33:09.800000", "%Y-%m-%d %H:%M:%S.%f")
M_ENC13_e=  datetime.datetime.strptime("2021-03-22 00:01:24.100000", "%Y-%m-%d %H:%M:%S.%f")

confusion_matrix = []
for i in range(86400):
    #print(time_to_be_detected)
    
    if M_ENC1_s <= time_to_be_detected <= M_ENC1_e or M_ENC2_s <= time_to_be_detected <= M_ENC2_e or M_ENC3_s <= time_to_be_detected <= M_ENC3_e or M_ENC4_s <= time_to_be_detected <= M_ENC4_e or M_ENC5_s <= time_to_be_detected <= M_ENC5_e or M_ENC6_s <= time_to_be_detected <= M_ENC6_e or M_ENC7_s <= time_to_be_detected <= M_ENC7_e or M_ENC8_s <= time_to_be_detected <= M_ENC8_e or M_ENC9_s <= time_to_be_detected <= M_ENC9_e or M_ENC10_s <= time_to_be_detected <= M_ENC10_e or M_ENC11_s <= time_to_be_detected <= M_ENC11_e or M_ENC12_s <= time_to_be_detected <= M_ENC12_e or M_ENC13_s <= time_to_be_detected <= M_ENC13_e:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e:
            #print("True Positive")
            confusion_matrix.append("TP")            
        else:
            #print("False Positive")
            confusion_matrix.append("FP")
    else:
        if H_ENC1_s <= time_to_be_detected <= H_ENC1_e or H_ENC2_s <= time_to_be_detected <= H_ENC2_e or H_ENC3_s <= time_to_be_detected <= H_ENC3_e or H_ENC4_s <= time_to_be_detected <= H_ENC4_e or H_ENC5_s <= time_to_be_detected <= H_ENC5_e or H_ENC6_s <= time_to_be_detected <= H_ENC6_e or H_ENC7_s <= time_to_be_detected <= H_ENC7_e or H_ENC8_s <= time_to_be_detected <= H_ENC8_e or H_ENC9_s <= time_to_be_detected <= H_ENC9_e or H_ENC10_s <= time_to_be_detected <= H_ENC10_e or H_ENC11_s <= time_to_be_detected <= H_ENC11_e or H_ENC12_s <= time_to_be_detected <= H_ENC12_e or H_ENC13_s <= time_to_be_detected <= H_ENC13_e or H_ENC14_s <= time_to_be_detected <= H_ENC14_e or H_ENC15_s <= time_to_be_detected <= H_ENC15_e or H_ENC16_s <= time_to_be_detected <= H_ENC16_e:
            #print("False Negative")
            confusion_matrix.append("FN")
        else:
            #print("True Negative")
            confusion_matrix.append("TN")    
           
    
    time_to_be_detected = time_to_be_detected + delta
    
confusion_matrix = pd.DataFrame(confusion_matrix, columns = ['confusion_matrix'])
prop_norm_off = confusion_matrix['confusion_matrix'].value_counts(normalize=False).to_string()#change normalize to true
#print("Confusion Matrix")
#print(prop_norm_off)
prop_norm_on = confusion_matrix['confusion_matrix'].value_counts(normalize=True).to_string()#change normalize to true
print("Model testing PAMGuard WMD x Human Detector all SNR WIT MORE THAN ONE DETECTION PER ENCOUNTER")
print()
print("Normalized Confusion Matrix")
print(prop_norm_on)

TN = int(confusion_matrix['confusion_matrix'].value_counts()['TN'])
FN = int(confusion_matrix['confusion_matrix'].value_counts()['FN'])
TP = int(confusion_matrix['confusion_matrix'].value_counts()['TP'])
FP = int(confusion_matrix['confusion_matrix'].value_counts()['FP'])
specificity = TN/(TN + FP)
sensitivity = TP/(FN+TP)
accuracy = (TP+TN)/(TP+TN+FP+FN)
precision = TP/(TP+FP)
print('Specificity:', specificity)
print('Sensitivity:', sensitivity)
print('Accuracy:', accuracy)
print('Precision:', precision)
# Out:
# Model testing PAMGuard WMD x Human Detector all SNR WIT MORE THAN ONE DETECTION PER ENCOUNTER
#
# Normalized Confusion Matrix
# TN    0.509028
# FN    0.234815
# FP    0.186678
# TP    0.069479
# Specificity: 0.7316707980502087
# Sensitivity: 0.22832908599901106
# Accuracy: 0.5785069444444444
# Precision: 0.2712362190493403
